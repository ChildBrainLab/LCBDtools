# %%
# General dependencies
import os, shutil
from os.path import join
from tqdm import tqdm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from copy import deepcopy
from glob import glob

# %%
# LCBD dependencies
# add relative path to our toolbox
import sys
sys.path.append('../../../..') # path to preprocessing from here

from LCBDtools.scripts import argParser
from LCBDtools.src import Plots
from LCBDtools.src import Statistics
from LCBDtools.src import TimeSeries
from LCBDtools.Stimuli.ATV import TrialReader

# %%
# Some configuration variables
dataDir = "/data/perlman/moochie/analysis/ATV_LCBD/ATV_data_clean_2"
# episode = 1 # which episode number (1-3) we are dealing with
TR = 0.8 # this is because we'll want to have it sampled at the TR for later (s)
min_episode_samples = 10000 # some recordings are shorter than others, and we don't want to include them...
ex_subs = [] # any subjects to not include in the dataset
participant_num_len = 3 # default length of participant numbers

# %%
# participant_keyring = {
# 	"104": ("Amanda", "BCA"),
# 	"100": ("Shelby", "ABC"),
# 	"103": ("Emily", "CAB"),
# 	"105": ("Sarah", "BCA"),
# 	"106": ("Shreeja", "CAB"),
# 	"101": ("Alcess", "BCA"),
# 	"107": ("Emma", "BAC"),
# 	"108": ("Clayton", "BCA"),
# 	"109": ("Nikhil", "ACB"),
# 	"110": ("Ruchika", "ABC"),
# 	"111": ("Justin", "BAC"),
# 	"112": ("Sishir", "BCA"),
# 	"113": ("Kaitlyn", "ABC"),
# 	"102": ("Natalia", "CBA"),
# 	"114": ("Ethan", "BCA"),
# 	"115": ("Jackie", "ACB"),
# 	"116": ("Susan", "BAC"),
#     "117": ("Susan", "ACB")
# }

# %%
# round 2
participant_keyring = {
	"204": ("Amanda", "ABC"),
    "304": ("Amanda", "ABC"),
# 	"200": ("Shelby", "ABC"),
	"203": ("Emily", "ABC"),
    "303": ("Emily", "ABC"),
	"205": ("Sarah", "ABC"),
    "305": ("Sarah", "ABC"),
	"206": ("Shreeja", "ABC"),
    "306": ("Shreeja", "ABC"),
	"201": ("Alcess", "ABC"),
    "301": ("Alcess", "ABC"),
	"207": ("Emma", "ABC"),
    "307": ("Emma", "ABC"),
    "108": ("Clayton", "BCA"),
	"208": ("Clayton", "ABC"),
    "308": ("Clayton", "ABC"),
	"116": ("Susan", "BAC"),
    "117": ("Susan", "ACB"),
    "218": ("Alana", "ABC"),
    "318": ("Alana", "ABC"),
    "219": ("Khalil", "ABC"),
    "319": ("Khalil", "ABC"),
    "216": ("Susan", "BAC"),
    "217": ("Susan", "ACB")
}

# %%
# build a list of all the applicable ATV data files
# fnames = [join(dataDir, fname) for fname in os.listdir(dataDir)\
#     if os.path.basename(fname)[:participant_num_len] not in ex_subs]

fnames = [fname for fname in glob(join(
    dataDir, '*.csv')) if os.path.basename(fname)[:participant_num_len] not in ex_subs]

# %%
len(fnames)
# Out:
# 20

# %%
dataset = []
print("Loading ATV files as TimeSeries objects:")
print("==========")
for fpath in tqdm(fnames):
    try:
        # for each filepath in the list, run an ATV.TrialReader builder
        # add each src.TimeSeries object generated from the TrialReader to
        # the dataset list
        for ts in TrialReader(fpath).ratingsSeries:
            ts.fix_nan()
            
            dataset.append(ts)
            
    except:
        print("Failure to read:", os.path.basename(fpath))
        pass
# Out:
# Loading ATV files as TimeSeries objects:
# ==========
# 100%|██████████| 20/20 [00:13<00:00,  1.48it/s]

# %%
for ts in dataset:
    print(ts.meta)
# Out:
# {'participant': '306', 'episode': 2, 'viewingOrder': 'CAB'}
# {'participant': '204', 'episode': 0, 'viewingOrder': 'ABC'}
# {'participant': '201', 'episode': 0, 'viewingOrder': 'ABC'}
# {'participant': '303', 'episode': 1, 'viewingOrder': 'BAC'}
# {'participant': '319', 'episode': 0, 'viewingOrder': 'ABC'}
# {'participant': '319', 'episode': 1, 'viewingOrder': 'ABC'}
# {'participant': '319', 'episode': 2, 'viewingOrder': 'ABC'}
# {'participant': '308', 'episode': 2, 'viewingOrder': 'CAB'}
# {'participant': '308', 'episode': 0, 'viewingOrder': 'CAB'}
# {'participant': '305', 'episode': 2, 'viewingOrder': 'CAB'}
# {'participant': '117', 'episode': 0, 'viewingOrder': 'ACB'}
# {'participant': '117', 'episode': 2, 'viewingOrder': 'ACB'}
# {'participant': '117', 'episode': 1, 'viewingOrder': 'ACB'}
# {'participant': '305', 'episode': 1, 'viewingOrder': 'BCA'}
# {'participant': '303', 'episode': 2, 'viewingOrder': 'CAB'}
# {'participant': '108', 'episode': 1, 'viewingOrder': 'BCA'}
# {'participant': '108', 'episode': 2, 'viewingOrder': 'BCA'}
# {'participant': '108', 'episode': 0, 'viewingOrder': 'BCA'}
# {'participant': '203', 'episode': 0, 'viewingOrder': 'ABC'}
# {'participant': '306', 'episode': 2, 'viewingOrder': 'CAB'}
# {'participant': '318', 'episode': 0, 'viewingOrder': 'ABC'}
# {'participant': '318', 'episode': 1, 'viewingOrder': 'ABC'}
# {'participant': '318', 'episode': 2, 'viewingOrder': 'ABC'}
# {'participant': '301', 'episode': 1, 'viewingOrder': 'BCA'}
# {'participant': '301', 'episode': 2, 'viewingOrder': 'BCA'}
# {'participant': '316', 'episode': 1, 'viewingOrder': 'BCA'}
# {'participant': '316', 'episode': 2, 'viewingOrder': 'BCA'}
# {'participant': '207', 'episode': 0, 'viewingOrder': 'ABC'}
# {'participant': '207', 'episode': 1, 'viewingOrder': 'ABC'}
# {'participant': '205', 'episode': 0, 'viewingOrder': 'ABC'}
# {'participant': '206', 'episode': 0, 'viewingOrder': 'ABC'}
# {'participant': '307', 'episode': 0, 'viewingOrder': 'ABC'}

# %%
# manual adjustment because Susan watched in 2 trials
# 1st was 116 watching B
# 2nd was 117 watching AC
# just make both into 116

for i, ts in reversed(list(enumerate(dataset))):
    if ts.meta['participant'] == '117':
        if ts.meta['episode'] == 1:
            dataset.pop(i)
            print("pop")
            
for i, ts in reversed(list(enumerate(dataset))):
    if len(ts.signal) < min_episode_samples:
        dataset.pop(i)
        print("pop:", ts.meta)
# Out:
# pop
# pop: {'participant': '207', 'episode': 1, 'viewingOrder': 'ABC'}
# pop: {'participant': '306', 'episode': 2, 'viewingOrder': 'CAB'}

# %%
print(
    [len(ts.signal) for ts in dataset]
)
# Out:
# [51505, 52968, 38593, 43826, 38372, 43349, 57606, 55854, 56076, 64387, 67070, 38406, 56826, 72613, 73591, 63494, 44077, 61301, 48094, 38353, 48067, 38593, 56288, 38530, 54961, 50888, 51824, 51426, 52711]

# %%
fig, axs = plt.subplots(nrows=len(dataset), sharex=True, sharey=True)

plt.tight_layout()

for i, ts in enumerate(dataset):
    axs[i].plot(
        ts.time,
        ts.signal,
        label=(ts.meta['participant']+": "+str(ts.meta['episode']))
    )
    
    axs[i].set_ylabel(ts.meta['participant'], rotation=45)
    axs[i].set_yticks([])
#axs.legend(loc='upper right')
#fig.xlabel("Time")
#fig.ylabel("Judges")
#fig.suptitle("Indvidiaul Emotional Ratings")
    
plt.savefig(
    "/data/perlman/moochie/user_data/SchneiderClayton/emoratingsmultiple.png",
    dpi=100,
    facecolor='white')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# fig, axs = plt.subplots(nrows=len(dataset))

# for i, ts in enumerate(dataset):
# #     axs[i].plot(
# #         np.linspace(
# #             ts.time[0],
# #             ts.time[-1],
# #             num=len(ts.time)),
# #         ts.time,
# #         label=(ts.meta['participant'])
# #     )
#     print(
#         np.linspace(
#             ts.time[0],
#             ts.time[-1],
#         num=len(ts.time)),
#     )
    
# plt.legend(loc='upper right')

# plt.show()

# %%
dataset_cop = dataset

# %%
print("Preprocessing TimeSeries:")
print("==========")

bads = []

for i, ts in enumerate(tqdm(dataset)):
    try:
        # correct NaN values (done up top ^^^)
        # ts.fix_nan()

        # accommodate for skippy framerates
        # i.e. make ts.time a linear range
        ts.lag_correct()

        # sample to TR
        ts.resample(sample_rate=TR)
        
        # accommodate for skippy framerates
        # i.e. make ts.time a linear range
        ts.lag_correct()

        # chunking
        # ts.signal = ts.round_res()

        # center timeseries?
        ts.center()

        # smoothing (savgol filter)
        ts.savgol_filter(w=13, poly_order=3)
        
    except:
        print("Error @", ts.meta, ": skipping.")
        bads.append(i)
        print(i)
        continue
        
while len(bads) > 0:
    dataset.pop(max(bads))
    bads.pop(bads.index(max(bads)))
# Out:
# Preprocessing TimeSeries:
# ==========
# 100%|██████████| 29/29 [00:00<00:00, 182.94it/s]

# %%
fig, axs = plt.subplots(nrows=len(dataset))

plt.tight_layout()

for i, ts in enumerate(dataset):
    axs[i].plot(
        ts.time,
        ts.signal,
        label=(ts.meta['participant']+": "+str(ts.meta['episode']))
    )
    
    axs[i].legend(loc='upper right')

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
print("Inspecting Lengths of Ratings in Each Episode:")
print("==========")
episodes = []

for episode in tqdm(list(set([int(ts.meta['episode']) for ts in dataset]))):
    episodes.append(episode)
    plt.hist(
        [ts.time[-1] for ts in dataset\
        if ts.meta['episode']==episode],
        alpha=0.5,
        label="Episode "+str(episode))
    
plt.xlim(0, 2000)
plt.title("distribution of episode lengths")
plt.legend()
# Out:
# Inspecting Lengths of Ratings in Each Episode:
# ==========
# 100%|██████████| 3/3 [00:00<00:00, 106.51it/s]

# %%
for episode in tqdm(list(set([int(ts.meta['episode']) for ts in dataset]))):
    for ts in [ts for ts in dataset \
        if ts.meta['episode']==episode]:
        print(
            "episode:",
            ts.meta['episode'],
            "\t",
            "participant ID:",
            ts.meta['participant'],
            "\t",
            "participant name:",
            participant_keyring["2"+ts.meta['participant'][1:]][0],
            "\t",
            "length:",
            len(ts.signal))
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 158.59it/s]
# episode: 0 	 participant ID: 204 	 participant name: Amanda 	 length: 1705
# episode: 0 	 participant ID: 201 	 participant name: Alcess 	 length: 1705
# episode: 0 	 participant ID: 319 	 participant name: Khalil 	 length: 1705
# episode: 0 	 participant ID: 308 	 participant name: Clayton 	 length: 1705
# episode: 0 	 participant ID: 117 	 participant name: Susan 	 length: 1705
# episode: 0 	 participant ID: 108 	 participant name: Clayton 	 length: 1705
# episode: 0 	 participant ID: 203 	 participant name: Emily 	 length: 1705
# episode: 0 	 participant ID: 318 	 participant name: Alana 	 length: 1705
# episode: 0 	 participant ID: 207 	 participant name: Emma 	 length: 1705
# episode: 0 	 participant ID: 205 	 participant name: Sarah 	 length: 1705
# episode: 0 	 participant ID: 206 	 participant name: Shreeja 	 length: 1705
# episode: 0 	 participant ID: 307 	 participant name: Emma 	 length: 1705
# episode: 1 	 participant ID: 303 	 participant name: Emily 	 length: 1605
# episode: 1 	 participant ID: 319 	 participant name: Khalil 	 length: 1605
# episode: 1 	 participant ID: 305 	 participant name: Sarah 	 length: 1605
# episode: 1 	 participant ID: 108 	 participant name: Clayton 	 length: 1605
# episode: 1 	 participant ID: 318 	 participant name: Alana 	 length: 1605
# episode: 1 	 participant ID: 301 	 participant name: Alcess 	 length: 1605
# episode: 1 	 participant ID: 316 	 participant name: Susan 	 length: 1605
# episode: 2 	 participant ID: 319 	 participant name: Khalil 	 length: 1652
# episode: 2 	 participant ID: 308 	 participant name: Clayton 	 length: 1652
# episode: 2 	 participant ID: 305 	 participant name: Sarah 	 length: 1652
# episode: 2 	 participant ID: 117 	 participant name: Susan 	 length: 1652
# episode: 2 	 participant ID: 303 	 participant name: Emily 	 length: 1652
# episode: 2 	 participant ID: 108 	 participant name: Clayton 	 length: 1652
# episode: 2 	 participant ID: 306 	 participant name: Shreeja 	 length: 1652
# episode: 2 	 participant ID: 318 	 participant name: Alana 	 length: 1652
# episode: 2 	 participant ID: 301 	 participant name: Alcess 	 length: 1652
# episode: 2 	 participant ID: 316 	 participant name: Susan 	 length: 1652

# %%
print(episodes)
# Out:
# [0, 1, 2]

# %%
print("Gold Standard ATV Rating:")
print("==========")

gold_standard = "Susan"

gold = []

for ts in dataset:
    if ts.meta['participant'][0] == '1':
        if participant_keyring[ts.meta['participant']][0] == gold_standard:
            gold.append(ts)

# gold = [ts for ts in dataset \
#     if (participant_keyring[ts.meta['participant']][0] == gold_standard) and (ts.meta['participant'][0] == '1') ]

for ts in gold:
    Plots.plot_xy_line(
        ts.time,
        ts.signal,
        ylabel="Rating of Emotion: -1 to 1 (Negative to Positive)",
        plot_axis=np.zeros(round(ts.time[-1])),
        title="Episode "+str(ts.meta['episode']))
# Out:
# Gold Standard ATV Rating:
# ==========

# %%
print("Inspecting Lengths of Ratings in Each Episode After Dropping:")
print("==========")

dataset = [ts for ts in dataset if ts.time[-1] > 1000]

for episode in episodes:
    
    plt.hist([ts.time[-1] for ts in dataset\
        if ts.meta['episode']==episode],
        alpha=0.5,
        label="Episode: "+str(episode))
plt.legend()
# Out:
# Inspecting Lengths of Ratings in Each Episode After Dropping:
# ==========

# %%
for episode in tqdm(list(set([ts.meta['episode'] for ts in dataset]))):
    for ts in [ts for ts in dataset \
        if ts.meta['episode']==episode]:
        print(
            "episode:",
            ts.meta['episode'],
            "\t",
            "participant ID:",
            ts.meta['participant'],
            "\t",
            "participant name:",
            participant_keyring["2"+ts.meta['participant'][1:]][0],
            "\t",
            "length:",
            len(ts.signal))
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 411.43it/s]
# episode: 0 	 participant ID: 204 	 participant name: Amanda 	 length: 1705
# episode: 0 	 participant ID: 201 	 participant name: Alcess 	 length: 1705
# episode: 0 	 participant ID: 319 	 participant name: Khalil 	 length: 1705
# episode: 0 	 participant ID: 308 	 participant name: Clayton 	 length: 1705
# episode: 0 	 participant ID: 117 	 participant name: Susan 	 length: 1705
# episode: 0 	 participant ID: 108 	 participant name: Clayton 	 length: 1705
# episode: 0 	 participant ID: 203 	 participant name: Emily 	 length: 1705
# episode: 0 	 participant ID: 318 	 participant name: Alana 	 length: 1705
# episode: 0 	 participant ID: 207 	 participant name: Emma 	 length: 1705
# episode: 0 	 participant ID: 205 	 participant name: Sarah 	 length: 1705
# episode: 0 	 participant ID: 206 	 participant name: Shreeja 	 length: 1705
# episode: 0 	 participant ID: 307 	 participant name: Emma 	 length: 1705
# episode: 1 	 participant ID: 303 	 participant name: Emily 	 length: 1605
# episode: 1 	 participant ID: 319 	 participant name: Khalil 	 length: 1605
# episode: 1 	 participant ID: 305 	 participant name: Sarah 	 length: 1605
# episode: 1 	 participant ID: 108 	 participant name: Clayton 	 length: 1605
# episode: 1 	 participant ID: 318 	 participant name: Alana 	 length: 1605
# episode: 1 	 participant ID: 301 	 participant name: Alcess 	 length: 1605
# episode: 1 	 participant ID: 316 	 participant name: Susan 	 length: 1605
# episode: 2 	 participant ID: 319 	 participant name: Khalil 	 length: 1652
# episode: 2 	 participant ID: 308 	 participant name: Clayton 	 length: 1652
# episode: 2 	 participant ID: 305 	 participant name: Sarah 	 length: 1652
# episode: 2 	 participant ID: 117 	 participant name: Susan 	 length: 1652
# episode: 2 	 participant ID: 303 	 participant name: Emily 	 length: 1652
# episode: 2 	 participant ID: 108 	 participant name: Clayton 	 length: 1652
# episode: 2 	 participant ID: 306 	 participant name: Shreeja 	 length: 1652
# episode: 2 	 participant ID: 318 	 participant name: Alana 	 length: 1652
# episode: 2 	 participant ID: 301 	 participant name: Alcess 	 length: 1652
# episode: 2 	 participant ID: 316 	 participant name: Susan 	 length: 1652

# %%
print("Matching Lengths and Discretizing the Dataset By Episode with Averages of Each:")
print("==========")

episodes = []
d_dataset = {}
d_avgs = {}
# truncate each batch of runs with the same episode to the length of the
# shortest trial in the batch
for episode in tqdm(list(set([ts.meta['episode'] for ts in dataset]))):
    episodes.append(episode)
    
    if len(list(set([len(ts.signal) for ts in dataset\
        if ts.meta['episode']==episode]))) > 1:
        
        ep_min = min([len(ts.signal) for ts in dataset\
            if ts.meta['episode']==episode and ts.time[-1] > min_episode_samples])

        # here is the trimming portion
        for ts in [ts for ts in dataset if ts.meta['episode']==episode]:
            ts.signal = ts.signal[:ep_min]
            ts.time = ts.time[:ep_min]
        
    # discretize the dataset to a dict with entry for each episode
    d_dataset[episode] = [ts for ts in dataset if ts.meta['episode'] == episode]
    # make averages (discretized) of each episode's runs (same struc as d_dataset)
    d_avgs[episode] = TimeSeries.TimeSeries(
        signal=np.average(np.array([ts.signal for ts in d_dataset[episode]]), axis=0),
        time=d_dataset[episode][0].time,
        meta={
            'participant': 'AVG',
            'episode': episode})
# Out:
# Matching Lengths and Discretizing the Dataset By Episode with Averages of Each:
# ==========
# 100%|██████████| 3/3 [00:00<00:00, 2157.19it/s]

# %%
for episode in episodes:
    plt.hist(
        [len(ts.signal) for ts in d_dataset[episode]],
        label="Episode "+str(episode))
plt.legend()

# %%
# just view the structure of this object
print(d_dataset)
print(d_avgs)
# Out:
# {0: [<LCBDtools.src.TimeSeries.TimeSeries object at 0x7fbb69097c10>, <LCBDtools.src.TimeSeries.TimeSeries object at 0x7fbb690972d0>, <LCBDtools.src.TimeSeries.TimeSeries object at 0x7fbb69084090>, <LCBDtools.src.TimeSeries.TimeSeries object at 0x7fbb690472d0>, <LCBDtools.src.TimeSeries.TimeSeries object at 0x7fbb69036550>, <LCBDtools.src.TimeSeries.TimeSeries object at 0x7fbb69034510>, <LCBDtools.src.TimeSeries.TimeSeries object at 0x7fbb690369d0>, <LCBDtools.src.TimeSeries.TimeSeries object at 0x7fbb668f1f10>, <LCBDtools.src.TimeSeries.TimeSeries object at 0x7fbb69036190>, <LCBDtools.src.TimeSeries.TimeSeries object at 0x7fbb69041c10>, <LCBDtools.src.TimeSeries.TimeSeries object at 0x7fbb69084c10>, <LCBDtools.src.TimeSeries.TimeSeries object at 0x7fbb668eac10>], 1: [<LCBDtools.src.TimeSeries.TimeSeries object at 0x7fbb69097d50>, <LCBDtools.src.TimeSeries.TimeSeries object at 0x7fbb69084f50>, <LCBDtools.src.TimeSeries.TimeSeries object at 0x7fbb69036f10>, <LCBDtools.src.TimeSeries.TimeSeries object at 0x7fbb69034310>, <LCBDtools.src.TimeSeries.TimeSeries object at 0x7fbb668f1a10>, <LCBDtools.src.TimeSeries.TimeSeries object at 0x7fbb69036250>, <LCBDtools.src.TimeSeries.TimeSeries object at 0x7fbb69041f50>], 2: [<LCBDtools.src.TimeSeries.TimeSeries object at 0x7fbb69084d90>, <LCBDtools.src.TimeSeries.TimeSeries object at 0x7fbb69047310>, <LCBDtools.src.TimeSeries.TimeSeries object at 0x7fbb690364d0>, <LCBDtools.src.TimeSeries.TimeSeries object at 0x7fbb69036410>, <LCBDtools.src.TimeSeries.TimeSeries object at 0x7fbb955eb510>, <LCBDtools.src.TimeSeries.TimeSeries object at 0x7fbb690348d0>, <LCBDtools.src.TimeSeries.TimeSeries object at 0x7fbb668f1610>, <LCBDtools.src.TimeSeries.TimeSeries object at 0x7fbb69036850>, <LCBDtools.src.TimeSeries.TimeSeries object at 0x7fbb69036490>, <LCBDtools.src.TimeSeries.TimeSeries object at 0x7fbb69041b50>]}
# {0: <LCBDtools.src.TimeSeries.TimeSeries object at 0x7fbad3983390>, 1: <LCBDtools.src.TimeSeries.TimeSeries object at 0x7fbad3e0dd10>, 2: <LCBDtools.src.TimeSeries.TimeSeries object at 0x7fbad3e0dc90>}

# %%
fig, axs = plt.subplots(nrows=len(episodes))

for i, episode in enumerate(episodes):
    for ts in d_dataset[episode]:
        axs[i].plot(ts.signal[20:80])
    
    axs[i].plot(d_avgs[episode].signal[20:80], "k--", label="Average")
    
    axs[i].legend(loc='upper right')
    axs[i].set_ylabel("Episode " + str(episode))
    
    
plt.savefig(
    "/data/perlman/moochie/user_data/SchneiderClayton/emoratingsynchrony.png",
    dpi=100,
    facecolor='white')
plt.show()

# %%
fig, axs = plt.subplots(nrows=1)

for i, episode in enumerate(episodes):
    if i != 1:
        continue

    for ts in d_dataset[episode]:
        axs.plot(ts.signal[20:120], color='lightblue')
    
    axs.plot(d_avgs[episode].signal[20:120], "k--", label="Average", linewidth=5)
    
    axs.legend(loc='upper right')
    axs.set_ylabel("Episode " + str(episode))
    
    
plt.savefig(
    "/data/perlman/moochie/user_data/SchneiderClayton/emoratingsynchrony_pretty.png",
    dpi=100,
    facecolor='white')
plt.show()

# %%
plt.scatter(
    d_dataset[0][0].signal,
    d_dataset[0][1].signal,
    alpha=0.2)

# %%
plt.scatter(
    d_dataset[0][0].signal,
    d_avgs[0].signal,
    alpha=0.2)

plt.savefig(
    "/data/perlman/moochie/user_data/SchneiderClayton/emoratingscovarywithavg.png",
    dpi=100,
    facecolor='white')
plt.show()

# %%
d_dataset[0][0].__dict__
# Out:
# {'signal': array([-0.0577522 ,  0.01037125,  0.0454744 , ...,  0.01937731,
#          0.01216194, -0.02677477]),
#  'time': array([0.00000000e+00, 7.99882629e-01, 1.59976526e+00, ...,
#         1.36140023e+03, 1.36220012e+03, 1.36300000e+03]),
#  'sampleRate': 60.049132224571,
#  'meta': {'participant': '204', 'episode': 0, 'viewingOrder': 'ABC'},
#  'unit': 's'}

# %%
Statistics.ping_icc([
    d_dataset[0][0],
    d_dataset[0][1]])
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:80: RequestsDependencyWarning: urllib3 (1.26.10) or chardet (5.0.0) doesn't match a supported version!
#   RequestsDependencyWarning)
# /home/usr/schneiderc/.local/lib/python3.7/site-packages/outdated/utils.py:18: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.5.1, the latest is 0.5.2.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs
#     Type              Description       ICC         F   df1   df2  \
# 0   ICC1   Single raters absolute  0.652570  4.756561  1704  1705
# 1   ICC2     Single random raters  0.652693  4.766267  1704  1704
# 2   ICC3      Single fixed raters  0.653155  4.766267  1704  1704
# 3  ICC1k  Average raters absolute  0.789764  4.756561  1704  1705
# 4  ICC2k    Average random raters  0.789854  4.766267  1704  1704
# 5  ICC3k     Average fixed raters  0.790192  4.766267  1704  1704
#
#             pval         CI95%
# 0  5.929215e-208  [0.62, 0.68]
# 1  2.334478e-208  [0.62, 0.68]
# 2  2.334478e-208  [0.63, 0.68]
# 3  5.929215e-208  [0.77, 0.81]
# 4  2.334478e-208  [0.77, 0.81]
# 5  2.334478e-208  [0.77, 0.81]

# %%
plt.plot(d_dataset[0][0].time, d_dataset[0][0].signal)
plt.plot(d_dataset[0][1].time, d_dataset[0][1].signal)

# %%
# initialize empty array for icc values (one per timepoint)
icc_dfs = {}
icc_vals = {}

for episode in episodes:
    
    # labels are all participants for episode + 'avg'
    xticklabels = list(set([ts.meta['participant'] for ts in d_dataset[episode]]))
    xticklabels.append('avg')
    yticklabels = deepcopy(xticklabels)
    
    df = pd.DataFrame(
        columns=xticklabels,
        index=yticklabels)
    
    
    for j, row in enumerate(df.index):
        for i, col in enumerate(df.columns):
        
            # case that we are in upper-right triangle of matrix
            if i > j:
                # grab ts1
                if col == 'avg':
                    ts1 = d_avgs[episode]
                else:
                    # the index of the dataset where the participant is col
                    ts1 = d_dataset[episode][[ts.meta['participant'] for ts in d_dataset[episode]].index(col)]
                    
                # grab ts2
                if row == 'avg':
                    ts2 = d_avgs[episode]
                else:
                    # the index of the dataset where the participant is row
                    ts2 = d_dataset[episode][[ts.meta['participant'] for ts in d_dataset[episode]].index(row)]

                try:
                    # compute ICC between ts1 and ts2
                    icc = Statistics.ping_icc([ts1, ts2])

                    df.iat[j, i] = icc.iat[0,2]
                    
                    # if significance
                    # if icc.iat[0, 6] < 0.05:
                        # df.iat[j, i] = df.iat[j, i]+"*"
                    
                except:
                    df.iat[j, i] = 0
                    print("Err @ row ", j, "col", i)
                    
            # case we are on diagonal
            elif i == j:
                df.iat[j, i] = 1
                
            # case that we are in bottom-left triangle of matrix
            else:
                df.iat[j, i] = df.iat[i, j]
            
    icc_dfs[episode] = df
    
    # do icc for whole set of them (not including average)
    icc = Statistics.ping_icc(d_dataset[episode])
    icc_vals[episode] = icc.iat[0,2].round(2)

# %%
icc_dfs[2]
# Out:
#           117       305       108       303       318       301       316  \
# 117         1  0.380706  0.373832  0.469741  0.454939  0.343255  0.697606
# 305  0.380706         1  0.393474  0.519083  0.397466  0.438939  0.348772
# 108  0.373832  0.393474         1  0.393357  0.211802  0.413678  0.342249
# 303  0.469741  0.519083  0.393357         1  0.523939   0.32731  0.516177
# 318  0.454939  0.397466  0.211802  0.523939         1  0.292886  0.501785
# 301  0.343255  0.438939  0.413678   0.32731  0.292886         1   0.33164
# 316  0.697606  0.348772  0.342249  0.516177  0.501785   0.33164         1
# 308  0.309077  0.440271  0.345207  0.355779  0.292972  0.400636  0.304381
# 306  0.372808  0.413561   0.34436  0.375616  0.368794  0.564873  0.313848
# 319  0.406879  0.429592  0.230009  0.399643  0.313989  0.423312  0.292192
# avg  0.651683  0.730939  0.553026  0.716192  0.631143  0.598577  0.622344
#
#           308       306       319       avg
# 117  0.309077  0.372808  0.406879  0.651683
# 305  0.440271  0.413561  0.429592  0.730939
# 108  0.345207   0.34436  0.230009  0.553026
# 303  0.355779  0.375616  0.399643  0.716192
# 318  0.292972  0.368794  0.313989  0.631143
# 301  0.400636  0.564873  0.423312  0.598577
# 316  0.304381  0.313848  0.292192  0.622344
# 308         1  0.403578  0.277884  0.606709
# 306  0.403578         1   0.38957  0.629399
# 319  0.277884   0.38957         1  0.576491
# avg  0.606709  0.629399  0.576491         1

# %%
avgsic = []

for i in range(3):
    avgsic.append(
        icc_dfs[i]['avg'][:-1].max()
    )

# %%
avgsic
# Out:
# [0.8141714432830374, 0.8502757544042274, 0.7309387250430093]

# %%
cmatrix = np.array(icc_dfs[0]).astype(float)

# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 100

# %%
plot_episode = 0

ax = sns.heatmap(
    cmatrix,
    annot=True,
    xticklabels=[str(col) for col in icc_dfs[plot_episode].columns],
    yticklabels=[str(ind) for ind in icc_dfs[plot_episode].index],
#     cmap=sns.diverging_palette(20, 220, n=200),
    cmap="BuGn",
    linewidths=1,
    square=True,
    vmin=0,
    vmax=1)

ax.set_title("ICC(1) of Episode {}: {}".format(plot_episode, icc_vals[plot_episode]))
ax.xaxis.tick_top() # x axis on top
ax.xaxis.set_label_position('top')

plt.savefig(
    "/data/perlman/moochie/user_data/SchneiderClayton/emoratingsheatmap.png",
    dpi=100,
    facecolor='white')
plt.show()
# ax.set_xticklabels(
#     [str(col) for col in iccs[0].columns],
#     rotation=45,
#     horizontalalignment='right')

# %%
plt.plot(
    d_avgs[0].time,
    d_avgs[0].signal)

# %%
d_avgs[0].signal
# Out:
# array([0.09660339, 0.06678638, 0.03939111, ..., 0.2117256 , 0.23039605,
#        0.25930786])

# %%
len(d_avgs[0].signal)
# Out:
# 1705

# %%
f = open('/data/perlman/moochie/analysis/CARE/AHKJ_rating_avg_movieC.txt', 'w')

for i, val in enumerate(d_avgs[2].signal):
    if i > 0:
        f.write('\n')
    f.write(str(val))
    
f.close()

# %%
total_len = 0

for episode in episodes:
    total_len += list(set([len(ts.signal) for ts in d_dataset[episode]]))[0]
    
print("Ideal concatenated length:", total_len, "samples.")
# Out:
# Ideal concatenated length: 3174 samples.

# %%
# concat each episode to each other ep for that participant?

c_dataset = {}

for i, episode in enumerate(episodes):
    
    for ts in d_dataset[episode]:
        if participant_keyring[ts.meta['participant']][0] not in c_dataset:
            c_dataset[participant_keyring[ts.meta['participant']][0]] = ts.signal
        else:
            c_dataset[participant_keyring[ts.meta['participant']][0]] = np.concatenate((
                c_dataset[participant_keyring[ts.meta['participant']][0]],
                ts.signal))

# %%
len(c_dataset)
# Out:
# 16

# %%
# only get those who have all 3 episodes

c_dataset = {
    sub: c_dataset[sub] for sub in c_dataset.keys() if len(c_dataset[sub]) == total_len}

# %%
# appears to be all of them here. great
len(c_dataset)
# Out:
# 16

# %%
iccs = []

for sub in c_dataset.keys():
    if sub is not "Susan":
        print(sub)
        iccs.append(Statistics.ping_icc([ts1, ts2]))

# %%
from scipy.signal import savgol_filter

# %%
y_filtered = savgol_filter(
    c_dataset['Susan'],
    window_length=13,
    polyorder=3
)

# %%
plt.plot(y_filtered, label='smooth')
plt.plot(c_dataset['Susan'], label='Susan')
plt.legend()

# %%
f = open("/data/perlman/moochie/analysis/CARE/AHKJ_rating.txt", 'w')

for i, val in enumerate(y_filtered):
    if i > 0:
        f.write('\n')
    f.write(str(val))
    
f.close()
