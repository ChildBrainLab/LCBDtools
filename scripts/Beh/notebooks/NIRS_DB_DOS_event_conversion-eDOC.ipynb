# %%
import sys
import os, shutil
from os.path import join
from glob import glob
from tqdm import tqdm
import pandas as pd
import numpy as np

# %%
sys.path.append('../../../..')
from LCBDtools.src import argParser

# %%
# parameters
nirs_dir = "/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/"
psypy_dir = "/data/perlman/moochie/study_data/eDOC_NARSAD/task_data/V1"
ex_subs = []
participant_num_len = 4
sample_rate = 7.81250
n_blocks = 3

# %%
nirs_session_dirs = [os.path.split(d)[0] for d in glob(
    nirs_dir+"**/*_probeInfo.mat",
    recursive=True)]

# %%
nirs_session_dirs
# Out:
# ['/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5016_N/5016_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5016_N/5016_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5098_N/5098_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5098_N/5098_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5124_N/5124_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5124_N/5124_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5082_N/5082_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5082_N/5082_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5075_N/5075_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5075_N/5075_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5065_N/5065_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5065_N/5065_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5044_N/5044_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5044_N/5044_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5088_N/5088_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5088_N/5088_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5134_N/5134_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5134_N/5134_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5115_N/5115_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5115_N/5115_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5064_N/5064_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5064_N/5064_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5093_N/5093_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5093_N/5093_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5083_N/5083_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5083_N/5083_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5055_N/5055_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5055_N/5055_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5036_N/5036_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5036_N/5036_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5017_N/5017_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5017_N/5017_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5106_N/5106_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5106_N/5106_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5015_N/5015_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5015_N/5015_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5034_N/5034_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5034_N/5034_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5057_N/5057_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5057_N/5057_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5144_N/5144_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5144_N/5144_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5076_N/5076_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5076_N/5076_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5066_N/5066_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5066_N/5066_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5047_N/5047_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5047_N/5047_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5137_N/5137_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5137_N/5137_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5005_N/5005_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5005_N/5005_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5004_N/5004_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5004_N/5004_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5025_N/5025_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5025_N/5025_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5046_N/5046_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5046_N/5046_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5067_N/5067_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5067_N/5067_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5090_N/5090_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5090_N/5090_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5077_N/5077_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5077_N/5077_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5080_N/5080_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5080_N/5080_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5056_N/5056_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5056_N/5056_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5145_N/5145_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5145_N/5145_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5103_N/5103_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5103_N/5103_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5010_N/5010_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5010_N/5010_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5069_N/5069_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5069_N/5069_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5122_N/5122_N_parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5122_N/5122_N_child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5119_N/5119_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5119_N/5119_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5138_N/5138_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5138_N/5138_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5073_N/5073_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5073_N/5073_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5063_N/5063_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5063_N/5063_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5094_N/5094_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5094_N/5094_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5132_N/5132_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5132_N/5132_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5079_N/5079_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5079_N/5079_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5113_N/5113_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5113_N/5113_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5133_N/5133_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5133_N/5133_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5020_N/5020_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5020_N/5020_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5150_N/5150_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5150_N/5150_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5043_N/5043_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5043_N/5043_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5053_N/5053_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5053_N/5053_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5118_N/5118_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5118_N/5118_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5030_N/5030_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5030_N/5030_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5123_N/5123_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5123_N/5123_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5068_N/5068_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5068_N/5068_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5102_N/5102_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5102_N/5102_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5049_N/5049_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5049_N/5049_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5100_N/5100_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5100_N/5100_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5032_N/5032_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5032_N/5032_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5121_N/5121_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5121_N/5121_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5009_N/5009_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5009_N/5009_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5060_N/5060_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5060_N/5060_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5097_N/5097_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5097_N/5097_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5022_N/5022_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5022_N/5022_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5003_N/5003_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5003_N/5003_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5111_N/5111_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5111_N/5111_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5040_N/5040_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5040_N/5040_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5096_N/5096_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5096_N/5096_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5039_N/5039_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5039_N/5039_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5086_N/5086_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5086_N/5086_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5071_N/5071_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5071_N/5071_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5143_N/5143_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5143_N/5143_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5008_N/5008_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5008_N/5008_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5033_N/5033_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5033_N/5033_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5101_N/5101_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5101_N/5101_N_Child_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5012_N/5012_N_Parent_fNIRS',
#  '/data/perlman/moochie/analysis/eDOC_NARSAD/NIRS_data_clean/5012_N/5012_N_Child_fNIRS']

# %%
def timeconvert_psychopy_to_nirstar(
    sample_rate,
    NSstim1_t,
    PSstim1_t,
    PSevent_t):
    
    NSevent_t = NSstim1_t + (PSevent_t - PSstim1_t) * sample_rate
    return NSevent_t

# %%
for ses in tqdm(nirs_session_dirs):
    # should always work, even with multiple-runs. 
    # TODO remember that these exist, where 2 runs are collected
    # for the same dyad of parent/child, for unknown reason. 
    # potentially check for truncated run while parsing this data in other
    # mne processing software
    
#     if ("50170_V0_fNIRS" in ses) or ("50171_V0_fNIRS" in ses):
#         pass
#     else:
#         continue
    
    # only do this if there's only 1 .evt file in study folder
    og_evt = glob(ses+"/*.evt")
    if len(og_evt) != 1:
        print("Error: found", len(og_evt), "evt files for the given sub / visit.")
        print("Skipping:", ses)
        continue
    else:
        og_evt = og_evt[0]
    
    # open original evt
    f = open(og_evt, 'r')
    line1 = f.readline()
    f.close()
    
    # first time marker is NIRS stim start 1
    NSstim1_t = line1.split('\t')[0]
    
#     print(ses)
    child_sub = ses.strip(nirs_dir).strip("/")[:participant_num_len]
#     print(child_sub)
    # looks like it's working!
    
    task_file = glob(join(psypy_dir, child_sub+"*")+ "/*.csv")
    
    # only continue if we have exactly 1 task file found
    if len(task_file) != 1:
        print("Error: found", len(task_file), "task files for the given sub / visit.")
        continue
    else:
        task_file = task_file[0]
      
    # df of psychopy csv output
    df = pd.read_csv(task_file)
    
    stims = []
    
    # iterate through any column that has "countdown" and ".started"
    block_i = 0
    for col in df.columns:
        
        # if we're dealing with a legitimate block column
        if ("intro_txt" in col) and (".stopped" in col):

            # then also generate the name of the corresponding stop column
            block_name_str = col.strip("intro_txt").strip(".stopped")
            
            stopcol = "timeup_txt"+block_name_str+".started"
            
            # store any non-NaN vals in the start and stop column (times)
            starts = (df[~df[col].isnull()][col].astype(float) + 5).tolist()
            stops = (df[~df[stopcol].isnull()][stopcol].astype(float)).tolist()
            
            if len(starts) != len(stops):
                print("Unequal number of starts and stops. ses:", ses, "block_i", block_i)
                continue
            
            # if there are no starts already entered / outlines has length 1,
            # then we know that the first start in our starts is the same as line1 trigger. 
            # meaning that is the reference point to which the time course of the psychopy
            # file and the NIRS file will be aligned, again using the sample rate
            # or, easily, if block_i == 1.
            
            # append to stims with tuples of (time, evt_stim_col)
            for i in range(len(starts)):
                stims.append((starts[i], block_i))
                stims.append((stops[i], 7))
            
            # if we're in the first block, we know psychopy stim 1 now
            if block_i == 0:
                PSstim1_t = starts[0]
                stims.pop(0)
            
            # convert using first NIRS stim and first Psychopy stim to align
            converted_stims = []
            for (time, val) in stims:
                converted_stims.append((
                    timeconvert_psychopy_to_nirstar(
                        float(sample_rate),
                        float(NSstim1_t),
                        float(PSstim1_t),
                        float(time)),
                    val))
            
            block_i += 1
        
        # if we're not dealing with a legitimate column, we can just keep iterating
        else:
            continue

    output_lines = [line1]
    
    for (stim_time, stim_col) in converted_stims:
        # make bit format stims
        evts = [0]*8
        evts[stim_col]=1
        
        # and write these as lines in correct format for .evt
        line = str(round(stim_time))
        for evt_col in evts:
            line += "\t"
            line += str(evt_col)
        line += "\n"
            
        output_lines.append(line)
    
    # move OG evt to _old.evt
    shutil.move(
        og_evt,
        og_evt.replace(".evt", "_old.evt"))
    
    # write the lines as the new, properly named .evt
    f = open(join(ses, og_evt), 'w')
    
    for line in output_lines:
        f.write(line)
    
    f.close()
# Out:
# 100%|█████████████████████████████████████████| 154/154 [00:03<00:00, 49.26it/s]
# Error: found 0 task files for the given sub / visit.
# Error: found 0 task files for the given sub / visit.
