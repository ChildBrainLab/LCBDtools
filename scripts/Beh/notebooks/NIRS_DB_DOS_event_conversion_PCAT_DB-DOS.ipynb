# %%
import sys
import os, shutil
from os.path import join
from glob import glob
from tqdm import tqdm
import pandas as pd
import numpy as np

# %%
sys.path.append('../../../..')
from LCBDtools.src import argParser

# %%
os.getcwd()
# Out:
# '/data/perlman/moochie/github/LCBDtools/scripts/Beh/notebooks'

# %%
# parameters
nirs_dir = "/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/"
psypy_dir = "/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/"
ex_subs = []
participant_num_len = 4
sample_rate = 7.81250
n_blocks = 3

# %%
nirs_session_dirs = [os.path.split(d)[0] for d in glob(
    nirs_dir+"**/*_probeInfo.mat",
    recursive=True) \
    if d.strip(nirs_dir).strip("/")[:participant_num_len] not in ex_subs and \
        "DB" in (os.path.basename(os.path.dirname(os.path.dirname(d))))]

# %%
nirs_session_dirs
# Out:
# ['/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1151/1151_DB-DOS/1151-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1151/1151_DB-DOS/1151-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1126/1126_DB-DOS/1126-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1126/1126_DB-DOS/1126-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1114/1114_DB-DOS/1114-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1114/1114_DB-DOS/1114-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1236/1236_DB-DOS/1236-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1236/1236_DB-DOS/1236-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1142/1142_DB-DOS/1142-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1142/1142_DB-DOS/1142-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1148/1148_DB-DOS/1148-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1148/1148_DB-DOS/1148-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1204/1204_DB-DOS/1204-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1204/1204_DB-DOS/1204-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1170/1170_DB-DOS/1170-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1170/1170_DB-DOS/1170-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1209/1209_DB-DOS/1209-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1209/1209_DB-DOS/1209-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1203/1203_DB-DOS/1203-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1203/1203_DB-DOS/1203-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1145/1145_DB-DOS/1145-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1145/1145_DB-DOS/1145-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1138/1138_DB-DOS/1138-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1138/1138_DB-DOS/1138-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1246/1246_DB-DOS/1246-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1246/1246_DB-DOS/1246-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1231/1231_DB-DOS/1231-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1231/1231_DB-DOS/1231-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1119/1119_DB-DOS/1119-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1119/1119_DB-DOS/1119-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1164/1164_DB-DOS/1164-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1164/1164_DB-DOS/1164-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1113/1113_DB-DOS/1113-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1113/1113_DB-DOS/1113-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1267/1267_DB-DOS/1267-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1267/1267_DB-DOS/1267-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1121/1121_DB-DOS/1121-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1121/1121_DB-DOS/1121-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1156/1156_DB-DOS/1156-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1156/1156_DB-DOS/1156-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1222/1222_DB-DOS/1222-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1222/1222_DB-DOS/1222-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1228/1228_DB-DOS/1228-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1228/1228_DB-DOS/1228-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1125/1125_DB-DOS/1125-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1125/1125_DB-DOS/1125-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1251/1251_DB-DOS/1251-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1251/1251_DB-DOS/1251-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1226/1226_DB-DOS/1226-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1226/1226_DB-DOS/1226-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1160/1160_DB-DOS/1160-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1160/1160_DB-DOS/1160-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1117/1117_DB-DOS/1117-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1117/1117_DB-DOS/1117-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1269/1269_DB-DOS/1269-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1269/1269_DB-DOS/1269-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1214/1214_DB-DOS/1214-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1214/1214_DB-DOS/1214-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1141/1141_DB-DOS/1141-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1141/1141_DB-DOS/1141-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1242/1242_DB-DOS/1242-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1242/1242_DB-DOS/1242-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1235/1235_DB-DOS/1235-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1235/1235_DB-DOS/1235-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1207/1207_DB-DOS/1207-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1207/1207_DB-DOS/1207-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1270/1270_DB-DOS/1270-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1270/1270_DB-DOS/1270-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1200/1200_DB-DOS/1200-C_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1200/1200_DB-DOS/1200-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1238/1238_DB-DOS/1238-P_fNIRS_DB-DOS',
#  '/data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/
/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1268/1268_DB-DOS/1268-C_fNIRS_DB-DOS']

# %%
len(nirs_session_dirs)
# Out:
# 161

# %%
def timeconvert_psychopy_to_nirstar(
    sample_rate,
    NSstim1_t,
    PSstim1_t,
    PSevent_t):
    
    NSevent_t = NSstim1_t + (PSevent_t - PSstim1_t) * sample_rate
    return NSevent_t

# %%
for ses in tqdm(nirs_session_dirs):
    # should always work, even with multiple-runs. 
    # TODO remember that these exist, where 2 runs are collected
    # for the same dyad of parent/child, for unknown reason. 
    # potentially check for truncated run while parsing this data in other
    # mne processing software
    
#     if ("50170_V0_fNIRS" in ses) or ("50171_V0_fNIRS" in ses):
#         pass
#     else:
#         continue
    
    # only do this if there's only 1 .evt file in study folder
    og_evt = glob(ses+"/*.evt")
    if len(og_evt) != 1:
        print("Error: found", len(og_evt), "evt files for the given sub / visit.")
        print("Skipping:", ses)
        continue
    else:
        og_evt = og_evt[0]
    
    # open original evt
    f = open(og_evt, 'r')
    line1 = f.readline()
    f.close()
    
    # first time marker is NIRS stim start 1
    NSstim1_t = line1.split('\t')[0]
    
#     print(ses)
    child_sub = ses.strip(nirs_dir).strip("/")[:participant_num_len]
#     print(child_sub)
    visit_ID = ses.strip(nirs_dir).strip("/")[participant_num_len+1:participant_num_len+3]
#     print(visit_ID)
    # looks like it's working!
    
    task_file = glob(ses + "/*.csv")
    
    # only continue if we have exactly 1 task file found
    if len(task_file) != 1:
        print("Error: found", len(task_file), "task files for ",child_sub ,".")
        continue
    else:
        task_file = task_file[0]
      
    # df of psychopy csv output
    df = pd.read_csv(task_file)
    
    stims = []
    
    # iterate through any column that has "countdown" and ".started"
    block_i = 0
    for col in df.columns:
        
        # if we're dealing with a legitimate block column
        if ("intro_txt" in col) and (".stopped" in col):

            # then also generate the name of the corresponding stop column
            block_name_str = col.strip("intro_txt").strip(".stopped")
            
            stopcol = "timeup_txt"+block_name_str+".started"
            
            # store any non-NaN vals in the start and stop column (times)
            starts = (df[~df[col].isnull()][col].astype(float) + 5).tolist()
            stops = (df[~df[stopcol].isnull()][stopcol].astype(float)).tolist()
            
            if len(starts) != len(stops):
                print("Unequal number of starts and stops. ses:", ses, "block_i", block_i)
                continue
            
            # if there are no starts already entered / outlines has length 1,
            # then we know that the first start in our starts is the same as line1 trigger. 
            # meaning that is the reference point to which the time course of the psychopy
            # file and the NIRS file will be aligned, again using the sample rate
            # or, easily, if block_i == 1.
            
            # append to stims with tuples of (time, evt_stim_col)
            for i in range(len(starts)):
                stims.append((starts[i], block_i))
                stims.append((stops[i], 7))
            
            # if we're in the first block, we know psychopy stim 1 now
            if block_i == 0:
                PSstim1_t = starts[0]
                stims.pop(0)
            
            # convert using first NIRS stim and first Psychopy stim to align
            converted_stims = []
            for (time, val) in stims:
                converted_stims.append((
                    timeconvert_psychopy_to_nirstar(
                        float(sample_rate),
                        float(NSstim1_t),
                        float(PSstim1_t),
                        float(time)),
                    val))
            
            block_i += 1
        
        # if we're not dealing with a legitimate column, we can just keep iterating
        else:
            continue

    output_lines = [line1]
    
    for (stim_time, stim_col) in converted_stims:
        # make bit format stims
        evts = [0]*8
        evts[stim_col]=1
        
        # and write these as lines in correct format for .evt
        line = str(round(stim_time))
        for evt_col in evts:
            line += "\t"
            line += str(evt_col)
        line += "\n"
            
        output_lines.append(line)
    
    # move OG evt to _old.evt
    shutil.move(
        og_evt,
        og_evt.replace(".evt", "_old.evt"))
    
    # write the lines as the new, properly named .evt
    f = open(join(ses, og_evt), 'w')
    
    for line in output_lines:
        f.write(line)
    
    f.close()
# Out:
# 100%|███████████████████████████████████████| 161/161 [00:00<00:00, 3546.99it/s]
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1151/1151_DB-DOS/1151-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1151/1151_DB-DOS/1151-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1126/1126_DB-DOS/1126-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1126/1126_DB-DOS/1126-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1114/1114_DB-DOS/1114-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1114/1114_DB-DOS/1114-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1236/1236_DB-DOS/1236-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1236/1236_DB-DOS/1236-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1142/1142_DB-DOS/1142-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1142/1142_DB-DOS/1142-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1148/1148_DB-DOS/1148-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1148/1148_DB-DOS/1148-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1204/1204_DB-DOS/1204-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1204/1204_DB-DOS/1204-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1170/1170_DB-DOS/1170-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1170/1170_DB-DOS/1170-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1209/1209_DB-DOS/1209-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1209/1209_DB-DOS/1209-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1203/1203_DB-DOS/1203-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1203/1203_DB-DOS/1203-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1145/1145_DB-DOS/1145-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1145/1145_DB-DOS/1145-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1138/1138_DB-DOS/1138-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1138/1138_DB-DOS/1138-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1246/1246_DB-DOS/1246-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1246/1246_DB-DOS/1246-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1231/1231_DB-DOS/1231-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1231/1231_DB-DOS/1231-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1119/1119_DB-DOS/1119-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1119/1119_DB-DOS/1119-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1164/1164_DB-DOS/1164-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1164/1164_DB-DOS/1164-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1113/1113_DB-DOS/1113-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1113/1113_DB-DOS/1113-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1267/1267_DB-DOS/1267-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1267/1267_DB-DOS/1267-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1121/1121_DB-DOS/1121-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1121/1121_DB-DOS/1121-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1156/1156_DB-DOS/1156-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1156/1156_DB-DOS/1156-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1222/1222_DB-DOS/1222-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1222/1222_DB-DOS/1222-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1228/1228_DB-DOS/1228-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1228/1228_DB-DOS/1228-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1125/1125_DB-DOS/1125-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1125/1125_DB-DOS/1125-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1251/1251_DB-DOS/1251-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1251/1251_DB-DOS/1251-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1226/1226_DB-DOS/1226-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1226/1226_DB-DOS/1226-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1160/1160_DB-DOS/1160-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1160/1160_DB-DOS/1160-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1117/1117_DB-DOS/1117-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1117/1117_DB-DOS/1117-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1269/1269_DB-DOS/1269-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1269/1269_DB-DOS/1269-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1214/1214_DB-DOS/1214-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1214/1214_DB-DOS/1214-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1141/1141_DB-DOS/1141-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1141/1141_DB-DOS/1141-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1242/1242_DB-DOS/1242-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1242/1242_DB-DOS/1242-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1235/1235_DB-DOS/1235-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1235/1235_DB-DOS/1235-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1207/1207_DB-DOS/1207-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1207/1207_DB-DOS/1207-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1270/1270_DB-DOS/1270-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1270/1270_DB-DOS/1270-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1200/1200_DB-DOS/1200-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1200/1200_DB-DOS/1200-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1238/1238_DB-DOS/1238-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1238/1238_DB-DOS/1238-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1146/1146_DB-DOS/1146-C_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1146/1146_DB-DOS/1146-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/1131/1131_DB-DOS/1131-P_fNIRS_DB-DOS
# Error: found 2 evt files for the given sub / visit.
# Skipping: /data/perlman/moochie/analysis/P-CAT/NIRS_Data_Clean_WU_PSU/