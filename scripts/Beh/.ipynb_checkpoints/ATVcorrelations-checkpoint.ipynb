# %%
# General dependencies
import os, shutil
from os.path import join
from tqdm import tqdm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from copy import deepcopy

# %%
# LCBD dependencies
# add relative path to our toolbox
import sys
sys.path.append('../../..') # path to preprocessing from here

from preprocessing.scripts import argParser
from preprocessing.src import Plots
from preprocessing.src import Statistics
from preprocessing.src import TimeSeries
from preprocessing.Stimuli.FreeViewing.ATV import TrialReader

# %%
# Some configuration variables
dataDir = "/data/perlman/moochie/user_data/SchneiderClayton/studyData/ATV_LCBD_copy_120821/data_clean"
# episode = 1 # which episode number (1-3) we are dealing with
TR = 0.8 # this is because we'll want to have it sampled at the TR for later (s)
min_episode_samples = 1000 # some recordings are shorter than others, and we don't want to include them...
ex_subs = ['102'] # any subjects to not include in the dataset
participant_num_len = 3 # default length of participant numbers

# %%
participant_keyring = {
	"104": ("Amanda", "BCA"),
	"100": ("Shelby", "ABC"),
	"103": ("Emily", "CAB"),
	"105": ("Sarah", "BCA"),
	"106": ("Shreeja", "CAB"),
	"101": ("Alcess", "BCA"),
	"107": ("Emma", "BAC"),
	"108": ("Clayton", "BCA"),
	"109": ("Nikhil", "ACB"),
	"110": ("Ruchika", "ABC"),
	"111": ("Justin", "BAC"),
	"112": ("Sishir", "BCA"),
	"113": ("Kaitlyn", "ABC"),
	"102": ("Natalia", "CBA"),
	"114": ("Ethan", "BCA"),
	"115": ("Jackie", "ACB"),
	"116": ("Susan", "BAC"),
    "117": ("Susan", "ACB")
}

# %%
# build a list of all the applicable ATV data files
fnames = [join(dataDir, fname) for fname in os.listdir(dataDir)\
    if os.path.basename(fname)[:participant_num_len] not in ex_subs]

dataset = []
print("Loading ATV files as TimeSeries objects:")
print("==========")
for fpath in tqdm(fnames):
    try:
        # for each filepath in the list, run an ATV.TrialReader builder
        # add each src.TimeSeries object generated from the TrialReader to
        # the dataset list
        for ts in TrialReader(fpath).ratingsSeries:
            dataset.append(ts)
    except:
        print("Failure to read:", os.path.basename(fpath))
        pass
# Out:
# Loading ATV files as TimeSeries objects:
# ==========
# 100%|██████████| 18/18 [00:33<00:00,  1.88s/it]

# %%
for ts in dataset:
    if participant_keyring[ts.meta['participant']][0] == "Susan":
        print(ts.meta)
# Out:
# {'participant': '116', 'episode': 1, 'viewingOrder': 'BAC'}
# {'participant': '117', 'episode': 0, 'viewingOrder': 'ACB'}
# {'participant': '117', 'episode': 2, 'viewingOrder': 'ACB'}
# {'participant': '117', 'episode': 1, 'viewingOrder': 'ACB'}

# %%
# manual adjustment because Susan watched in 2 trials
# 1st was 116 watching B
# 2nd was 117 watching AC
# just make both into 116
for i, ts in enumerate(dataset):
    if ts.meta['participant'] == '117':
        if ts.meta['episode'] == 1:
            dataset.pop(i)
            print("pop")
# Out:
# pop

# %%
print("Preprocessing TimeSeries:")
print("==========")
for ts in tqdm(dataset):
    # correct NaN values
    ts.fix_nan()
    # accommodate for skippy framerates
    ts.lag_correct()
    # center timeseries?
    ts.center()
    
    # sample to TR
    ts.resample(sample_rate=0.8)
    # chunking
    # ts.signal = ts.round_res()
# Out:
# Preprocessing TimeSeries:
# ==========
# 100%|██████████| 49/49 [00:08<00:00,  5.49it/s]

# %%
print("Inspecting Lengths of Ratings in Each Episode:")
print("==========")
episodes = []

for episode in tqdm(list(set([int(ts.meta['episode']) for ts in dataset]))):
    episodes.append(episode)
    plt.hist(
        [ts.time[-1] for ts in dataset\
        if ts.meta['episode']==episode],
        alpha=0.5,
        label="Episode "+str(episode))
    
plt.xlim(0, 2000)
plt.title("distribution of episode lengths")
plt.legend()
# Out:
# Inspecting Lengths of Ratings in Each Episode:
# ==========
# 100%|██████████| 3/3 [00:00<00:00, 82.25it/s]

# %%
for episode in tqdm(list(set([int(ts.meta['episode']) for ts in dataset]))):
    for ts in [ts for ts in dataset \
        if ts.meta['episode']==episode]:
        print(
            "episode:",
            ts.meta['episode'],
            "\t",
            "participant ID:",
            ts.meta['participant'],
            "\t",
            "participant name:",
            participant_keyring[ts.meta['participant']][0],
            "\t",
            "length:",
            len(ts.signal))
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 234.79it/s]
# episode: 0 	 participant ID: 101 	 participant name: Alcess 	 length: 1091
# episode: 0 	 participant ID: 104 	 participant name: Amanda 	 length: 1091
# episode: 0 	 participant ID: 115 	 participant name: Jackie 	 length: 1091
# episode: 0 	 participant ID: 112 	 participant name: Sishir 	 length: 1091
# episode: 0 	 participant ID: 110 	 participant name: Ruchika 	 length: 1091
# episode: 0 	 participant ID: 106 	 participant name: Shreeja 	 length: 1091
# episode: 0 	 participant ID: 103 	 participant name: Emily 	 length: 1091
# episode: 0 	 participant ID: 114 	 participant name: Ethan 	 length: 1091
# episode: 0 	 participant ID: 108 	 participant name: Clayton 	 length: 1091
# episode: 0 	 participant ID: 113 	 participant name: Kaitlyn 	 length: 1091
# episode: 0 	 participant ID: 100 	 participant name: Shelby 	 length: 1091
# episode: 0 	 participant ID: 105 	 participant name: Sarah 	 length: 1091
# episode: 0 	 participant ID: 117 	 participant name: Susan 	 length: 1091
# episode: 0 	 participant ID: 111 	 participant name: Justin 	 length: 1091
# episode: 0 	 participant ID: 107 	 participant name: Emma 	 length: 1091
# episode: 0 	 participant ID: 109 	 participant name: Nikhil 	 length: 1091
# episode: 0 	 participant ID: 106 	 participant name: Shreeja 	 length: 9
# episode: 1 	 participant ID: 101 	 participant name: Alcess 	 length: 1026
# episode: 1 	 participant ID: 104 	 participant name: Amanda 	 length: 1027
# episode: 1 	 participant ID: 115 	 participant name: Jackie 	 length: 1026
# episode: 1 	 participant ID: 112 	 participant name: Sishir 	 length: 1027
# episode: 1 	 participant ID: 110 	 participant name: Ruchika 	 length: 1026
# episode: 1 	 participant ID: 106 	 participant name: Shreeja 	 length: 1026
# episode: 1 	 participant ID: 103 	 participant name: Emily 	 length: 1026
# episode: 1 	 participant ID: 114 	 participant name: Ethan 	 length: 1026
# episode: 1 	 participant ID: 108 	 participant name: Clayton 	 length: 1026
# episode: 1 	 participant ID: 116 	 participant name: Susan 	 length: 1027
# episode: 1 	 participant ID: 113 	 participant name: Kaitlyn 	 length: 1026
# episode: 1 	 participant ID: 100 	 participant name: Shelby 	 length: 1026
# episode: 1 	 participant ID: 105 	 participant name: Sarah 	 length: 1026
# episode: 1 	 participant ID: 111 	 participant name: Justin 	 length: 1026
# episode: 1 	 participant ID: 107 	 participant name: Emma 	 length: 1026
# episode: 1 	 participant ID: 109 	 participant name: Nikhil 	 length: 1026
# episode: 2 	 participant ID: 101 	 participant name: Alcess 	 length: 1057
# episode: 2 	 participant ID: 104 	 participant name: Amanda 	 length: 1057
# episode: 2 	 participant ID: 115 	 participant name: Jackie 	 length: 1057
# episode: 2 	 participant ID: 112 	 participant name: Sishir 	 length: 1057
# episode: 2 	 participant ID: 110 	 participant name: Ruchika 	 length: 1057
# episode: 2 	 participant ID: 103 	 participant name: Emily 	 length: 1057
# episode: 2 	 participant ID: 114 	 participant name: Ethan 	 length: 1057
# episode: 2 	 participant ID: 108 	 participant name: Clayton 	 length: 1057
# episode: 2 	 participant ID: 113 	 participant name: Kaitlyn 	 length: 1057
# episode: 2 	 participant ID: 100 	 participant name: Shelby 	 length: 1057
# episode: 2 	 participant ID: 105 	 participant name: Sarah 	 length: 1057
# episode: 2 	 participant ID: 117 	 participant name: Susan 	 length: 1057
# episode: 2 	 participant ID: 111 	 participant name: Justin 	 length: 1057
# episode: 2 	 participant ID: 107 	 participant name: Emma 	 length: 1057
# episode: 2 	 participant ID: 109 	 participant name: Nikhil 	 length: 1057
# episode: 2 	 participant ID: 106 	 participant name: Shreeja 	 length: 1057

# %%
print(episodes)
# Out:
# [0, 1, 2]

# %%
print("Gold Standard ATV Rating:")
print("==========")

gold_standard = "Susan"

gold = [ts for ts in dataset \
    if participant_keyring[ts.meta['participant']][0] == gold_standard ]

for ts in gold:
    Plots.plot_xy_line(
        ts.time,
        ts.signal,
        ylabel="Rating of Emotion: -1 to 1 (Negative to Positive)",
        plot_axis=np.zeros(round(ts.time[-1])),
        title="Episode "+str(ts.meta['episode']))
# Out:
# Gold Standard ATV Rating:
# ==========

# %%
print("Inspecting Lengths of Ratings in Each Episode After Dropping:")
print("==========")

dataset = [ts for ts in dataset if ts.time[-1] > 1000]

for episode in episodes:
    
    plt.hist([ts.time[-1] for ts in dataset\
        if ts.meta['episode']==episode],
        alpha=0.5,
        label="Episode: "+str(episode))
plt.legend()
# Out:
# Inspecting Lengths of Ratings in Each Episode After Dropping:
# ==========

# %%
for episode in tqdm(list(set([ts.meta['episode'] for ts in dataset]))):
    for ts in [ts for ts in dataset \
        if ts.meta['episode']==episode]:
        print(
            "episode:",
            ts.meta['episode'],
            "\t",
            "participant ID:",
            ts.meta['participant'],
            "\t",
            "participant name:",
            participant_keyring[ts.meta['participant']][0],
            "\t",
            "length:",
            len(ts.signal))
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 492.23it/s]
# episode: 0 	 participant ID: 101 	 participant name: Alcess 	 length: 1091
# episode: 0 	 participant ID: 104 	 participant name: Amanda 	 length: 1091
# episode: 0 	 participant ID: 115 	 participant name: Jackie 	 length: 1091
# episode: 0 	 participant ID: 112 	 participant name: Sishir 	 length: 1091
# episode: 0 	 participant ID: 110 	 participant name: Ruchika 	 length: 1091
# episode: 0 	 participant ID: 106 	 participant name: Shreeja 	 length: 1091
# episode: 0 	 participant ID: 103 	 participant name: Emily 	 length: 1091
# episode: 0 	 participant ID: 114 	 participant name: Ethan 	 length: 1091
# episode: 0 	 participant ID: 108 	 participant name: Clayton 	 length: 1091
# episode: 0 	 participant ID: 113 	 participant name: Kaitlyn 	 length: 1091
# episode: 0 	 participant ID: 100 	 participant name: Shelby 	 length: 1091
# episode: 0 	 participant ID: 105 	 participant name: Sarah 	 length: 1091
# episode: 0 	 participant ID: 117 	 participant name: Susan 	 length: 1091
# episode: 0 	 participant ID: 111 	 participant name: Justin 	 length: 1091
# episode: 0 	 participant ID: 107 	 participant name: Emma 	 length: 1091
# episode: 0 	 participant ID: 109 	 participant name: Nikhil 	 length: 1091
# episode: 1 	 participant ID: 101 	 participant name: Alcess 	 length: 1026
# episode: 1 	 participant ID: 104 	 participant name: Amanda 	 length: 1027
# episode: 1 	 participant ID: 115 	 participant name: Jackie 	 length: 1026
# episode: 1 	 participant ID: 112 	 participant name: Sishir 	 length: 1027
# episode: 1 	 participant ID: 110 	 participant name: Ruchika 	 length: 1026
# episode: 1 	 participant ID: 106 	 participant name: Shreeja 	 length: 1026
# episode: 1 	 participant ID: 103 	 participant name: Emily 	 length: 1026
# episode: 1 	 participant ID: 114 	 participant name: Ethan 	 length: 1026
# episode: 1 	 participant ID: 108 	 participant name: Clayton 	 length: 1026
# episode: 1 	 participant ID: 116 	 participant name: Susan 	 length: 1027
# episode: 1 	 participant ID: 113 	 participant name: Kaitlyn 	 length: 1026
# episode: 1 	 participant ID: 100 	 participant name: Shelby 	 length: 1026
# episode: 1 	 participant ID: 105 	 participant name: Sarah 	 length: 1026
# episode: 1 	 participant ID: 111 	 participant name: Justin 	 length: 1026
# episode: 1 	 participant ID: 107 	 participant name: Emma 	 length: 1026
# episode: 1 	 participant ID: 109 	 participant name: Nikhil 	 length: 1026
# episode: 2 	 participant ID: 101 	 participant name: Alcess 	 length: 1057
# episode: 2 	 participant ID: 104 	 participant name: Amanda 	 length: 1057
# episode: 2 	 participant ID: 115 	 participant name: Jackie 	 length: 1057
# episode: 2 	 participant ID: 112 	 participant name: Sishir 	 length: 1057
# episode: 2 	 participant ID: 110 	 participant name: Ruchika 	 length: 1057
# episode: 2 	 participant ID: 103 	 participant name: Emily 	 length: 1057
# episode: 2 	 participant ID: 114 	 participant name: Ethan 	 length: 1057
# episode: 2 	 participant ID: 108 	 participant name: Clayton 	 length: 1057
# episode: 2 	 participant ID: 113 	 participant name: Kaitlyn 	 length: 1057
# episode: 2 	 participant ID: 100 	 participant name: Shelby 	 length: 1057
# episode: 2 	 participant ID: 105 	 participant name: Sarah 	 length: 1057
# episode: 2 	 participant ID: 117 	 participant name: Susan 	 length: 1057
# episode: 2 	 participant ID: 111 	 participant name: Justin 	 length: 1057
# episode: 2 	 participant ID: 107 	 participant name: Emma 	 length: 1057
# episode: 2 	 participant ID: 109 	 participant name: Nikhil 	 length: 1057
# episode: 2 	 participant ID: 106 	 participant name: Shreeja 	 length: 1057

# %%
print("Matching Lengths and Discretizing the Dataset By Episode with Averages of Each:")
print("==========")

episodes = []
d_dataset = {}
d_avgs = {}
# truncate each batch of runs with the same episode to the length of the
# shortest trial in the batch
for episode in tqdm(list(set([ts.meta['episode'] for ts in dataset]))):
    episodes.append(episode)
    ep_min = min([len(ts.signal) for ts in dataset\
        if ts.meta['episode']==episode and ts.time[-1] > min_episode_samples])

    # here is the trimming portion
    for ts in [ts for ts in dataset if ts.meta['episode']==episode]:
        ts.signal = ts.signal[:ep_min]
        ts.time = ts.time[:ep_min]
        
    # discretize the dataset to a dict with entry for each episode
    d_dataset[episode] = [ts for ts in dataset if ts.meta['episode'] == episode]
    # make averages (discretized) of each episode's runs (same struc as d_dataset)
    d_avgs[episode] = TimeSeries.TimeSeries(
        signal=np.average(np.array([ts.signal for ts in d_dataset[episode]]), axis=0),
        time=ts.time,
        meta={
            'participant': 'AVG',
            'episode': episode})
# Out:
# Matching Lengths and Discretizing the Dataset By Episode with Averages of Each:
# ==========
# 100%|██████████| 3/3 [00:00<00:00, 3435.14it/s]

# %%
for episode in episodes:
    plt.hist(
        [len(ts.signal) for ts in d_dataset[episode]],
        label="Episode "+str(episode))
plt.legend()

# %%
# just view the structure of this object
print(d_dataset)
print(d_avgs)
# Out:
# {0: [<preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a18d0>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e1913a10>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a3690>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e1913d90>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a3550>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a1a50>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e1913a50>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a1490>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a3f90>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a13d0>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a3490>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a1cd0>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a33d0>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a1f10>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18be690>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a1b50>], 1: [<preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a1d90>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e1913410>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a3ad0>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e1913fd0>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a3510>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a1f50>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e1913090>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a1310>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a3810>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a3cd0>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a1950>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a3590>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a1090>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a14d0>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18be610>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a1810>], 2: [<preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a1b90>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e1913710>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a35d0>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e1913490>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a34d0>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e1913750>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a1c10>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a3b10>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a1a90>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a3890>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a12d0>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a3f50>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53ee081a90>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18bed90>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e18a1d10>, <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53e1913850>]}
# {0: <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53da0e0d90>, 1: <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53dc8a9810>, 2: <preprocessing.src.TimeSeries.TimeSeries object at 0x7f53da0d6890>}

# %%
for episode in episodes:
    for ts in d_dataset[episode]:
        plt.plot(ts.signal[20:80])

# %%
plt.scatter(
    d_dataset[0][0].signal,
    d_dataset[0][1].signal,
    alpha=0.2)

# %%
plt.scatter(
    d_dataset[0][0].signal,
    d_avgs[0].signal,
    alpha=0.2)

# %%
d_dataset[0][0].__dict__
# Out:
# {'signal': array([0., 0., 0., ..., 1., 1., 1.]),
#  'time': array([0.00000000e+00, 1.25137615e+00, 2.50275229e+00, ...,
#         1.36149725e+03, 1.36274862e+03, 1.36400000e+03]),
#  'sampleRate': 0.8,
#  'meta': {'participant': '101', 'episode': 0, 'viewingOrder': 'BCA'},
#  'unit': 's'}

# %%
Statistics.ping_icc([
    d_dataset[0][0],
    d_dataset[0][1]])
# Out:
#     Type              Description       ICC         F   df1   df2  \
# 0   ICC1   Single raters absolute  0.534063  3.292423  1090  1091
# 1   ICC2     Single random raters  0.534215  3.297063  1090  1090
# 2   ICC3      Single fixed raters  0.534566  3.297063  1090  1090
# 3  ICC1k  Average raters absolute  0.696272  3.292423  1090  1091
# 4  ICC2k    Average random raters  0.696402  3.297063  1090  1090
# 5  ICC3k     Average fixed raters  0.696700  3.297063  1090  1090
#
#            pval         CI95%
# 0  6.705246e-82  [0.49, 0.58]
# 1  4.988444e-82  [0.49, 0.58]
# 2  4.988444e-82  [0.49, 0.58]
# 3  6.705246e-82  [0.66, 0.73]
# 4  4.988444e-82  [0.66, 0.73]
# 5  4.988444e-82  [0.66, 0.73]

# %%
plt.plot(d_dataset[0][0].time, d_dataset[0][0].signal)
plt.plot(d_dataset[0][1].time, d_dataset[0][1].signal)

# %%
# initialize empty array for icc values (one per timepoint)
icc_dfs = {}
icc_vals = {}

for episode in episodes:
    
    # labels are all participants for episode + 'avg'
    xticklabels = list(set([ts.meta['participant'] for ts in d_dataset[episode]]))
    xticklabels.append('avg')
    yticklabels = deepcopy(xticklabels)
    
    df = pd.DataFrame(
        columns=xticklabels,
        index=yticklabels)
    
    
    for j, row in enumerate(df.index):
        for i, col in enumerate(df.columns):
        
            # case that we are in upper-right triangle of matrix
            if i > j:
                # grab ts1
                if col == 'avg':
                    ts1 = d_avgs[episode]
                else:
                    # the index of the dataset where the participant is col
                    ts1 = d_dataset[episode][[ts.meta['participant'] for ts in d_dataset[episode]].index(col)]
                    
                # grab ts2
                if row == 'avg':
                    ts2 = d_avgs[episode]
                else:
                    # the index of the dataset where the participant is row
                    ts2 = d_dataset[episode][[ts.meta['participant'] for ts in d_dataset[episode]].index(row)]

                try:
                    # compute ICC between ts1 and ts2
                    icc = Statistics.ping_icc([ts1, ts2])

                    df.iat[j, i] = icc.iat[0,2]
                    
                    # if significance
                    # if icc.iat[0, 6] < 0.05:
                        # df.iat[j, i] = df.iat[j, i]+"*"
                    
                except:
                    df.iat[j, i] = 0
                    print("Err @ row ", j, "col", i)
                    
            # case we are on diagonal
            elif i == j:
                df.iat[j, i] = 1
                
            # case that we are in bottom-left triangle of matrix
            else:
                df.iat[j, i] = df.iat[i, j]
            
    icc_dfs[episode] = df
    
    # do icc for whole set of them (not including average)
    icc = Statistics.ping_icc(d_dataset[episode])
    icc_vals[episode] = icc.iat[0,2].round(2)
# Out:
# Err @ row  0 col 8
# Err @ row  0 col 9
# Err @ row  0 col 10
# Err @ row  1 col 8
# Err @ row  1 col 9
# Err @ row  1 col 10
# Err @ row  2 col 8
# Err @ row  2 col 9
# Err @ row  2 col 10
# Err @ row  3 col 8
# Err @ row  3 col 9
# Err @ row  3 col 10
# Err @ row  4 col 8
# Err @ row  4 col 9
# Err @ row  4 col 10
# Err @ row  5 col 8
# Err @ row  5 col 9
# Err @ row  5 col 10
# Err @ row  6 col 8
# Err @ row  6 col 9
# Err @ row  6 col 10
# Err @ row  7 col 8
# Err @ row  7 col 9
# Err @ row  7 col 10
# Err @ row  8 col 9
# Err @ row  8 col 10
# Err @ row  8 col 11
# Err @ row  8 col 12
# Err @ row  8 col 13
# Err @ row  8 col 14
# Err @ row  8 col 15
# Err @ row  8 col 16
# Err @ row  9 col 11
# Err @ row  9 col 12
# Err @ row  9 col 13
# Err @ row  9 col 14
# Err @ row  9 col 15
# Err @ row  9 col 16
# Err @ row  10 col 11
# Err @ row  10 col 12
# Err @ row  10 col 13
# Err @ row  10 col 14
# Err @ row  10 col 15
# Err @ row  10 col 16
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-579f40aedaa9> in <module>
#      59
#      60     # do icc for whole set of them (not including average)
# ---> 61     icc = Statistics.ping_icc(d_dataset[episode])
#      62     icc_vals[episode] = icc.iat[0,2].round(2)
#
# /data/perlman/moochie/github/preprocessing/src/Statistics.py in ping_icc(dX, icc_type)
#      96         targets='time',
#      97         raters='participant',
# ---> 98         ratings='rating',
#      99 #         nan_policy='omit'
#     100     )
#
# ~/.local/lib/python3.7/site-packages/pingouin/reliability.py in intraclass_corr(data, targets, raters, ratings, nan_policy)
#     274             data = data.dropna(axis=0, how='any')
#     275         else:
# --> 276             raise ValueError("Either missing values are present in data or "
#     277                              "data are unbalanced. Please remove them "
#     278                              "manually or use nan_policy='omit'.")
#
# ValueError: Either missing values are present in data or data are unbalanced. Please remove them manually or use nan_policy='omit'.

# %%
icc_dfs[0]

# %%
cmatrix = np.array(icc_dfs[0]).astype(float)

# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 100

# %%
plot_episode = 1

ax = sns.heatmap(
    cmatrix,
    annot=True,
    xticklabels=[str(col) for col in icc_dfs[plot_episode].columns],
    yticklabels=[str(ind) for ind in icc_dfs[plot_episode].index],
#     cmap=sns.diverging_palette(20, 220, n=200),
    cmap="BuGn",
    linewidths=1,
    square=True,
    vmin=0,
    vmax=1)

ax.set_title("ICC(1) of Episode {}: {}".format(plot_episode, icc_vals[plot_episode]))
ax.xaxis.tick_top() # x axis on top
ax.xaxis.set_label_position('top')

# ax.set_xticklabels(
#     [str(col) for col in iccs[0].columns],
#     rotation=45,
#     horizontalalignment='right')

# %%
total_len = 0

for episode in episodes:
    total_len += list(set([len(ts.signal) for ts in d_dataset[episode]]))[0]
    
print("Ideal concatenated length:", total_len, "samples.")
# Out:
# Ideal concatenated length: 3174 samples.

# %%
# concat each episode to each other ep for that participant?

c_dataset = {}

for i, episode in enumerate(episodes):
    
    for ts in d_dataset[episode]:
        if participant_keyring[ts.meta['participant']][0] not in c_dataset:
            c_dataset[participant_keyring[ts.meta['participant']][0]] = ts.signal
        else:
            c_dataset[participant_keyring[ts.meta['participant']][0]] = np.concatenate((
                c_dataset[participant_keyring[ts.meta['participant']][0]],
                ts.signal))

# %%
len(c_dataset)
# Out:
# 16

# %%
# only get those who have all 3 episodes

c_dataset = {
    sub: c_dataset[sub] for sub in c_dataset.keys() if len(c_dataset[sub]) == total_len}

# %%
# appears to be all of them here. great
len(c_dataset)
# Out:
# 16

# %%
iccs = []

for sub in c_dataset.keys():
    if sub is not "Susan":
        print(sub)
        iccs.append(Statistics.ping_icc([ts1, ts2]))

# %%
from scipy.signal import savgol_filter

# %%
y_filtered = savgol_filter(
    c_dataset['Susan'],
    window_length=13,
    polyorder=3
)

# %%
plt.plot(y_filtered, label='smooth')
plt.plot(c_dataset['Susan'], label='Susan')
plt.legend()

# %%
f = open("/data/perlman/moochie/analysis/CARE/AHKJ_rating.txt", 'w')

for i, val in enumerate(y_filtered):
    if i > 0:
        f.write('\n')
    f.write(str(val))
    
f.close()
