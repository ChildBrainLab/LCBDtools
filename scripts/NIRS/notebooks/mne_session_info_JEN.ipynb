# %%
# General dependencies
import os, shutil
from os.path import join
from tqdm import tqdm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from copy import deepcopy
from glob import glob

import mne
import mne_nirs

# %%
plt.rcParams["figure.figsize"] = (10, 6)

# %%
# LCBD dependencies
# add relative path to our toolbox
import sys
sys.path.append('../../../..')
from preprocessing.scripts import argParser
from preprocessing.src import Plots

# %%
# Some configuration variables
study_dir = "/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data"
participant_num_len = 4 # default length of participant numbers
ex_subs = [
    '7021',
    '7017',
    '7023',
    '7030',
    '7039',
    '7043'
] # any subjects to not include in the dataset

visit = 'V1'

# %%
# session_dirs = [d for d in glob(study_dir+"/*/V*/*/*") \
#     if os.path.basename(os.path.split(os.path.split(d)[1])[1]) not in ex_subs]
session_dirs = [d for d in glob(study_dir+"/"+visit+"/*/*/*") \
    if "Subject" in os.path.basename(d)]

# session_dirs = [ses for ses in session_dirs if\
#     "V1" in os.listdir(join(study_dir, ses.strip(study_dir).split('/')[0])) and\
#     "V2" in os.listdir(join(study_dir, ses.strip(study_dir).split('/')[0]))]

subjects = list(set([os.path.basename(d)[:participant_num_len] for d in session_dirs]))

# %%
session_dirs
# Out:
# ['/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7034/2020-02-11_001/Subject2',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7034/2020-02-11_001/Subject1',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7043/2020-03-12_002/Subject2',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7043/2020-03-12_002/Subject1',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7043/2020-03-12_001/Subject1',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7043/2020-03-12_001/Subject2',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7027/2019-12-16_001/Subject2',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7027/2019-12-16_001/Subject1',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7039/2020-03-05_001/Subject2',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7039/2020-03-05_001/Subject1',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7033/2020-02-03_001/Subject2',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7033/2020-02-03_001/Subject1',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7040/2020-03-04_001/Subject2',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7040/2020-03-04_001/Subject1',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7024/2019-12-11_003/Subject2',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7024/2019-12-11_003/Subject1',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7029/2020-01-25_001/Subject2',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7029/2020-01-25_001/Subject1',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7023/2019-12-02_002/Subject1',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7023/2019-12-02_002/Subject2',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7023/2019-12-02_001/Subject1',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7023/2019-12-02_001/Subject2',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7030/2020-01-29_001/Subject1',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7030/2020-01-29_001/Subject2',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7038/2020-03-05_002/Subject2',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7038/2020-03-05_002/Subject1',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7021/2019-11-23_003/Subject1',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7021/2019-11-23_003/Subject2',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7026/2019-12-11_004/Subject1',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7026/2019-12-11_004/Subject2',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7042/2020-03-10_004/Subject1',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7042/2020-03-10_004/Subject2',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7035/2020-02-19_001/Subject1',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7035/2020-02-19_001/Subject2',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7031/2020-01-16_001/Subject2',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7031/2020-01-16_001/Subject1',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7022/2020-01-23_001/Subject1',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7022/2020-01-23_001/Subject2',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7017/2019-11-22_001/Subject2',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7017/2019-11-22_001/Subject1',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7025/2019-12-17_001/Subject1',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7025/2019-12-17_001/Subject2',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7036/2020-02-20_001/Subject2',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7036/2020-02-20_001/Subject1',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7041/2020-03-06_001/Subject1',
#  '/data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7041/2020-03-06_001/Subject2']

# %%
print("Number of dyad scans:", int(len(session_dirs) / 2))
# Out:
# Number of dyad scans: 23

# %%
mne.viz.set_3d_backend('pyvista')
raw_intensities = []

for ses in session_dirs:

    
    try:
        raw_intensities.append(mne.io.read_raw_nirx(ses).load_data())
    except:
        print("Skipped:", ses)
    
#     raw_intensities[-1].resample(0.7) # downsample to 0.7 HZ to run faster
    
#     # replace raw_ints annotations with events from custom file. 
#     # read events from file
#     events, event_dict = mne.read_events(join(ses, "new_eve.txt"))
#     annot_from_events = mne.annotations_from_events(
#         events=events,
#         event_desc=event_dict,
#         sfreq=raw_intensities[-1].info['sfreq'],
#         orig_time=raw_intensities[-1].info['meas_date'])
    
#     raw_intensities[-1].set_annotations(annot_from_events)
# Out:
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7034/2020-02-11_001/Subject2
# Reading 0 ... 10122  =      0.000 ...  1295.616 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7034/2020-02-11_001/Subject1
# Reading 0 ... 10122  =      0.000 ...  1295.616 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7043/2020-03-12_002/Subject2
# Reading 0 ... 5337  =      0.000 ...   683.136 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7043/2020-03-12_002/Subject1
# Reading 0 ... 5337  =      0.000 ...   683.136 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7043/2020-03-12_001/Subject1
# Reading 0 ... 4694  =      0.000 ...   600.832 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7043/2020-03-12_001/Subject2
# Reading 0 ... 4694  =      0.000 ...   600.832 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7027/2019-12-16_001/Subject2
# Reading 0 ... 10061  =      0.000 ...  1287.808 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7027/2019-12-16_001/Subject1
# Reading 0 ... 10061  =      0.000 ...  1287.808 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7039/2020-03-05_001/Subject2
# Reading 0 ... 8673  =      0.000 ...  1110.144 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7039/2020-03-05_001/Subject1
# Reading 0 ... 8673  =      0.000 ...  1110.144 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7033/2020-02-03_001/Subject2
# Reading 0 ... 9276  =      0.000 ...  1187.328 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7033/2020-02-03_001/Subject1
# Reading 0 ... 9276  =      0.000 ...  1187.328 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7040/2020-03-04_001/Subject2
# Reading 0 ... 9329  =      0.000 ...  1194.112 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7040/2020-03-04_001/Subject1
# Reading 0 ... 9329  =      0.000 ...  1194.112 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7024/2019-12-11_003/Subject2
# Reading 0 ... 9333  =      0.000 ...  1194.624 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7024/2019-12-11_003/Subject1
# Reading 0 ... 9333  =      0.000 ...  1194.624 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7029/2020-01-25_001/Subject2
# Reading 0 ... 9730  =      0.000 ...  1245.440 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7029/2020-01-25_001/Subject1
# Reading 0 ... 9730  =      0.000 ...  1245.440 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7023/2019-12-02_002/Subject1
# Reading 0 ... 4458  =      0.000 ...   570.624 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7023/2019-12-02_002/Subject2
# Reading 0 ... 4458  =      0.000 ...   570.624 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7023/2019-12-02_001/Subject1
# Reading 0 ... 4900  =      0.000 ...   627.200 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7023/2019-12-02_001/Subject2
# Reading 0 ... 4900  =      0.000 ...   627.200 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7030/2020-01-29_001/Subject1
# Skipped: /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7030/2020-01-29_001/Subject1
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7030/2020-01-29_001/Subject2
# Skipped: /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7030/2020-01-29_001/Subject2
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7038/2020-03-05_002/Subject2
# Reading 0 ... 9142  =      0.000 ...  1170.176 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7038/2020-03-05_002/Subject1
# Reading 0 ... 9142  =      0.000 ...  1170.176 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7021/2019-11-23_003/Subject1
# Reading 0 ... 9202  =      0.000 ...  1177.856 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7021/2019-11-23_003/Subject2
# Reading 0 ... 9202  =      0.000 ...  1177.856 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7026/2019-12-11_004/Subject1
# Reading 0 ... 9785  =      0.000 ...  1252.480 secs...
# </usr/local/lib/python3.7/dist-packages/decorator.py:decorator-gen-401>:12: RuntimeWarning: A single dat file was expected in the specified path, but got 0. This may indicate that the file structure has been modified since the measurement was saved.
# </usr/local/lib/python3.7/dist-packages/decorator.py:decorator-gen-401>:12: RuntimeWarning: A single dat file was expected in the specified path, but got 0. This may indicate that the file structure has been modified since the measurement was saved.
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7026/2019-12-11_004/Subject2
# Reading 0 ... 9785  =      0.000 ...  1252.480 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7042/2020-03-10_004/Subject1
# Reading 0 ... 9062  =      0.000 ...  1159.936 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7042/2020-03-10_004/Subject2
# Reading 0 ... 9062  =      0.000 ...  1159.936 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7035/2020-02-19_001/Subject1
# Reading 0 ... 9474  =      0.000 ...  1212.672 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7035/2020-02-19_001/Subject2
# Reading 0 ... 9474  =      0.000 ...  1212.672 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7031/2020-01-16_001/Subject2
# Reading 0 ... 9689  =      0.000 ...  1240.192 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7031/2020-01-16_001/Subject1
# Reading 0 ... 9689  =      0.000 ...  1240.192 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7022/2020-01-23_001/Subject1
# Reading 0 ... 9230  =      0.000 ...  1181.440 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7022/2020-01-23_001/Subject2
# Reading 0 ... 9230  =      0.000 ...  1181.440 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7017/2019-11-22_001/Subject2
# Reading 0 ... 9845  =      0.000 ...  1260.160 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7017/2019-11-22_001/Subject1
# Reading 0 ... 9845  =      0.000 ...  1260.160 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7025/2019-12-17_001/Subject1
# Reading 0 ... 9992  =      0.000 ...  1278.976 secs...
# </usr/local/lib/python3.7/dist-packages/decorator.py:decorator-gen-401>:12: RuntimeWarning: A single dat file was expected in the specified path, but got 0. This may indicate that the file structure has been modified since the measurement was saved.
# </usr/local/lib/python3.7/dist-packages/decorator.py:decorator-gen-401>:12: RuntimeWarning: A single dat file was expected in the specified path, but got 0. This may indicate that the file structure has been modified since the measurement was saved.
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7025/2019-12-17_001/Subject2
# Reading 0 ... 9992  =      0.000 ...  1278.976 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7036/2020-02-20_001/Subject2
# Reading 0 ... 9544  =      0.000 ...  1221.632 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7036/2020-02-20_001/Subject1
# Reading 0 ... 9544  =      0.000 ...  1221.632 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7041/2020-03-06_001/Subject1
# Reading 0 ... 9147  =      0.000 ...  1170.816 secs...
# Loading /data/perlman/moochie/study_data/Neurophotonics/Jennings/NIRS_data/V1/7041/2020-03-06_001/Subject2
# Reading 0 ... 9147  =      0.000 ...  1170.816 secs...

# %%
for raw in raw_intensities:
    print(raw.times[-1])
# Out:
# 1295.616
# 1295.616
# 683.136
# 683.136
# 600.832
# 600.832
# 1287.808
# 1287.808
# 1110.144
# 1110.144
# 1187.328
# 1187.328
# 1194.112
# 1194.112
# 1194.624
# 1194.624
# 1245.44
# 1245.44
# 570.624
# 570.624
# 627.2
# 627.2
# 1170.176
# 1170.176
# 1177.856
# 1177.856
# 1252.48
# 1252.48
# 1159.936
# 1159.936
# 1212.672
# 1212.672
# 1240.192
# 1240.192
# 1181.44
# 1181.44
# 1260.16
# 1260.16
# 1278.976
# 1278.976
# 1221.632
# 1221.632
# 1170.816
# 1170.816

# %%
d_data = []

bad_data = []

for raw in raw_intensities:
    if raw.times[-1] > 1100:
        d_data.append(raw)
    else:
        bad_data.append(raw)

# d_data = raw_intensities

# %%
len(d_data)
# Out:
# 36

# %%
print([raw.info['subject_info']['his_id'] for raw in bad_data])
# Out:
# ['7043-2', '7043-1', '7043-1', '7043-2', '7023-1', '7023-2', '7023-1', '7023-2']

# %%
raw_intensities = d_data

# %%
len(raw_intensities[0])
# Out:
# 9169

# %%
subjects = list(set([raw.info['subject_info']['his_id'] for raw in raw_intensities]))
print(subjects)
# Out:
# ['7009-1', '7031', '7019', '7004', '7009-2']

# %%
raw_intensities[0].plot_sensors(to_sphere=True) # viz is screwed up lol

# %%
def draw_3d_brain():
    fig = mne.viz.create_3d_figure(size=(800, 600), bgcolor='white')

    fig = mne.viz.plot_alignment(
        raw_intensities[0].info,
        show_axes=True,
        subject='fsaverage',
        coord_frame='mri',
        trans='fsaverage',
        surfaces=['brain'],
        fnirs=[
            'channels',
            'pairs',
            'sources',
            'detectors'],
        subjects_dir="/usr/local/pkg/freesurfer/subjects",
        fig=fig)

# %%
def label_3d_brain():
    b = mne.viz.Brain(
        'fsaverage',
        'both',
        'pial',
        subjects_dir="/usr/local/pkg/freesurfer/subjects",
        figure=fig,
        units='m',
        alpha=0.2,
        cortex='low_contrast')

    labels = mne.read_labels_from_annot(
        'fsaverage', 
        subjects_dir="/usr/local/pkg/freesurfer/subjects")

    ROIs = [
        'frontalpole-lh',
        'frontalpole-rh',
        'temporalpole-lh',
        'temporalpole-rh'
    ]

    colors = [
        'green',
        'blue',
        'red',
        'orange',
        'yellow'
    ]

    aud_labels = [label for label in labels if label.name in ROIs]
    for i, label in enumerate(aud_labels):
        b.add_label(label, borders=False, color=colors[len(colors)%(i+1)])

# %%
# draw_3d_brain()
# label_3d_brain()

# %%
from mne_nirs.experimental_design import make_first_level_design_matrix
from mne_nirs.statistics import run_glm
from mne_nirs.channels import (
    get_long_channels,
    get_short_channels,
    picks_pair_to_idx)

from nilearn.plotting import plot_design_matrix

# %% [markdown]
# # Clean up annotations before analysis
#
# Next we update the annotations by assigning names to each trigger ID. Then we crop the recording to the section containing our experimental conditions.

# %%
sample_rate = raw_intensities[0].info['sfreq']

# durations = {
#     'Block 1': 120,
#     'Block 2': 105,
#     'Block 3': 120,
#     'Stop Signal': 1}

# %%
d_data = []

# %%
for raw_ints in raw_intensities:
    
#     print(raw_ints)
#     print(raw_ints.annotations)

    if len(raw_ints.annotations) > 0:
        d_data.append(raw_ints)
    else:
        print("Popping:", raw_ints)
        print(raw_ints.info['subject_info'])

#     raw_ints.annotations.rename({
#         '1.0': 'Block 1',
#         '2.0': 'Block 2',
#         '4.0': 'Block 3',
#         '128.0': 'Stop Signal'})
    
#     raw_ints.annotations.set_durations(durations, verbose=True)

#     raw_ints.annotations.delete(raw_ints.annotations.description == 'Stop Signal')

# %%
raw_intensities = d_data

# %%
str(raw)
# Out:
# '<RawNIRX | Subject2, 20 x 4298 (550.0 s), ~702 kB, data loaded>'

# %%
for raw_ints in raw_intensities:
#     if "7022" in raw_ints.info['subject_info']['his_id']:
    print(raw_ints)
    print(raw_ints.info['subject_info'])
    events, event_dict = mne.events_from_annotations(
        raw_ints,
        verbose=False)
    
#     events = np.append(events, [raw.times[-1], 0, 1])
    print(events)

    fig, ax = plt.subplots()
    fig = mne.viz.plot_events(events, event_id=event_dict, sfreq=raw_ints.info['sfreq'], axes=ax)
    ax.set_xlim(0, raw_ints.times[-1])
# Out:
# <RawNIRX | Subject1, 20 x 9169 (1173.5 s), ~1.4 MB, data loaded>
# {'his_id': '7031', 'first_name': '7031', 'sex': 0 (FIFFV_SUBJ_SEX_UNKNOWN), 'birthday': (2020, 3, 11)}
# [[  67    0    1]
#  [ 106    0    2]
#  [ 966    0    1]
#  [1083    0    1]
#  [1161    0    2]
#  [2021    0    1]
#  [2138    0    1]
#  [2216    0    2]
#  [3076    0    1]
#  [3193    0    1]
#  [3271    0    2]
#  [4131    0    1]
#  [4821    0    4]
#  [4884    0    1]
#  [4962    0    3]
#  [5939    0    1]
#  [6017    0    3]
#  [6994    0    1]
#  [7072    0    3]
#  [8048    0    1]
#  [8127    0    3]]
# <RawNIRX | Subject2, 20 x 9169 (1173.5 s), ~1.4 MB, data loaded>
# {'his_id': '7031', 'first_name': '7031', 'sex': 0 (FIFFV_SUBJ_SEX_UNKNOWN), 'birthday': (2020, 3, 11)}
# [[  67    0    1]
#  [ 106    0    2]
#  [ 966    0    1]
#  [1083    0    1]
#  [1161    0    2]
#  [2021    0    1]
#  [2138    0    1]
#  [2216    0    2]
#  [3076    0    1]
#  [3193    0    1]
#  [3271    0    2]
#  [4131    0    1]
#  [4821    0    4]
#  [4884    0    1]
#  [4962    0    3]
#  [5939    0    1]
#  [6017    0    3]
#  [6994    0    1]
#  [7072    0    3]
#  [8048    0    1]
#  [8127    0    3]]
# <RawNIRX | Subject2, 20 x 9400 (1203.1 s), ~1.5 MB, data loaded>
# {'his_id': '7009-2', 'first_name': '7009-2', 'sex': 0 (FIFFV_SUBJ_SEX_UNKNOWN), 'birthday': (2020, 3, 18)}
# [[  79    0    1]
#  [ 118    0    2]
#  [ 978    0    1]
#  [1095    0    1]
#  [1173    0    2]
#  [2033    0    1]
#  [2150    0    1]
#  [2228    0    2]
#  [3087    0    1]
#  [3205    0    1]
#  [3283    0    2]
#  [4142    0    1]
#  [5026    0    4]
#  [5089    0    1]
#  [5167    0    3]
#  [6144    0    1]
#  [6222    0    3]
#  [7198    0    1]
#  [7276    0    3]
#  [8253    0    1]
#  [8331    0    3]]
# <RawNIRX | Subject1, 20 x 9400 (1203.1 s), ~1.5 MB, data loaded>
# {'his_id': '7009-1', 'first_name': '7009-1', 'sex': 0 (FIFFV_SUBJ_SEX_UNKNOWN), 'birthday': (2020, 3, 18)}
# [[  79    0    1]
#  [ 118    0    2]
#  [ 978    0    1]
#  [1095    0    1]
#  [1173    0    2]
#  [2033    0    1]
#  [2150    0    1]
#  [2228    0    2]
#  [3087    0    1]
#  [3205    0    1]
#  [3283    0    2]
#  [4142    0    1]
#  [5026    0    4]
#  [5089    0    1]
#  [5167    0    3]
#  [6144    0    1]
#  [6222    0    3]
#  [7198    0    1]
#  [7276    0    3]
#  [8253    0    1]
#  [8331    0    3]]
# <RawNIRX | Subject1, 20 x 10121 (1295.4 s), ~1.6 MB, data loaded>
# {'his_id': '7004', 'first_name': '7004', 'sex': 0 (FIFFV_SUBJ_SEX_UNKNOWN), 'birthday': (2020, 1, 28)}
# [[ 183    0    1]
#  [5422    0    2]]
# <RawNIRX | Subject2, 20 x 10121 (1295.4 s), ~1.6 MB, data loaded>
# {'his_id': '7004', 'first_name': '7004', 'sex': 0 (FIFFV_SUBJ_SEX_UNKNOWN), 'birthday': (2020, 1, 28)}
# [[ 183    0    1]
#  [5422    0    2]]
# <RawNIRX | Subject2, 20 x 9042 (1157.2 s), ~1.4 MB, data loaded>
# {'his_id': '7019', 'first_name': '7019', 'sex': 0 (FIFFV_SUBJ_SEX_UNKNOWN), 'birthday': (2020, 2, 28)}
# [[ 675    0    1]
#  [ 792    0    1]
#  [ 871    0    2]
#  [1730    0    1]
#  [1847    0    1]
#  [1925    0    2]
#  [2785    0    1]
#  [2902    0    1]
#  [2980    0    2]
#  [3840    0    1]
#  [4712    0    4]
#  [4775    0    1]
#  [4853    0    3]
#  [5830    0    1]
#  [5908    0    2]
#  [6885    0    1]
#  [6963    0    3]
#  [7940    0    1]
#  [8018    0    3]]
# <RawNIRX | Subject1, 20 x 9042 (1157.2 s), ~1.4 MB, data loaded>
# {'his_id': '7019', 'first_name': '7019', 'sex': 0 (FIFFV_SUBJ_SEX_UNKNOWN), 'birthday': (2020, 2, 28)}
# [[ 675    0    1]
#  [ 792    0    1]
#  [ 871    0    2]
#  [1730    0    1]
#  [1847    0    1]
#  [1925    0    2]
#  [2785    0    1]
#  [2902    0    1]
#  [2980    0    2]
#  [3840    0    1]
#  [4712    0    4]
#  [4775    0    1]
#  [4853    0    3]
#  [5830    0    1]
#  [5908    0    2]
#  [6885    0    1]
#  [6963    0    3]
#  [7940    0    1]
#  [8018    0    3]]

# %%
len(events)
# Out:
# 19

# %%
print(len(d_data) / 2)
# Out:
# 21.0

# %%
print(event_dict)
# Out:
# {'1.0': 1, '2.0': 2, '3.0': 3, '7.0': 4}

# %%
def create_boxcar(raw, event_id=None, stim_dur=1):
    """
    Generate boxcar representation of the experimental paradigm.

    Parameters
    ----------
    raw : instance of Raw
        Haemoglobin data.
    event_id : as specified in MNE
        Information about events.
    stim_dur : Number
        The length of your stimulus.

    Returns
    -------
    s : array
        Returns an array for each annotation label.
    """
    from scipy import signal
    
    events, ids = mne.events_from_annotations(raw, event_id=event_id)
    s = np.zeros((len(raw.times), len(ids)))
    for idx, id in enumerate(ids):
        bc = signal.boxcar(round(raw.info['sfreq'] * stim_dur[id]))
        
        id_idx = [e[2] == idx + 1 for e in events]
        id_evt = events[id_idx]
        event_samples = [e[0] for e in id_evt]
        s[event_samples, idx] = 1.
        s[:, idx] = np.convolve(s[:, idx], bc)[:len(raw.times)]
    return s

# %%
for raw_ints in raw_intensities:
    s = create_boxcar(
        raw_ints,
        stim_dur = durations)
    
    fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(15, 6))
    plt.plot(raw_ints.times, s, axes=axes)
    plt.legend([
        "Block 1",
        "Block 2",
        "Block 3"],
        loc="upper right")
    plt.xlabel("Time (s)")
    plt.ylabel("Stimulus")
    plt.title("raw_ints")
#     plt.xlim(0, 1800)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-bee507488f47> in <module>
#       2     s = create_boxcar(
#       3         raw_ints,
# ----> 4         stim_dur = durations)
#       5
#       6     fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(15, 6))
#
# NameError: name 'durations' is not defined

# %%
raw_ints.info['subject_info']['his_id']

# %% [markdown]
# # Preprocess NIRS Data

# %%
raw_ods = []
for raw_ints in raw_intensities:
    raw_od = mne.preprocessing.nirs.optical_density(raw_ints)
    raw_haemo = mne.preprocessing.nirs.beer_lambert_law(raw_od)
    
#     short_chs = get_short_channels(raw_haemo)
    long_chs = get_long_channels(raw_haemo)

# %%
len(raw_ints)
# Out:
# 15112

# %%
long_chs
# Out:
# <RawNIRX | 5089_V0_fNIRS, 16 x 15112 (1934.2 s), ~1.9 MB, data loaded>

# %% [markdown]
# # Create design matrix

# %%
design_matrix = make_first_level_design_matrix(
    raw_haemo,
    hrf_model='spm',
#     stim_dur=120.0,
    drift_order=3,
    drift_model='polynomial')

# %%
from nilearn.glm.first_level import make_first_level_design_matrix

# %%
raw_ints.annotations[0]
# Out:
# OrderedDict([('onset', 11.648),
#              ('duration', 120.0),
#              ('description', 'Block 1'),
#              ('orig_time',
#               datetime.datetime(2022, 1, 18, 15, 15, 34, 54000, tzinfo=datetime.timezone.utc))])

# %%
annot = raw_ints.annotations.to_data_frame()

# %%
raw_ints.annotations.onset
# Out:
# array([  11.648,  145.536,  279.424,  413.312,  821.376,  940.032,
#        1058.688, 1177.472, 1397.888, 1531.776, 1665.664, 1799.552])

# %%
annot['onset'] = raw_ints.annotations.onset

# %%
annot = annot.rename(columns={"description": "trial_type"})

# %%
design_matrix = make_first_level_design_matrix(
    raw_ints.times,
    events=annot,
    hrf_model='glover',
    drift_model='polynomial',
    high_pass=0.01,
    drift_order=3)

# %%
fig, ax1 = plt.subplots(figsize=(10, 6), nrows=1, ncols=1)
fig = plot_design_matrix(design_matrix, ax=ax1)

# %%
raw_od.plot(events=events, duration=2000, show_scrollbars=False, clipping=None)
# Out:
# Opening raw-browser...
# <MNEBrowseFigure size 576x576 with 4 Axes>
# <MNEBrowseFigure size 576x576 with 4 Axes>

# %%
for raw_ints in raw_intensities:
    s = create_boxcar(
        raw_ints,
        stim_dur = durations)
    
    fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(15, 6))
    plt.plot(raw_ints.times, s, axes=axes)

    plt.plot(design_matrix['Block_1'])
    
#     plt.legend([
#         "Block 1",
#         "Block 2",
#         "Block 3"],
#         loc="upper right")
    plt.legend(["Stimulus", "Model Response"])
    
    plt.xlabel("Time (s)")
    plt.ylabel("Amplitude")
    plt.title("Glover HRF Over Block 1")
    
    plt.xlim(0, 180)
# Out:
# Used Annotations descriptions: ['Block 1', 'Block 2', 'Block 3']

# %%
for raw in raw_intensities:
    mne_nirs.preprocessing.peak_power(raw_od)

# %%
for raw in raw_intensities:
    raw.plot_psd()
# Out:
# Effective window size : 262.144 (s)
# <MNELineFigure size 720x252 with 2 Axes>

# %%
for raw in raw_intensities:
    raw.plot_psd_topo()
# Out:
# Effective window size : 262.144 (s)

# %%
sci = mne.preprocessing.nirs.scalp_coupling_index(raw_od)
fig, ax = plt.subplots()
ax.hist(sci)
ax.set(xlabel='Scalp Coupling Index', ylabel='Count', xlim=[0, 1])
# Out:
# [Text(0.5, 0, 'Scalp Coupling Index'), Text(0, 0.5, 'Count'), (0.0, 1.0)]

# %%
from itertools import compress
raw_od.info['bads'] = list(compress(raw_od.ch_names, sci < 0.7))
print(raw_od.info['bads'])
# Out:
# []

# %%
raw_od.plot(events=events, duration=2000, show_scrollbars=False, clipping=None)
# Out:
# Opening raw-browser...
# <MNEBrowseFigure size 576x576 with 4 Axes>
# <MNEBrowseFigure size 576x576 with 4 Axes>

# %%
raw_od.plot_sensors()

# %% [markdown]
# # Fit GLM to Subset of data and estimate response for each experimental condition

# %%
data_subset = raw_haemo.copy().pick(picks=range(2))

# %%
glm_est = run_glm(data_subset, design_matrix, noise_model='ar4')

# %%
glm_est
# Out:
# GLM Results for 2 channels

# %%
glm_est.ch_names
# Out:
# ['S1_D1 hbo', 'S1_D1 hbr']

# %%
glm_est.copy().pick('hbo')
# Out:
# GLM Results for 1 channels

# %%
glm_est.data['S1_D1 hbo'].model.rho
# Out:
# array([ 0.96435698, -0.08090524,  0.0668896 ,  0.03997772])

# %%
plt.plot(glm_est.data['S1_D1 hbo'].Y)
plt.plot(glm_est.data['S1_D1 hbo'].whitened_Y)

plt.legend(["Input signal", "Whitened signal"])

plt.xlabel("Sample")
plt.ylabel("Delta Mol")
# Out:
# Text(0, 0.5, 'Delta Mol')

# %%
glm_est.to_dataframe()
# Out:
# variable      Condition   df           mse   p_value            se         t  \
# 0         Block_1_Start  7.0  4.187141e-15  0.480678  8.567755e-08  0.744742
# 1         Block_2_Start  7.0  4.187141e-15  0.145418  8.787840e-08  1.638068
# 2         Block_3_Start  7.0  4.187141e-15  0.395273  9.337474e-08  0.905549
# 3              constant  7.0  4.187141e-15  0.333333  6.269736e-08 -1.039054
# 4               drift_1  7.0  4.187141e-15  0.001296  2.074049e-07 -5.169154
# 5               drift_2  7.0  4.187141e-15  0.229432  6.487285e-07 -1.316625
# 6               drift_3  7.0  4.187141e-15  0.657649  2.342262e-06  0.462656
# 7         Block_1_Start  7.0  5.700375e-16  0.077546  3.024489e-08  2.067122
# 8         Block_2_Start  7.0  5.700375e-16  0.299201  3.130494e-08  1.121165
# 9         Block_3_Start  7.0  5.700375e-16  0.429855  3.446035e-08  0.837727
# 10             constant  7.0  5.700375e-16  0.111599  1.997918e-08 -1.819813
# 11              drift_1  7.0  5.700375e-16  0.734641  6.687729e-08 -0.352774
# 12              drift_2  7.0  5.700375e-16  0.868203  2.022365e-07 -0.172135
# 13              drift_3  7.0  5.700375e-16  0.871310  7.190246e-07  0.168031
#
# variable         theta Source Detector Chroma  Significant    ch_name
# 0         6.380768e-08      1        1    hbo        False  S1_D1 hbo
# 1         1.439508e-07      1        1    hbo        False  S1_D1 hbo
# 2         8.455541e-08      1        1    hbo        False  S1_D1 hbo
# 3        -6.514596e-08      1        1    hbo        False  S1_D1 hbo
# 4        -1.072108e-06      1        1    hbo         True  S1_D1 hbo
# 5        -8.541318e-07      1        1    hbo        False  S1_D1 hbo
# 6         1.083662e-06      1        1    hbo        False  S1_D1 hbo
# 7         6.251988e-08      1        1    hbr        False  S1_D1 hbr
# 8         3.509800e-08      1        1    hbr        False  S1_D1 hbr
# 9         2.886837e-08      1        1    hbr        False  S1_D1 hbr
# 10       -3.635837e-08      1        1    hbr        False  S1_D1 hbr
# 11       -2.359259e-08      1        1    hbr        False  S1_D1 hbr
# 12       -3.481192e-08      1        1    hbr        False  S1_D1 hbr
# 13        1.208188e-07      1        1    hbr        False  S1_D1 hbr

# %%
glm_est.scatter()
# Out:
# <AxesSubplot:xlabel='Condition', ylabel='Theta'>

# %% [markdown]
# # Run on entire dataset (all channels)

# %%
glm_est = run_glm(raw_haemo, design_matrix)

# %%
glm_est
# Out:
# GLM Results for 20 channels

# %%
glm_est.plot_topo(conditions=["Control", "Block_1_Start", "Block_2_Start", "Block_3_Start"])

# %%
_, scores, times = scalp_coupling_index_windowed(raw_od, time_window=60)
plot_timechannel_quality_metric(raw_od, scores, times, threshold=0.7,
    title="Scalp Coupling Index Quality Evaluation")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-167-dfec4fe9a70f> in <module>
# ----> 1 _, scores, times = scalp_coupling_index_windowed(raw_od, time_window=60)
#       2 plot_timechannel_quality_metric(raw_od, scores, times, threshold=0.7,
#       3     title="Scalp Coupling Index Quality Evaluation")
#
# NameError: name 'scalp_coupling_index_windowed' is not defined

# %%
raw_od, scores, times = peak_power(raw_od, time_window=10)
plot_timechannel_quality_metric(raw_od, scores, times, threshold=0.1,
    title="Peak Power Quality Evaluation")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-50db79e404f4> in <module>
# ----> 1 raw_od, scores, times = peak_power(raw_od, time_window=10)
#       2 plot_timechannel_quality_metric(raw_od, scores, times, threshold=0.1,
#       3     title="Peak Power Quality Evaluation")
#
# NameError: name 'peak_power' is not defined
