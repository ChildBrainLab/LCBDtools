# %%
#RUN THE NIRS_DB_DOS_event_conversion-CARE.ipynb SCRIPT in the Beh notebook WHEN NEW SUBJECTS HAVE BEEN ADDED

#general dependencies (importing premade packages/libraries)
import numpy as np
import pandas as pd
import mne
import os
from glob import glob
from itertools import compress
from tqdm import tqdm

# %%
from platform import python_version
python_version()
# Out:
# '3.7.5'

# %%
import pycwt as wavelet
from pycwt.helpers import find

# %%
import io
from copy import copy
from collections import OrderedDict
import requests

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# LCBD dependencies
# add relative path to our toolbox
import sys
sys.path.append('../../../..')
from LCBDtools.src import argParser
from LCBDtools.src import Plots

# %%
# Some configuration variables
study_dir = "/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2"
participant_num_len = 5 # default length of participant numbers
ex_subs = [] # any subjects to not include in the dataset
debug = True

# set block durations (blocks here are actually trials) (original data has start and stop data points, those stop data points are eventually removed to replace with durations instead, they are easier to work with)
durations = {
    'Block 1': 120,
    'Block 2': 105,
    'Block 3': 120}

# %%
# set the channels for each ROI
ROIs = {
    'Left Frontal': ['S3_D2 hbo', 'S4_D2 hbo'],
    'Right Frontal': ['S5_D3 hbo', 'S6_D3 hbo'],
    'Left Temporal': ['S1_D1 hbo', 'S2_D1 hbo', 'S2_D2 hbo'],
    'Right Temporal': ['S7_D3 hbo', 'S7_D4 hbo', 'S8_D4 hbo']}

# %%
# make a list of all matching session paths (in this case for V0, assuming there should be more sessions?)
session_dirs = [d for d in glob(study_dir+"/*/V0/*") \
    if os.path.basename(os.path.split(os.path.split(d)[1])[1]) not in ex_subs]

subjects = list(set([os.path.basename(d)[:participant_num_len] for d in session_dirs]))

# %%
session_dirs
# Out:
# ['/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51241/V0/5124_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51241/V0/51241_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51701/V0/5170_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51701/V0/51701_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51331/V0/51331_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51331/V0/5133_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51491/V0/51491_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51491/V0/5149_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50841/V0/5084_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50841/V0/50841_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50021/V0/5002_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50021/V0/50021_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50322/V0/50321_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50322/V0/5032_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50781/V0/50781_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50781/V0/5078_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51662/V0/51662_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51662/V0/5166_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51781/V0/5178_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51781/V0/51781_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51841/V0/5184_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51841/V0/51841_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51021/V0/51021_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51021/V0/5102_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51411/V0/51411_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51411/V0/5141_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50032/V0/50032_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50032/V0/5003_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50491/V0/50491_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50491/V0/5049_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50241/V0/5024_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50241/V0/50241_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50331/V0/50331_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50331/V0/5033_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50701/V0/50701_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50701/V0/5070_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50601/V0/5060_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50601/V0/50601_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50231/V0/5023_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50231/V0/50231_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50341/V0/5034_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50341/V0/50341_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50771/V0/50771_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50771/V0/5077_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50591/V0/50591_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50591/V0/5059_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50502/V0/50502_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50502/V0/5050_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51511/V0/51511_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51511/V0/5151_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51831/V0/5183_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51831/V0/51831_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51121/V0/51121_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51121/V0/5112_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51051/V0/5105_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51051/V0/51051_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51461/V0/51461_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51461/V0/5146_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50121/V0/50121_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50121/V0/5012_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50831/V0/50831_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50831/V0/5083_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50461/V0/50461_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50461/V0/5046_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50941/V0/5094_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50941/V0/50941_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51591/V0/51591_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51591/V0/5159_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51132/V0/51132_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51132/V0/5113_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51231/V0/51231_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/

#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50552/V0/50552_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50552/V0/5055_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50991/V0/5099_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50991/V0/50991_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50261/V0/50261_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50261/V0/5026_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50721/V0/5072_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50721/V0/50721_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51391/V0/51391_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51391/V0/5139_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51171/V0/5117_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51171/V0/51171_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51431/V0/51431_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51431/V0/5143_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51001/V0/5100_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51001/V0/51001_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51631/V0/5163_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51631/V0/51631_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51201/V0/5120_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51201/V0/51201_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51371/V0/51371_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51371/V0/5137_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51741/V0/51741_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51741/V0/5174_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51191/V0/5119_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51191/V0/51191_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50801/V0/5080_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50801/V0/50801_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50521/V0/50521_V0_fNIRS_1',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50521/V0/50521_V0_fNIRS_2',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50111/V0/50111_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50111/V0/5011_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50451/V0/50451_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50451/V0/5045_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50971/V0/50971_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50971/V0/5097_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50281/V0/50281_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50281/V0/5028_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50752/V0/5075_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50752/V0/50752_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51281/V0/5128_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51281/V0/51281_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51212/V0/5121_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51212/V0/51212_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51521/V0/5152_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51521/V0/51521_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51801/V0/51801_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51801/V0/5180_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50962/V0/50962_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50962/V0/5096_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50191/V0/50191_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50191/V0/5019_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50532/V0/50532_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50532/V0/5053_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50631/V0/50631_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50631/V0/5063_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50371/V0/50371_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50371/V0/5037_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50731/V0/5073_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50731/V0/50731_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50301/V0/50301_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50301/V0/5030_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50091/V0/50091_V0_fNIRS_2',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50091/V0/50091_V0_fNIRS_1',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50981/V0/5098_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50981/V0/50981_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51161/V0/51161_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51161/V0/5116_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51082/V0/51082_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51082/V0/5108_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51421/V0/51421_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51421/V0/5142_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51011/V0/5101_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51011/V0/51011_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51381/V0/5138_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51381/V0/51381_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51262/V0/5126_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51262/V0/51262_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51652/V0/51651_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51652/V0/5165_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50381/V0/50381_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50381/V0/5038_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50551/V0/50551_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50551/V0/5055_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50871/V0/5087_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50871/V0/50871_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50992/V0/5099_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50992/V0/50992_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50421/V0/50421_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/50421/V0/5042_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51091/V0/51091_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51091/V0/5109_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51271/V0/5127_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51271/V0/51271_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51301/V0/51301_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51301/V0/5130_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51731/V0/5173_V0_fNIRS',
#  '/data/perlman/moochie/analysis/CARE/NIRS_data_clean_2/51731/V0/51731_V0_fNIRS']

# %%
len(session_dirs)
# Out:
# 317

# %%
len(session_dirs)/2
# Out:
# 158.5

# %%
# make a list where all of the scans will get loaded into (for children and for parent)
scans = []

# loop over all the session directories (dyads / DB-DOS folders)
for dyad_dir in list(set([os.path.split(ses)[0] for ses in session_dirs])):
    try:
        
        # get subject and visit from this path
        sub = os.path.basename(os.path.dirname(dyad_dir))
        visit = os.path.basename(dyad_dir)
        
        if debug:
            print(f'{sub} - {visit}')
        
        # determining whether sub is Child or Parent can be done by reading the config file in the .nirx directory        
        config_files = glob(os.path.join(dyad_dir, "*fNIRS", "*config*"))

        # open the file and read the line with Subject= in it
        for config in config_files:
            with open(config, 'r') as f:
                line = f.readline()
                while "Subject=" not in line:
                    line = f.readline()
                line = line.strip()
                line = line.replace("Subject=", "")
                
                # if the line is 1 it's the child
                if line == "1":
                    sub1 = os.path.dirname(config) # child
                elif line == "2":
                    sub2 = os.path.dirname(config) # parent
                    
        # make sure it has 'modern' .evt files
        evts = glob(sub1 + "/*.evt")
        if len(evts) != 2:
            print("There should be 2 evt files. Skipping:", os.path.basename(sub1))
            continue

#         #**load each in via hypyp loader (fixing config file so that even if child and parent numbers were flipped, they will now each be labelled as c or p in object)**
        fnirs_participant_1 = mne.io.read_raw_nirx(sub1, preload=False, verbose="warning") # child
        fnirs_participant_1.info['subject_info']['his_id'] = f"{sub[:participant_num_len]}c"
        
        fnirs_participant_2 = mne.io.read_raw_nirx(sub2, preload=False, verbose="warning") # parent
        fnirs_participant_2.info['subject_info']['his_id'] = f"{sub[:participant_num_len]}p"
        
        scans.append((fnirs_participant_1, fnirs_participant_2))
    
    #when there aren't 2 evt files    
    except:
        print("skipping session:", dyad_dir)
        continue
# Out:
# 50501 - V0
# 51781 - V0
# 51651 - V0
# 51521 - V0
# 50962 - V0
# 51331 - V0
# 50601 - V0
# 51381 - V0
# 51082 - V0
# /tmp/ipykernel_43843/1718574802.py:40: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   fnirs_participant_1 = mne.io.read_raw_nirx(sub1, preload=False, verbose="warning") # child
# /tmp/ipykernel_43843/1718574802.py:43: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   fnirs_participant_2 = mne.io.read_raw_nirx(sub2, preload=False, verbose="warning") # parent
# 51461 - V0
# 50831 - V0
# 50261 - V0
# 51471 - V0
# 50371 - V0
# 51141 - V0
# 51701 - V0
# 50001 - V0
# 50291 - V0
# 51181 - V0
# 51801 - V0
# 50992 - V0
# 50221 - V0
# 51041 - V0
# 50731 - V0
# 50451 - V0
# 51011 - V0
# 51441 - V0
# 51021 - V0
# 50961 - V0
# 51841 - V0
# 50991 - V0
# 51263 - V0
# 50281 - V0
# 51411 - V0
# 50503 - V0
# 50592 - V0
# 50701 - V0
# 50211 - V0
# 51431 - V0
# 51662 - V0
# 50841 - V0
# 50301 - V0
# There should be 2 evt files. Skipping: 50301_V0_fNIRS
# 51691 - V0
# 50581 - V0
# 50422 - V0
# 50381 - V0
# 50751 - V0
# There should be 2 evt files. Skipping: 50751_V0_fNIRS
# 50711 - V0
# 51741 - V0
# 51211 - V0
# /tmp/ipykernel_43843/1718574802.py:40: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   fnirs_participant_1 = mne.io.read_raw_nirx(sub1, preload=False, verbose="warning") # child
# /tmp/ipykernel_43843/1718574802.py:43: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   fnirs_participant_2 = mne.io.read_raw_nirx(sub2, preload=False, verbose="warning") # parent
# 50771 - V0
# 51091 - V0
# 50031 - V0
# 51131 - V0
# 51231 - V0
# 50331 - V0
# 51591 - V0
# 50111 - V0
# 50071 - V0
# 51491 - V0
# 51191 - V0
# 50591 - V0
# 51051 - V0
# 50391 - V0
# 51281 - V0
# 51731 - V0
# 51421 - V0
# 50091 - V0
# 50321 - V0
# /tmp/ipykernel_43843/1718574802.py:40: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   fnirs_participant_1 = mne.io.read_raw_nirx(sub1, preload=False, verbose="warning") # child
# /tmp/ipykernel_43843/1718574802.py:43: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   fnirs_participant_2 = mne.io.read_raw_nirx(sub2, preload=False, verbose="warning") # parent
# 51262 - V0
# 51271 - V0
# 50401 - V0
# 50552 - V0
# 51052 - V0
# /tmp/ipykernel_43843/1718574802.py:40: RuntimeWarning: A single dat file was expected in the specified path, but got 0. This may indicate that the file structure has been modified since the measurement was saved.
#   fnirs_participant_1 = mne.io.read_raw_nirx(sub1, preload=False, verbose="warning") # child
# /tmp/ipykernel_43843/1718574802.py:40: RuntimeWarning: Omitted 2 annotation(s) that were outside data range.
#   fnirs_participant_1 = mne.io.read_raw_nirx(sub1, preload=False, verbose="warning") # child
# /tmp/ipykernel_43843/1718574802.py:40: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   fnirs_participant_1 = mne.io.read_raw_nirx(sub1, preload=False, verbose="warning") # child
# /tmp/ipykernel_43843/1718574802.py:43: RuntimeWarning: A single dat file was expected in the specified path, but got 0. This may indicate that the file structure has been modified since the measurement was saved.
#   fnirs_participant_2 = mne.io.read_raw_nirx(sub2, preload=False, verbose="warning") # parent
# /tmp/ipykernel_43843/1718574802.py:43: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   fnirs_participant_2 = mne.io.read_raw_nirx(sub2, preload=False, verbose="warning") # parent
# 51251 - V0
# 51081 - V0
# 50781 - V0
# 50491 - V0
# 50421 - V0
# 50481 - V0
# 51481 - V0
# 51212 - V0
# 51121 - V0
# 51161 - V0
# 51201 - V0
# 51221 - V0
# 50121 - V0
# 50752 - V0
# 51301 - V0
# 51341 - V0
# 50361 - V0
# 50322 - V0
# 50241 - V0
# 50721 - V0
# 51001 - V0
# 50611 - V0
# 51261 - V0
# 50032 - V0
# /tmp/ipykernel_43843/1718574802.py:40: RuntimeWarning: A single dat file was expected in the specified path, but got 0. This may indicate that the file structure has been modified since the measurement was saved.
#   fnirs_participant_1 = mne.io.read_raw_nirx(sub1, preload=False, verbose="warning") # child
# 50021 - V0
# 50761 - V0
# 50342 - V0
# 50971 - V0
# 50351 - V0
# 50911 - V0
# 50981 - V0
# 50891 - V0
# 51601 - V0
# 51702 - V0
# 50802 - V0
# 50832 - V0
# 50861 - V0
# 51391 - V0
# 50621 - V0
# 50531 - V0
# 50092 - V0
# 51511 - V0
# 50461 - V0
# 51791 - V0
# 50341 - V0
# 51711 - V0
# 50441 - V0
# 51382 - V0
# 51171 - V0
# 51571 - V0
# 50431 - V0
# 51631 - V0
# 50181 - V0
# 50631 - V0
# 50602 - V0
# 51361 - V0
# 50081 - V0
# 50191 - V0
# 51132 - V0
# 50521 - V0
# 50941 - V0
# 51661 - V0
# 50942 - V0
# 50231 - V0
# 50171 - V0
# 50851 - V0
# 50131 - V0
# 50532 - V0
# 51831 - V0
# 51422 - V0
# 50691 - V0
# 50502 - V0
# 51751 - V0
# /tmp/ipykernel_43843/1718574802.py:40: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   fnirs_participant_1 = mne.io.read_raw_nirx(sub1, preload=False, verbose="warning") # child
# /tmp/ipykernel_43843/1718574802.py:43: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   fnirs_participant_2 = mne.io.read_raw_nirx(sub2, preload=False, verbose="warning") # parent
# 50811 - V0
# 50251 - V0
# 50801 - V0
# 51851 - V0
# 50871 - V0
# 51241 - V0
# 51371 - V0
# 50551 - V0
# 50921 - V0
# 51652 - V0
# 51501 - V0

# %%
#raw NIRS data for child and parent now loaded into "scans" object
scans
# Out:
# [(<RawNIRX | 50501_V0_fNIRS, 20 x 15354 (1965.2 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5050_V0_fNIRS, 20 x 15354 (1965.2 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 51781_V0_fNIRS, 20 x 15034 (1924.2 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5178_V0_fNIRS, 20 x 15034 (1924.2 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 51651_V0_fNIRS, 20 x 14958 (1914.5 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5165_V0_fNIRS, 20 x 14958 (1914.5 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 51521_V0_fNIRS, 20 x 14991 (1918.7 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5152_V0_fNIRS, 20 x 14991 (1918.7 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 50962_V0_fNIRS, 20 x 15599 (1996.5 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5096_V0_fNIRS, 20 x 15599 (1996.5 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 51331_V0_fNIRS, 20 x 15262 (1953.4 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5133_V0_fNIRS, 20 x 15262 (1953.4 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 50601_V0_fNIRS, 20 x 13999 (1791.7 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5060_V0_fNIRS, 20 x 13999 (1791.7 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 51381_V0_fNIRS, 20 x 15268 (1954.2 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5138_V0_fNIRS, 20 x 15268 (1954.2 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 51082_V0_fNIRS, 20 x 13435 (1719.6 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5108_V0_fNIRS, 20 x 13435 (1719.6 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 51461_V0_fNIRS, 20 x 15233 (1949.7 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5146_V0_fNIRS, 20 x 15233 (1949.7 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 50831_V0_fNIRS, 20 x 14349 (1836.5 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5083_V0_fNIRS, 20 x 14349 (1836.5 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 50261_V0_fNIRS, 20 x 17417 (2229.2 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5026_V0_fNIRS, 20 x 17417 (2229.2 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 51471_V0_fNIRS, 20 x 15984 (2045.8 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5147_V0_fNIRS, 20 x 15984 (2045.8 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 50371_V0_fNIRS, 20 x 15355 (1965.3 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5037_V0_fNIRS, 20 x 15355 (1965.3 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 51141_V0_fNIRS, 20 x 15024 (1922.9 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5114_V0_fNIRS, 20 x 15024 (1922.9 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 51701_V0_fNIRS, 20 x 14664 (1876.9 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5170_V0_fNIRS, 20 x 14664 (1876.9 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 50001_V0_fNIRS, 20 x 15501 (1984.0 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5000_V0_fNIRS, 20 x 15501 (1984.0 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 50291_V0_fNIRS, 20 x 15526 (1987.2 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5029_V0_fNIRS, 20 x 15526 (1987.2 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 51181_V0_fNIRS, 20 x 15910 (2036.4 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5118_V0_fNIRS, 20 x 15910 (2036.4 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 51801_V0_fNIRS, 20 x 15420 (1973.6 s), ~31 kB, data not loaded>,
#   <RawNIRX | 
#         0.2211838],
#        ...,
#        [0.8032469, 0.8085325, 0.8136439, ..., 1.140528 , 1.1414197,
#         1.1396215],
#        [0.1140138, 0.1150933, 0.1161584, ..., 0.3632928, 0.3638025,
#         0.3606351],
#        [0.1394837, 0.1411477, 0.1426566, ..., 0.378006 , 0.3786136,
#         0.3731771]])

# %%
scans[0][0].get_data().shape
# Out:
# (20, 15354)

# %%
t = scans[0][0].times

# %%
scans[26][0].times
# Out:
# array([0.000000e+00, 1.280000e-01, 2.560000e-01, ..., 1.911040e+03,
#        1.911168e+03, 1.911296e+03])

# %%
scans[0][0].ch_names
# Out:
# ['S1_D1 760',
#  'S1_D1 850',
#  'S2_D1 760',
#  'S2_D1 850',
#  'S2_D2 760',
#  'S2_D2 850',
#  'S3_D2 760',
#  'S3_D2 850',
#  'S4_D2 760',
#  'S4_D2 850',
#  'S5_D3 760',
#  'S5_D3 850',
#  'S6_D3 760',
#  'S6_D3 850',
#  'S7_D3 760',
#  'S7_D3 850',
#  'S7_D4 760',
#  'S7_D4 850',
#  'S8_D4 760',
#  'S8_D4 850']

# %%
plt.plot(
    t,
    X[19]
)

# %%
#can use to check the subject info for each member of dyad in the scans object. First number selects dyad pair, 2nd number: 0 = child, 1 = parent
scans[0][0].info['subject_info']
# Out:
# {'his_id': '50501c',
#  'first_name': '5050-1',
#  'sex': 0 (FIFFV_SUBJ_SEX_UNKNOWN),
#  'birthday': (2021, 10, 24)}

# %%
#Checking annotation before running script to remove the stop annotations
scans[0][0].annotations
# Out:
# <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>

# %%
#if annotations don't match across subjects, need to check the evt files for consistency, run a event conversion script for the data
#Need to check if this works for the CARE data
for scan in scans:
    print(scan[0].info['subject_info']['his_id'],scan[0].annotations)
# Out:
# 50501c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51781c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51651c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51521c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50962c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51331c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50601c <Annotations | 23 segments: 1.0 (4), 128.0 (11), 2.0 (4), 4.0 (4)>
# 51381c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51082c <Annotations | 20 segments: 1.0 (4), 128.0 (10), 2.0 (4), 4.0 (2)>
# 51461c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50831c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50261c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51471c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50371c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51141c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51701c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50001c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50291c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51181c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51801c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50992c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50221c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51041c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50731c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50451c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51011c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51441c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51021c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50961c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51841c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50991c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51263c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50281c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51411c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50503c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50592c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50701c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50211c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51431c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51662c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50841c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51691c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50581c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50422c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50381c <Annotations | 23 segments: 1.0 (3), 128.0 (11), 2.0 (4), 4.0 (4), 5.0 (1)>
# 50711c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51741c <Annotations | 24 segments: 1.0 (3), 128.0 (12), 2.0 (4), 4.0 (4), 8.0 (1)>
# 51211c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50771c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51091c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50031c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51131c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51231c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50331c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51591c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50111c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50071c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51491c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51191c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50591c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51051c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50391c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51281c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51731c <Annotations | 23 segments: 1.0 (3), 128.0 (11), 2.0 (4), 4.0 (4), 8.0 (1)>
# 51421c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50091c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50321c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51262c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51271c <Annotations | 22 segments: 1.0 (4), 128.0 (11), 2.0 (4), 4.0 (3)>
# 50401c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50552c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51052c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51251c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51081c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50781c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50491c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50421c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50481c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51481c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51212c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51121c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51161c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51201c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51221c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50121c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50752c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51301c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51341c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50361c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50322c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50241c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50721c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51001c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50611c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51261c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50032c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50021c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50761c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50342c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50971c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50351c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50911c <Annotations | 24 segments: 1.0 (3), 128.0 (12), 2.0 (4), 4.0 (4), 9.0 (1)>
# 50981c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50891c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51601c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51702c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50802c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50832c <Annotations | 22 segments: 1.0 (4), 128.0 (11), 2.0 (4), 4.0 (3)>
# 50861c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51391c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50621c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50531c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50092c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51511c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50461c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51791c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50341c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51711c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50441c <Annotations | 8 segments: 1.0 (4), 128.0 (4)>
# 51382c <Annotations | 24 segments: 1.0 (3), 128.0 (12), 2.0 (4), 4.0 (4), 8.0 (1)>
# 51171c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51571c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50431c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51631c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50181c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50631c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50602c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51361c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50081c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50191c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51132c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50521c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50941c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51661c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50942c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50231c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50171c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50851c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50131c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50532c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51831c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51422c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50691c <Annotations | 23 segments: 1.0 (4), 128.0 (11), 2.0 (4), 4.0 (4)>
# 50502c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51751c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50811c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50251c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50801c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51851c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50871c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51241c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51371c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50551c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 50921c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51652c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>
# 51501c <Annotations | 24 segments: 1.0 (4), 128.0 (12), 2.0 (4), 4.0 (4)>

# %%
# rename events and set durations for block 1 and 2

# if we can't load in the annotations right, we'll remove them from our list of scans
bads = []

for i, dscan in enumerate(scans):
    
    try:
        for scan in dscan:

            # rename the binary annotations with actual names
            scan.annotations.rename({
                '1.0': 'Block 1',
                '2.0': 'Block 2',
                '4.0': 'Block 3'})

            # remove any stop annotations
            scan.annotations.delete(scan.annotations.description == '128.0')

            # set the durations based off the durations dictionary
            scan.annotations.set_durations(durations, verbose=True)
    
    except:
        bads.append(i)
        
for i in sorted(bads, reverse=True):
    del scans[i]

# %%
scans[0][0].annotations
# Out:
# <Annotations | 12 segments: Block 1 (4), Block 2 (4), Block 3 (4)>

# %%
scans[0][0].annotations.to_data_frame()
# Out:
#                      onset  duration description
# 0  2021-10-24 09:47:17.644     120.0     Block 1
# 1  2021-10-24 09:49:31.660     120.0     Block 1
# 2  2021-10-24 09:51:45.548     120.0     Block 1
# 3  2021-10-24 09:53:59.564     120.0     Block 1
# 4  2021-10-24 10:01:26.028     105.0     Block 2
# 5  2021-10-24 10:03:25.196     105.0     Block 2
# 6  2021-10-24 10:05:24.108     105.0     Block 2
# 7  2021-10-24 10:07:22.892     105.0     Block 2
# 8  2021-10-24 10:10:49.612     120.0     Block 3
# 9  2021-10-24 10:13:03.628     120.0     Block 3
# 10 2021-10-24 10:15:17.516     120.0     Block 3
# 11 2021-10-24 10:17:31.404     120.0     Block 3

# %%
len(scans)
# Out:
# 155

# %%
scans
# Out:
# [(<RawNIRX | 50501_V0_fNIRS, 20 x 15354 (1965.2 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5050_V0_fNIRS, 20 x 15354 (1965.2 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 51781_V0_fNIRS, 20 x 15034 (1924.2 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5178_V0_fNIRS, 20 x 15034 (1924.2 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 51651_V0_fNIRS, 20 x 14958 (1914.5 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5165_V0_fNIRS, 20 x 14958 (1914.5 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 51521_V0_fNIRS, 20 x 14991 (1918.7 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5152_V0_fNIRS, 20 x 14991 (1918.7 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 50962_V0_fNIRS, 20 x 15599 (1996.5 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5096_V0_fNIRS, 20 x 15599 (1996.5 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 
3 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 50691_V0_fNIRS, 20 x 15580 (1994.1 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5069_V0_fNIRS, 20 x 15580 (1994.1 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 50502_V0_fNIRS, 20 x 14351 (1836.8 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5050_V0_fNIRS, 20 x 14351 (1836.8 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 51751_V0_fNIRS, 20 x 14858 (1901.7 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5175_V0_fNIRS, 20 x 14858 (1901.7 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 50811_V0_fNIRS, 20 x 14461 (1850.9 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5081_V0_fNIRS, 20 x 14461 (1850.9 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 50251_V0_fNIRS, 20 x 15258 (1952.9 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5025_V0_fNIRS, 20 x 15258 (1952.9 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 50801_V0_fNIRS, 20 x 15467 (1979.6 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5080_V0_fNIRS, 20 x 15467 (1979.6 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 51851_V0_fNIRS, 20 x 16117 (2062.8 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5185_V0_fNIRS, 20 x 16117 (2062.8 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 50871_V0_fNIRS, 20 x 14895 (1906.4 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5087_V0_fNIRS, 20 x 14895 (1906.4 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 51241_V0_fNIRS, 20 x 14767 (1890.0 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5124_V0_fNIRS, 20 x 14767 (1890.0 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 51371_V0_fNIRS, 20 x 15142 (1938.0 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5137_V0_fNIRS, 20 x 15142 (1938.0 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 50551_V0_fNIRS, 20 x 15521 (1986.6 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5055_V0_fNIRS, 20 x 15521 (1986.6 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 50921_V0_fNIRS, 20 x 14855 (1901.3 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5092_V0_fNIRS, 20 x 14855 (1901.3 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 51651_V0_fNIRS, 20 x 14834 (1898.6 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5165_V0_fNIRS, 20 x 14834 (1898.6 s), ~31 kB, data not loaded>),
#  (<RawNIRX | 51501_V0_fNIRS, 20 x 15218 (1947.8 s), ~31 kB, data not loaded>,
#   <RawNIRX | 5150_V0_fNIRS, 20 x 15218 (1947.8 s), ~31 kB, data not loaded>)]

# %%
from typing import Union

# function to do Continuous Wavelet Transform on a single signal
#Sig1: raw MNE converted signal or Epoch; plot = set whether you want to plot the wavelet (True or False); chs: produce a wavelet for a specific channel
def mne_wavelet_transform(sig1: [mne.io.Raw, mne.Epochs], plot: bool = True,
                      chs: Union[str] = None):
    """
    Perform a continuous wavelet transform based off data in mne Raw object
    """
    
    #Fourier Transform "transforms" data from time to frequency domain (certain number of oscillations per second)
    #The the final wavelet transform is an intermediate between time and frequency domain, it just needs to be transformed to frquency first
    # set time ##t0 = start time and dt = distance in time from t0. N is length
    t0 = sig1.times[0]
    dt = sig1.times[1] - t0
    N = len(sig1.times)
    #t = np.arange(0, N) * dt + t0
    t = sig1.times
    
    # define wavelet analysis parameters ## Clayton Add reference for parameters? (By default uses a Morlet convolution function to align detected signal with
    # with this base function) 
    #Video on Morlet wavelets
    mother = wavelet.Morlet(6)
    s0 = 2 * dt # starting scale, in this case 2 * 0.128 s = 0.256 s
    dj = 1 / 12 # twelve sub-octaves per octaves
    J = 10 / dj # ten powers of 2 with dj sub-octaves
    
    if chs is None:
        chs = sig1.info['ch_names']
        
    #reshaping of signal
    for ch in chs:
        dat = np.squeeze(sig1.get_data(picks=[ch])) * 1e5
        
        # detrend and normalize the input data by its standard deviation (to remove drift effects)
        p = np.polyfit(t - t0, dat, 1)
        dat_notrend = dat - np.polyval(p, t - t0)
        std = dat_notrend.std() # standard deviation
        var = std ** 2 # variance
        dat_norm = dat_notrend / std # normalized dataset
        
        alpha, _, _ = wavelet.ar1(dat) # lag-1 autocorrelation for red noise
        
        #This is the actual function where dat_norm, dt etc. are entered to produce the wavelet tranformed matrix, weighted scales for each matrix, list of frequencies
        # coming from each matrix, the cone of influence (gives a prospective range in which signal should closely convolve with Morlet),
        #fast fourier transform? (fft)
        wave, scales, freqs, coi, fft, fftfreqs = wavelet.cwt(
            dat_norm, dt, dj, s0, J, mother)
        iwave = wavelet.icwt(wave, scales, dt, dj, mother) * std
    
        # plotting the fourier tranform
        power = (np.abs(wave)) ** 2
        fft_power = np.abs(fft) ** 2
        period = 1 / freqs
        power /= scales[:, None] # optional according to Liu et al. (2007)
        
        # power significance test (the degree of convergence of the signal and the Morlet function? Also compare frequencies in one epoch vs the other?)
        signif, fft_theor = wavelet.significance(
            1.0, dt, scales, 0, alpha,
            significance_level=0.95, 
            wavelet=mother)
        sig95 = np.ones([1, N]) * signif[:, None]
        sig95 = power / sig95
        
        # calculate global wavelet spectrum and determine its significance level
        glbl_power = power.mean(axis=1)
        dof = N - scales # correction for padding at edges
        glbl_signif, tmp = wavelet.significance(var, dt, scales, 1, alpha,
                                                significance_level=0.95, dof=dof,
                                                wavelet=mother)
        
        # calculate scale average and its significance level
        sel = find((period >= 10) & (period < 50))
        Cdelta = mother.cdelta
        scale_avg = (scales * np.ones((N, 1))).transpose()
        scale_avg = power / scale_avg # As in Torrence and Compo (1998) equation 24
        scale_avg = var * dj * dt / Cdelta * scale_avg[sel, :].sum(axis=0)
        scale_avg_signif, tmp = wavelet.significance(var, dt, scales, 2, alpha,
                                                    significance_level=0.95,
                                                    dof=[scales[sel[0]],
                                                        scales[sel[-1]]],
                                                    wavelet=mother)
        
        if plot is True:
            
            title = f"{sig1.info['subject_info']['his_id']} Channel {ch} Continuous Wavelet Transform"
            label = ""
            units = 'Absorbance Units (AU)'
            
            # prepare the figure
            plt.close('all')
            plt.ioff()
            figprops = dict(figsize=(11, 8), dpi=72)
            fig = plt.figure(**figprops)
            
            # first sub-plot, the original time series
            ax = plt.axes([0.1, 0.75, 0.65, 0.2])
            ax.plot(t, dat, 'k', linewidth=1.5)
            ax.set_title('a) {}'.format(title))
            ax.set_ylabel(r'{} [{}]'.format(label, units))
            
            # second sub-plot, the normalized wavelet power spectrum and significance
            # level contour lines and cone of influence hatched area. Note that period
            # scale is logarithmic
            bx = plt.axes([0.1, 0.37, 0.65, 0.28], sharex=ax)
            levels = [0.0625, 0.125, 0.25, 0.5, 1, 2, 4, 8, 16]
            conmap = bx.contourf(t, np.log2(period), np.log2(power), np.log2(levels), 
                        extend='both', cmap=plt.cm.jet)
#             plt.colorbar(conmap)
            extent = [t.min(), t.max(), 0, max(period)]
            bx.contour(t, np.log2(period), sig95, [-99, 1], colors='k', linewidths=2,
                                  extent=extent)
            bx.fill(np.concatenate([t, t[-1:] + dt, t[-1:] + dt,
                                   t[:1] - dt, t[:1] - dt]),
                    np.concatenate([np.log2(coi), [1e-9], np.log2(period[-1:]),
                                    np.log2(period[-1:]), [1e-9]]),
                    'k', alpha=0.3, hatch='x')
            bx.set_title('b) {} Wavelet Power Spectrum ({})'.format(label, mother.name))
            bx.set_ylabel('Frequency (Hz)')
            
            Yticks = 2 ** np.arange(np.ceil(np.log2(period.min())),
                                    np.ceil(np.log2(period.max())))
            
            bx.set_yticks(np.log2(Yticks))
            bx.set_yticklabels(1/Yticks)
            
            # third sub-plot, the global wavelet and Fourier power spectra and theoretical
            # noise spectra. Note that period scale is logarithmic
            cx = plt.axes([0.77, 0.37, 0.2, 0.28], sharey=bx)
            cx.plot(glbl_signif, np.log2(period), 'k--')
            cx.plot(var * fft_theor, np.log2(period), '--', color='#cccccc')
            cx.plot(var * fft_power, np.log2(1./fftfreqs), '-', color='#cccccc',
                    linewidth=1.)
            cx.plot(var * glbl_power, np.log2(period), 'k-', linewidth=1.5)
            cx.set_title('c) Global Wavelet Spectrum')
            cx.set_xlabel(r'Power [({})^2]'.format(units))
            cx.set_xlim([0, glbl_power.max() + var])
            cx.set_ylim(np.log2([period.min(), period.max()]))
            cx.set_yticks(np.log2(Yticks))
            cx.set_yticklabels(1/Yticks)
            plt.setp(cx.get_yticklabels(), visible=False)
            
            # Fourth sub-plot, the scale averaged wavelet spectrum.
            dx = plt.axes([0.1, 0.07, 0.65, 0.2], sharex=ax)
            dx.axhline(scale_avg_signif, color='k', linestyle='--', linewidth=1.)
            dx.plot(t, scale_avg, 'k-', linewidth=1.5)
            dx.set_title('d) {}--{} second scale-averaged power'.format(2, 8))
            dx.set_xlabel('Time (seconds)')
            dx.set_ylabel(r'Average variance [{}]'.format(units))
            ax.set_xlim([t.min(), t.max()])

            plt.show()
    
    return wave, scales, freqs, coi, fft, fftfreqs


# function to do wavelet coherence transform on 2 signals
def mne_wavelet_coherence_transform(sig1: [mne.io.Raw, mne.Epochs],
        sig2: [mne.io.Raw, mne.Epochs],
        plot: bool = True, fig_fname: str = None,
        chs: Union[str] = None):
    
    t0 = sig1.times[0]
    dt = sig1.times[1] - t0
    N = len(sig1.times)
#     t = np.arange(0, N) * dt + t0
    t = sig1.times
    
    # define wavelet analysis parameters
    mother = wavelet.Morlet(6)
    s0 = 2 * dt # starting scale, in this case 2 * 0.128 s = 0.256 s
    dj = 1 / 12 # twelve sub-octaves per octaves
    J = 10 / dj # ten powers of 2 with dj sub-octaves
    
    if chs is None:
        chs = sig1.info['ch_names']
        
    for ch in chs:
        dat1 = np.squeeze(sig1.get_data(picks=[ch]))
        dat2 = np.squeeze(sig2.get_data(picks=[ch]))
        
        if np.isnan(dat1).any():
            print("Dat 1 contains NaN values")
            raise ValueError
            
        if np.isnan(dat2).any():
            print("Dat 2 contains NaN values")
            raise ValueError
        
        # detrend and normalize the input data by its standard deviation
        p1 = np.polyfit(t - t0, dat1, 1)
        dat_notrend1 = dat1 - np.polyval(p1, t - t0)
        std1 = dat_notrend1.std() # standard deviation
        var1 = std1 ** 2 # variance
        dat_norm1 = dat_notrend1 / std1 # normalized dataset
        
        # detrend and normalize the input data by its standard deviation
        p2 = np.polyfit(t - t0, dat2, 1)
        dat_notrend2 = dat2 - np.polyval(p2, t - t0)
        std2 = dat_notrend2.std() # standard deviation
        var2 = std2 ** 2 # variance
        dat_norm2 = dat_notrend2 / std2 # normalized dataset
        
        WCT, aWCT, coi, freqs, sig95 = wavelet.wct(
            dat_norm1, dat_norm2,
            dt, dj=dj, s0=s0, J=J, sig=False,
            significance_level=0.95, wavelet='morlet',
            normalize=True)
        
        period = 1 / freqs
        
        if plot is True:
            
            title = f"{sig1.info['subject_info']['his_id']} / {sig2.info['subject_info']['his_id']} Channel {ch} Wavelet Coherence Transform"
            label = f"{sig1.info['subject_info']['his_id']} {sig2.info['subject_info']['his_id']} {ch}"
            units = 'Absorbance Units (AU)'
            
            # prepare the figure
            plt.close('all')
            plt.ioff()
            figprops = dict(figsize=(11, 8), dpi=72)
            fig = plt.figure(**figprops)
            
            # first sub-plot, the normalized wavelet power spectrum and significance
            # level contour lines and cone of influence hatched area. Note that period
            # scale is logarithmic
            ax = plt.axes([0.1, 0.37, 0.65, 0.28])
#             levels = [0.0625, 0.125, 0.25, 0.5, 1, 2, 4, 8, 16]
            levels = list(np.arange(0.1, 1, step=0.1))
            conmap = ax.contourf(t, np.log2(period), WCT, levels, 
                        extend='both', cmap=plt.cm.jet)
            plt.colorbar(conmap)
            extent = [t.min(), t.max(), 0, max(period)]
#             ax.contour(t, np.log2(period), sig95, [-99, 1], colors='k', linewidths=2,
#                                   extent=extent)
            ax.fill(np.concatenate([t, t[-1:] + dt, t[-1:] + dt,
                                   t[:1] - dt, t[:1] - dt]),
                    np.concatenate([np.log2(coi), [1e-9], np.log2(period[-1:]),
                                    np.log2(period[-1:]), [1e-9]]),
                    'k', alpha=0.3, hatch='x')
            ax.set_title('b) {} Wavelet Coherence Spectrum ({})'.format(label, mother.name))
            ax.set_ylabel('Frequency (Hz)')
            
            Yticks = 2 ** np.arange(np.ceil(np.log2(period.min())),
                                    np.ceil(np.log2(period.max())))
            
            ax.set_yticks(np.log2(Yticks))
            ax.set_yticklabels(1/Yticks)
            ax.set_xlim([t.min(), t.max()])
            ax.set_ylim(np.log2([period.min(), period.max()]))
            
            if fig_fname is None:
                plt.show()
            else:
                plt.savefig(fig_fname)
            
    return WCT, aWCT, coi, freqs, sig95

# %%
#will be converted to HbO and HbR channels later in the script
scans[8][1].ch_names
# Out:
# ['S1_D1 760',
#  'S1_D1 850',
#  'S2_D1 760',
#  'S2_D1 850',
#  'S2_D2 760',
#  'S2_D2 850',
#  'S3_D2 760',
#  'S3_D2 850',
#  'S4_D2 760',
#  'S4_D2 850',
#  'S5_D3 760',
#  'S5_D3 850',
#  'S6_D3 760',
#  'S6_D3 850',
#  'S7_D3 760',
#  'S7_D3 850',
#  'S7_D4 760',
#  'S7_D4 850',
#  'S8_D4 760',
#  'S8_D4 850']

# %%
# example Block plot for 3000 seconds
scans[10][0].copy().pick(['S3_D2 850']).plot(duration=3000, scalings=1)
# Out:
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
#Concise description of wavelet transform, inputs and outputs that were coded in the function above
wave, scales, freqs, coi, fft, fftfreqs = mne_wavelet_transform(
    #scans is object we built above that contains raw NIRS data from children and parent, first index number (0)
    #is the dyadic pair (can switch to any number of dyadic pairs in data, 2nd index is where you select child (0) or parent (1)
    scans[0][0].copy().crop(tmax=400),
    #to plot the data, would say False if you want no plot
    plot=True,
    #select the channel(s) you want to visualize data from
    chs=['S3_D2 850'])

# %%
#Concise description of wavelet transform, inputs and outputs that were coded in the function above (clean)
wave, scales, freqs, coi, fft, fftfreqs = mne_wavelet_transform(
    scans[25][1].copy().crop(tmax=1500),
    plot=True,
    chs=['S3_D2 850'])

# %%
# example plot for 2200 seconds
scans[50][1].copy().pick(['S2_D2 850']).plot(duration=2200, scalings=1)
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
# example wavelet transform for 1800 seconds
wave, scales, freqs, coi, fft, fftfreqs = mne_wavelet_transform(
    scans[6][1].copy().crop(tmax=1800),
    plot=True,
    chs=['S5_D3 850']
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_43843/3713196074.py in <module>
#       1 # example wavelet transform for 1800 seconds
#       2 wave, scales, freqs, coi, fft, fftfreqs = mne_wavelet_transform(
# ----> 3     scans[6][1].copy().crop(tmax=1800),
#       4     plot=True,
#       5     chs=['S5_D3 850']
#
# /data/perlman/moochie/resources/server_access/NIRSenv/lib/python3.7/site-packages/mne/io/base.py in crop(self, tmin, tmax, include_tmax)
#    1319         elif tmax > max_time:
#    1320             raise ValueError('tmax (%s) must be less than or equal to the max '
# -> 1321                              'time (%0.4f sec)' % (tmax, max_time))
#    1322
#    1323         smin, smax = np.where(_time_mask(
#
# ValueError: tmax (1800) must be less than or equal to the max time (1791.7440 sec)

# %%
# example coherence transformo from a real dyad with 400 seconds (approach 1)
# 0 = child and 1 = parent for the 2nd index point of the scan object
#synchrony value goes from 0 to 1, 1 to max syncrhony
WCT, aWCT, coi, freqs, sig95 = mne_wavelet_coherence_transform(
    scans[25][0].copy().crop(tmax=400),
    scans[25][1].copy().crop(tmax=400),
    plot=True,
    chs=['S1_D1 850'])

# %%
# example coherence transformo from a real dyad with 400 seconds (approach 2)
# 0 = child and 1 = parent for the 2nd index point of the scan object
#synchrony value goes from 0 to 1, 1 to max syncrhony
WCT, aWCT, coi, freqs, sig95 = mne_wavelet_coherence_transform(
    scans[4][0].copy().pick(['S3_D2 850']).crop(tmax=400),
    scans[4][1].copy().pick(['S3_D2 850']).crop(tmax=400),
    plot=True)

# %% [markdown]
# # Preprocessing Step
#
# Now that data are loaded in and events are correctly distinct, we iterate through each dyad and each individual scan to apply LCBD-standard preprocessing functions.
# - Convert to Optical Density
# - Record Scalp-Coupling Index and Mark Channels < 0.5
# - Temporal Derivative Distribution Repair
# - Beer Lambert Law to Convert to Haemoglobin
# - Bandpass Filter 0.01-0.5 Hz
#
# and append those dyads to a list of preprocessed scans.

# %%
#Here the signals collected from the various channels are converted to relaative hemoglobin concentration instead of a frequency waveform,
#which is what we were working with above before preprocessing

# make a list where the preprocessed scans will go
pps = []

# for each dyad scan in scans
for dscan in scans:

    ppdscan = [] # make a list for the preprocessed dyad's scans
    
    # individually preprocess each subject in dyad
    for scan in dscan:
        
        # convert to optical density
        raw_od = mne.preprocessing.nirs.optical_density(scan)

        # scalp coupling index
        sci = mne.preprocessing.nirs.scalp_coupling_index(raw_od)
        raw_od.info['bads'] = list(compress(raw_od.ch_names, sci < 0.5))
        
        # linear detrend, par example
#         raw.data[:] = scipy.signal.detrend(raw.get_data(), axis=-1, fit='linear')

        if len(raw_od.info['bads']) > 0:
            print("Bad channels in subject", raw_od.info['subject_info']['his_id'], ":", raw_od.info['bads'])
        
        # temporal derivative distribution repair (motion attempt)
        tddr_od = mne.preprocessing.nirs.tddr(raw_od)
#         print("tddr")
#         tddr_od.plot(
#             n_channels=len(tddr_od.ch_names),
#             scalings=0.1,
#             duration=100,
#             show_scrollbars=False)
        
        # savgol filter (linear polynomial smoothing)
#         sav_od = raw_od.savgol_filter(0.5)
#         print("savgol filtering")
#         sav_od.plot(
#             n_channels=len(sav_od.ch_names),
#             scalings=0.1,
#             duration=100,
#             show_scrollbars=False)

        bp_od = tddr_od.filter(0.01, 0.5)
#         print("bandpass")
#         bp_od.plot(
#             n_channels=len(bp_od.ch_names),
#             duration=100,
#             scalings=0.1,
#             show_scrollbars=False)
    
        # haemoglobin conversion using Beer Lambert Law (this will change channel names from frequency to hemo or deoxy hemo labelling)
        haemo = mne.preprocessing.nirs.beer_lambert_law(bp_od, ppf=0.1)
#         print("haemo")
#         haemo.plot(
#             n_channels=len(haemo.ch_names),
#             duration=100,
#             scalings=0.0001,
#             show_scrollbars=False)

#         print("PSD")
#         haemo_lp.plot_psd(average=True)
        
        ppdscan.append(haemo)
        
    pps.append(ppdscan)
# Out:
# Bad channels in subject 51781c : ['S8_D4 760', 'S8_D4 850']
# Bad channels in subject 51381c : ['S5_D3 760', 'S5_D3 850']
# Bad channels in subject 51381p : ['S8_D4 760', 'S8_D4 850']
# Bad channels in subject 50261p : ['S1_D1 760', 'S1_D1 850', 'S7_D4 760', 'S7_D4 850', 'S8_D4 760', 'S8_D4 850']
# Bad channels in subject 50371p : ['S1_D1 760', 'S1_D1 850', 'S3_D2 760', 'S3_D2 850', 'S8_D4 760', 'S8_D4 850']
# Bad channels in subject 51141c : ['S2_D1 760', 'S2_D1 850']
# Bad channels in subject 51701p : ['S2_D1 760', 'S2_D1 850', 'S2_D2 760', 'S2_D2 850', 'S3_D2 760', 'S3_D2 850']
# Bad channels in subject 50001p : ['S5_D3 760', 'S5_D3 850']
# Bad channels in subject 51181c : ['S5_D3 760', 'S5_D3 850', 'S6_D3 760', 'S6_D3 850']
# Bad channels in subject 51181p : ['S1_D1 760', 'S1_D1 850']
# Bad channels in subject 51801c : ['S6_D3 760', 'S6_D3 850']
# Bad channels in subject 50992c : ['S2_D2 760', 'S2_D2 850']
# Bad channels in subject 50221p : ['S1_D1 760', 'S1_D1 850']
# Bad channels in subject 51041c : ['S1_D1 760', 'S1_D1 850', 'S3_D2 760', 'S3_D2 850']
# Bad channels in subject 50451p : ['S8_D4 760', 'S8_D4 850']
# Bad channels in subject 51011c : ['S2_D2 760', 'S2_D2 850']
# Bad channels in subject 51441c : ['S5_D3 760', 'S5_D3 850']
# Bad channels in subject 51263c : ['S2_D2 760', 'S2_D2 850']
# Bad channels in subject 51411p : ['S1_D1 760', 'S1_D1 850', 'S2_D1 760', 'S2_D1 850', 'S8_D4 760', 'S8_D4 850']
# Bad channels in subject 50701p : ['S1_D1 760', 'S1_D1 850', 'S2_D1 760', 'S2_D1 850', 'S3_D2 760', 'S3_D2 850', 'S6_D3 760', 'S6_D3 850', 'S8_D4 760', 'S8_D4 850']
# Bad channels in subject 50211p : ['S1_D1 760', 'S1_D1 850', 'S2_D1 760', 'S2_D1 850', 'S3_D2 760', 'S3_D2 850', 'S6_D3 760', 'S6_D3 850', 'S8_D4 760', 'S8_D4 850']
# Bad channels in subject 51431p : ['S1_D1 760', 'S1_D1 850', 'S2_D1 760', 'S2_D1 850', 'S2_D2 760', 'S2_D2 850', 'S3_D2 760', 'S3_D2 850', 'S6_D3 760', 'S6_D3 850', 'S8_D4 760', 'S8_D4 850']
# Bad channels in subject 51662p : ['S8_D4 760', 'S8_D4 850']
# Bad channels in subject 50381p : ['S1_D1 760', 'S1_D1 850']
# Bad channels in subject 50711p : ['S1_D1 760', 'S1_D1 850', 'S8_D4 760', 'S8_D4 850']
# Bad channels in subject 51741c : ['S1_D1 760', 'S1_D1 850', 'S2_D2 760', 'S2_D2 850', 'S3_D2 760', 'S3_D2 850', 'S5_D3 760', 'S5_D3 850', 'S6_D3 760', 'S6_D3 850', 'S7_D3 760', 'S7_D3 850']
# Bad channels in subject 51741p : ['S8_D4 760', 'S8_D4 850']
# Bad channels in subject 50771p : ['S1_D1 760', 'S1_D1 850']
# Bad channels in subject 51091c : ['S5_D3 760', 'S5_D3 850']
# Bad channels in subject 50031p : ['S8_D4 760', 'S8_D4 850']
# Bad channels in subject 50111p : ['S1_D1 760', 'S1_D1 850', 'S2_D1 760', 'S2_D1 850', 'S3_D2 760', 'S3_D2 850', 'S8_D4 760', 'S8_D4 850']
# Bad channels in subject 50071p : ['S1_D1 760', 'S1_D1 850']
# Bad channels in subject 51491p : ['S8_D4 760', 'S8_D4 850']
# Bad channels in subject 50591p : ['S1_D1 760', 'S1_D1 850', 'S8_D4 760', 'S8_D4 850']
# Bad channels in subject 51281c : ['S5_D3 760', 'S5_D3 850']
# Bad channels in subject 51281p : ['S5_D3 760', 'S5_D3 850', 'S6_D3 760', 'S6_D3 850']
# Bad channels in subject 51421c : ['S3_D2 760', 'S3_D2 850']
# Bad channels in subject 51421p : ['S2_D2 760', 'S2_D2 850', 'S3_D2 760', 'S3_D2 850', 'S6_D3 760', 'S6_D3 850', 'S7_D3 760', 'S7_D3 850', 'S7_D4 760', 'S7_D4 850', 'S8_D4 760', 'S8_D4 850']
# Bad channels in subject 50091c : ['S3_D2 760', 'S3_D2 850']
# Bad channels in subject 50091p : ['S2_D2 760', 'S2_D2 850', 'S3_D2 760', 'S3_D2 850', 'S6_D3 760', 'S6_D3 850', 'S7_D3 760', 'S7_D3 850', 'S7_D4 760', 'S7_D4 850', 'S8_D4 760', 'S8_D4 850']
# Bad channels in subject 50321c : ['S3_D2 760', 'S3_D2 850']
# Bad channels in subject 51251c : ['S5_D3 760', 'S5_D3 850']
# Bad channels in subject 51081p : ['S8_D4 760', 'S8_D4 850']
# Bad channels in subject 50781c : ['S8_D4 760', 'S8_D4 850']
# Bad channels in subject 50781p : ['S1_D1 760', 'S1_D1 850', 'S2_D2 760', 'S2_D2 850', 'S8_D4 760', 'S8_D4 850']
# Bad channels in subject 50491p : ['S1_D1 760', 'S1_D1 850', 'S8_D4 760', 'S8_D4 850']
# Bad channels in subject 51481p : ['S1_D1 760', 'S1_D1 850']
# Bad channels in subject 50121c : ['S3_D2 760', 'S3_D2 850']
# Bad channels in subject 51301c : ['S5_D3 760', 'S5_D3 850']
# Bad channels in subject 51301p : ['S6_D3 760', 'S6_D3 850']
# Bad channels in subject 51341c : ['S5_D3 760', 'S5_D3 850']
# Bad channels in subject 51341p : ['S6_D3 760', 'S6_D3 850', 'S8_D4 760', 'S8_D4 850']
# Bad channels in subject 50721p : ['S1_D1 760', 'S1_D1 850', 'S3_D2 760', 'S3_D2 850', 'S4_D2 760', 'S4_D2 850']
# Bad channels in subject 51001c : ['S2_D2 760', 'S2_D2 850']
# Bad channels in subject 51261c : ['S3_D2 760', 'S3_D2 850']
# Bad channels in subject 50032p : ['S7_D3 760', 'S7_D3 850', 'S7_D4 760', 'S7_D4 850', 'S8_D4 760', 'S8_D4 850']
# Bad channels in subject 50021p : ['S1_D1 760', 'S1_D1 850', 'S7_D3 760', 'S7_D3 850', 'S7_D4 760', 'S7_D4 850', 'S8_D4 760', 'S8_D4 850']
# Bad channels in subject 50761p : ['S2_D2 760', 'S2_D2 850']
# Bad channels in subject 50342p : ['S1_D1 760', 'S1_D1 850', 'S7_D3 760', 'S7_D3 850']
# Bad channels in subject 50971c : ['S1_D1 760', 'S1_D1 850', 'S8_D4 760', 'S8_D4 850']
# Bad channels in subject 50971p : ['S1_D1 760', 'S1_D1 850', 'S2_D1 760', 'S2_D1 850', 'S2_D2 760', 'S2_D2 850']
# Bad channels in subject 50802p : ['S1_D1 760', 'S1_D1 850']
# Bad channels in subject 50861p : ['S8_D4 760', 'S8_D4 850']
# /tmp/ipykernel_43843/1016720289.py:16: RuntimeWarning: Negative intensities encountered. Setting to abs(x)
#   raw_od = mne.preprocessing.nirs.optical_density(scan)
# Bad channels in subject 51391c : ['S5_D3 760', 'S5_D3 850']
# Bad channels in subject 50531p : ['S8_D4 760', 'S8_D4 850']
# Bad channels in subject 51791c : ['S6_D3 760', 'S6_D3 850']
# Bad channels in subject 51791p : ['S3_D2 760', 'S3_D2 850', 'S6_D3 760', 'S6_D3 850']
# Bad channels in subject 50341c : ['S1_D1 760', 'S1_D1 850']
# Bad channels in subject 50341p : ['S1_D1 760', 'S1_D1 850', 'S8_D4 760', 'S8_D4 850']
# Bad channels in subject 51382c : ['S5_D3 760', 'S5_D3 850']
# Bad channels in subject 51382p : ['S8_D4 760', 'S8_D4 850']
# Bad channels in subject 51171p : ['S1_D1 760', 'S1_D1 850']
# Bad channels in subject 51631p : ['S6_D3 760', 'S6_D3 850']
# Bad channels in subject 51361c : ['S5_D3 760', 'S5_D3 850']
# Bad channels in subject 50081c : ['S5_D3 760', 'S5_D3 850']
# Bad channels in subject 50942p : ['S8_D4 760', 'S8_D4 850']
# Bad channels in subject 50231p : ['S7_D3 760', 'S7_D3 850']
# Bad channels in subject 50131c : ['S3_D2 760', 'S3_D2 850', 'S6_D3 760', 'S6_D3 850', 'S7_D4 760', 'S7_D4 850', 'S8_D4 760', 'S8_D4 850']
# /tmp/ipykernel_43843/1016720289.py:16: RuntimeWarning: Negative intensities encountered. Setting to abs(x)
#   raw_od = mne.preprocessing.nirs.optical_density(scan)
# /tmp/ipykernel_43843/1016720289.py:16: RuntimeWarning: Negative intensities encountered. Setting to abs(x)
#   raw_od = mne.preprocessing.nirs.optical_density(scan)
# Bad channels in subject 51831p : ['S1_D1 760', 'S1_D1 850', 'S2_D1 760', 'S2_D1 850']
# Bad channels in subject 51422c : ['S7_D3 760', 'S7_D3 850', 'S7_D4 760', 'S7_D4 850']
# Bad channels in subject 51422p : ['S1_D1 760', 'S1_D1 850', 'S2_D1 760', 'S2_D1 850', 'S2_D2 760', 'S2_D2 850', 'S3_D2 760', 'S3_D2 850', 'S4_D2 760', 'S4_D2 850', 'S6_D3 760', 'S6_D3 850', 'S7_D3 760', 'S7_D3 850', 'S7_D4 760', 'S7_D4 850', 'S8_D4 760', 'S8_D4 850']
# Bad channels in subject 50691c : ['S8_D4 760', 'S8_D4 850']
# Bad channels in subject 50801p : ['S1_D1 760', 'S1_D1 850']
# Bad channels in subject 51851c : ['S8_D4 760', 'S8_D4 850']
# Bad channels in subject 51851p : ['S7_D3 760', 'S7_D3 850']
# Bad channels in subject 51371c : ['S5_D3 760', 'S5_D3 850']
# Bad channels in subject 51371p : ['S3_D2 760', 'S3_D2 850']
# Bad channels in subject 50921p : ['S8_D4 760', 'S8_D4 850']
# Bad channels in subject 51501p : ['S1_D1 760', 'S1_D1 850']

# %%
#Creating a dictionary variable to store bad channels for later
bad_channels_dict = {}

for dscan in pps:
    
    for scan in dscan:
        
        bads = scan.info['bads']
        bad_channels_dict[scan.info['subject_info']['his_id']] = \
            bads

# %%
#Count of number of bad channels to report in any future manuscript (total channels overall is "Number of subjects x 20")
len(bad_channels_dict)
# Out:
# 310

# %%
bad_channels_dict
# Out:
# {'50501c': [],
#  '50501p': [],
#  '51781c': ['S8_D4 hbo', 'S8_D4 hbr'],
#  '51781p': [],
#  '51651c': [],
#  '51651p': [],
#  '51521c': [],
#  '51521p': [],
#  '50962c': [],
#  '50962p': [],
#  '51331c': [],
#  '51331p': [],
#  '50601c': [],
#  '50601p': [],
#  '51381c': ['S5_D3 hbo', 'S5_D3 hbr'],
#  '51381p': ['S8_D4 hbo', 'S8_D4 hbr'],
#  '51082c': [],
#  '51082p': [],
#  '51461c': [],
#  '51461p': [],
#  '50831c': [],
#  '50831p': [],
#  '50261c': [],
#  '50261p': ['S1_D1 hbo',
#   'S1_D1 hbr',
#   'S7_D4 hbo',
#   'S7_D4 hbr',
#   'S8_D4 hbo',
#   'S8_D4 hbr'],
#  '51471c': [],
#  '51471p': [],
#  '50371c': [],
#  '50371p': ['S1_D1 hbo',
#   'S1_D1 hbr',
#   'S3_D2 hbo',
#   'S3_D2 hbr',
#   'S8_D4 hbo',
#   'S8_D4 hbr'],
#  '51141c': ['S2_D1 hbo', 'S2_D1 hbr'],
#  '51141p': [],
#  '51701c': [],
#  '51701p': ['S2_D1 hbo',
#   'S2_D1 hbr',
#   'S2_D2 hbo',
#   'S2_D2 hbr',
#   'S3_D2 hbo',
#   'S3_D2 hbr'],
#  '50001c': [],
#  '50001p': ['S5_D3 hbo', 'S5_D3 hbr'],
#  '50291c': [],
#  '50291p': [],
#  '51181c': ['S5_D3 hbo', 'S5_D3 hbr', 'S6_D3 hbo', 'S6_D3 hbr'],
#  '51181p': ['S1_D1 hbo', 'S1_D1 hbr'],
#  '51801c': ['S6_D3 hbo', 'S6_D3 hbr'],
#  '51801p': [],
#  '50992c': ['S2_D2 hbo', 'S2_D2 hbr'],
#  '50992p': [],
#  '50221c': [],
#  '50221p': ['S1_D1 hbo', 'S1_D1 hbr'],
#  '51041c': ['S1_D1 hbo', 'S1_D1 hbr', 'S3_D2 hbo', 'S3_D2 hbr'],
#  '51041p': [],
#  '50731c': [],
#  '50731p': [],
#  '50451c': [],
#  '50451p': ['S8_D4 hbo', 'S8_D4 hbr'],
#  '51011c': ['S2_D2 hbo', 'S2_D2 hbr'],
#  '51011p': [],
#  '51441c': ['S5_D3 hbo', 'S5_D3 hbr'],
#  '51441p': [],
#  '51021c': [],
#  '51021p': [],
#  '50961c': [],
#  '50961p': [],
#  '51841c': [],
#  '51841p': [],
#  '50991c': [],
#  '50991p': [],
#  '51263c': ['S2_D2 hbo', 'S2_D2 hbr'],
#  '51263p': [],
#  '50281c': [],
#  '50281p': [],
#  '51411c': [],
#  '51411p': ['S1_D1 hbo',
#   'S1_D1 hbr',
#   'S2_D1 hbo',
#   'S2_D1 hbr',
#   'S8_D4 hbo',
#   'S8_D4 hbr'],
#  '50503c': [],
#  '50503p': [],
#  '50592c': [],
#  '50592p': [],
#  '50701c': [],
#  '50701p': ['S1_D1 hbo',
#   'S1_D1 hbr',
#   'S2_D1 hbo',
#   'S2_D1 hbr',
#   'S3_D2 hbo',
#   'S3_D2 hbr',
#   'S6_D3 hbo',
#   'S6_D3 hbr',
#   'S8_D4 hbo',
#   'S8_D4 hbr'],
#  '50211c': [],
#  '50211p': ['S1_D1 hbo',
#   'S1_D1 hbr',
#   'S2_D1 hbo',
#   'S2_D1 hbr',
#   'S3_D2 hbo',
#   'S3_D2 hbr',
#   'S6_D3 hbo',
#   'S6_D3 hbr',
#   'S8_D4 hbo',
#   'S8_D4 hbr'],
#  '51431c': [],
#  '51431p': ['S1_D1 hbo',
#   'S1_D1 hbr',
#   'S2_D1 hbo',
#   'S2_D1 hbr',
#   'S2_D2 hbo',
#   'S2_D2 hbr',
#   'S3_D2 hbo',
#   'S3_D2 hbr',
#   'S6_D3 hbo',
#   'S6_D3 hbr',
#   'S8_D4 hbo',
#   'S8_D4 hbr'],
#  '51662c': [],
#  '51662p': ['S8_D4 hbo', 'S8_D4 hbr'],
#  '50841c': [],
#  '50841p': [],
#  '51691c': [],
#  '51691p': [],
#  '50581c': [],
#  '50581p': [],
#  '50422c': [],
#  '50422p': [],
#  '50381c': [],
#  '50381p': ['S1_D1 hbo', 'S1_D1 hbr'],
#  '50711c': [],
#  '50711p': ['S1_D1 hbo', 'S1_D1 hbr', 'S8_D4 hbo', 'S8_D4 hbr'],
#  '51741c': ['S1_D1 hbo',
#   'S1_D1 hbr',
#   'S2_D2 hbo',
#   'S2_D2 hbr',
#   'S3_D2 hbo',
#   'S3_D2 hbr',
#   'S5_D3 hbo',
#   'S5_D3 hbr',
#   'S6_D3 hbo',
#   'S6_D3 hbr',
#   'S7_D3 hbo',
#   'S7_D3 hbr'],
#  '51741p': ['S8_D4 hbo', 'S8_D4 hbr'],
#  '51211c': [],
#  '51211p': [],
#  '50771c': [],
#  '50771p': ['S1_D1 hbo', 'S1_D1 hbr'],
#  '51091c': ['S5_D3 hbo', 'S5_D3 hbr'],
#  '51091p': [],
#  '50031c': [],
#  '50031p': ['S8_D4 hbo', 'S8_D4 hbr'],
#  '51131c': [],
#  '51131p': [],
#  '51231c': [],
#  '51231p': [],
#  '50331c': [],
#  '50331p': [],
#  '51591c': [],
#  '51591p': [],
#  '50111c': [],
#  '50111p': ['S1_D1 hbo',
#   'S1_D1 hbr',
#   'S2_D1 hbo',
#   'S2_D1 hbr',
#   'S3_D2 hbo',
#   'S3_D2 hbr',
#   'S8_D4 hbo',
#   'S8_D4 hbr'],
#  '50071c': [],
#  '50071p': ['S1_D1 hbo', 'S1_D1 hbr'],
#  '51491c': [],
#  '51491p': ['S8_D4 hbo', 'S8_D4 hbr'],
#  '51191c': [],
#  '51191p': [],
#  '50591c': [],
#  '50591p': ['S1_D1 hbo', 'S1_D1 hbr', 'S8_D4 hbo', 'S8_D4 hbr'],
#  '51051c': [],
#  '51051p': [],
#  '50391c': [],
#  '50391p': [],
#  '51281c': ['S5_D3 hbo', 'S5_D3 hbr'],
#  '51281p': ['S5_D3 hbo', 'S5_D3 hbr', 'S6_D3 hbo', 'S6_D3 hbr'],
#  '51731c': [],
#  '51731p': [],
#  '51421c': ['S3_D2 hbo', 'S3_D2 hbr'],
#  '51421p': ['S2_D2 hbo',
#   'S2_D2 hbr',
#   'S3_D2 hbo',
#   'S3_D2 hbr',
#   'S6_D3 hbo',
#   'S6_D3 hbr',
#   'S7_D3 hbo',
#   'S7_D3 hbr',
#   'S7_D4 hbo',
#   'S7_D4 hbr',
#   'S8_D4 hbo',
#   'S8_D4 hbr'],
#  '50091c': ['S3_D2 hbo', 'S3_D2 hbr'],
#  '50091p': ['S2_D2 hbo',
#   'S2_D2 hbr',
#   'S3_D2 hbo',
#   'S3_D2 hbr',
#   'S6_D3 hbo',
#   'S6_D3 hbr',
#   'S7_D3 hbo',
#   'S7_D3 hbr',
#   'S7_D4 hbo',
#   'S7_D4 hbr',
#   'S8_D4 hbo',
#   'S8_D4 hbr'],
#  '50321c': ['S3_D2 hbo', 'S3_D2 hbr'],
#  '50321p': [],
#  '51262c': [],
#  '51262p': [],
#  '51271c': [],
#  '51271p': [],
#  '50401c': [],
#  '50401p': [],
#  '50552c': [],
#  '50552p': [],
#  '51052c': [],
#  '51052p': [],
#  '51251c': ['S5_D3 hbo', 'S5_D3 hbr'],
#  '51251p': [],
#  '51081c': [],
#  '51081p': ['S8_D4 hbo', 'S8_D4 hbr'],
#  '50781c': ['S8_D4 hbo', 'S8_D4 hbr'],
#  '50781p': ['S1_D1 hbo',
#   'S1_D1 hbr',
#   'S2_D2 hbo',
#   'S2_D2 hbr',
#   'S8_D4 hbo',
#   'S8_D4 hbr'],
#  '50491c': [],
#  '50491p': ['S1_D1 hbo', 'S1_D1 hbr', 'S8_D4 hbo', 'S8_D4 hbr'],
#  '50421c': [],
#  '50421p': [],
#  '50481c': [],
#  '50481p': [],
#  '51481c': [],
#  '51481p': ['S1_D1 hbo', 'S1_D1 hbr'],
#  '51212c': [],
#  '51212p': [],
#  '51121c': [],
#  '51121p': [],
#  '51161c': [],
#  '51161p': [],
#  '51201c': [],
#  '51201p': [],
#  '51221c': [],
#  '51221p': [],
#  '50121c': ['S3_D2 hbo', 'S3_D2 hbr'],
#  '50121p': [],
#  '50752c': [],
#  '50752p': [],
#  '51301c': ['S5_D3 hbo', 'S5_D3 hbr'],
#  '51301p': ['S6_D3 hbo', 'S6_D3 hbr'],
#  '51341c': ['S5_D3 hbo', 'S5_D3 hbr'],
#  '51341p': ['S6_D3 hbo', 'S6_D3 hbr', 'S8_D4 hbo', 'S8_D4 hbr'],
#  '50361c': [],
#  '50361p': [],
#  '50322c': [],
#  '50322p': [],
#  '50241c': [],
#  '50241p': [],
#  '50721c': [],
#  '50721p': ['S1_D1 hbo',
#   'S1_D1 hbr',
#   'S3_D2 hbo',
#   'S3_D2 hbr',
#   'S4_D2 hbo',
#   'S4_D2 hbr'],
#  '51001c': ['S2_D2 hbo', 'S2_D2 hbr'],
#  '51001p': [],
#  '50611c': [],
#  '50611p': [],
#  '51261c': ['S3_D2 hbo', 'S3_D2 hbr'],
#  '51261p': [],
#  '50032c': [],
#  '50032p': ['S7_D3 hbo',
#   'S7_D3 hbr',
#   'S7_D4 hbo',
#   'S7_D4 hbr',
#   'S8_D4 hbo',
#   'S8_D4 hbr'],
#  '50021c': [],
#  '50021p': ['S1_D1 hbo',
#   'S1_D1 hbr',
#   'S7_D3 hbo',
#   'S7_D3 hbr',
#   'S7_D4 hbo',
#   'S7_D4 hbr',
#   'S8_D4 hbo',
#   'S8_D4 hbr'],
#  '50761c': [],
#  '50761p': ['S2_D2 hbo', 'S2_D2 hbr'],
#  '50342c': [],
#  '50342p': ['S1_D1 hbo', 'S1_D1 hbr', 'S7_D3 hbo', 'S7_D3 hbr'],
#  '50971c': ['S1_D1 hbo', 'S1_D1 hbr', 'S8_D4 hbo', 'S8_D4 hbr'],
#  '50971p': ['S1_D1 hbo',
#   'S1_D1 hbr',
#   'S2_D1 hbo',
#   'S2_D1 hbr',
#   'S2_D2 hbo',
#   'S2_D2 hbr'],
#  '50351c': [],
#  '50351p': [],
#  '50911c': [],
#  '50911p': [],
#  '50981c': [],
#  '50981p': [],
#  '50891c': [],
#  '50891p': [],
#  '51601c': [],
#  '51601p': [],
#  '51702c': [],
#  '51702p': [],
#  '50802c': [],
#  '50802p': ['S1_D1 hbo', 'S1_D1 hbr'],
#  '50832c': [],
#  '50832p': [],
#  '50861c': [],
#  '50861p': ['S8_D4 hbo', 'S8_D4 hbr'],
#  '51391c': ['S5_D3 hbo', 'S5_D3 hbr'],
#  '51391p': [],
#  '50621c': [],
#  '50621p': [],
#  '50531c': [],
#  '50531p': ['S8_D4 hbo', 'S8_D4 hbr'],
#  '50092c': [],
#  '50092p': [],
#  '51511c': [],
#  '51511p': [],
#  '50461c': [],
#  '50461p': [],
#  '51791c': ['S6_D3 hbo', 'S6_D3 hbr'],
#  '51791p': ['S3_D2 hbo', 'S3_D2 hbr', 'S6_D3 hbo', 'S6_D3 hbr'],
#  '50341c': ['S1_D1 hbo', 'S1_D1 hbr'],
#  '50341p': ['S1_D1 hbo', 'S1_D1 hbr', 'S8_D4 hbo', 'S8_D4 hbr'],
#  '51711c': [],
#  '51711p': [],
#  '51382c': ['S5_D3 hbo', 'S5_D3 hbr'],
#  '51382p': ['S8_D4 hbo', 'S8_D4 hbr'],
#  '51171c': [],
#  '51171p': ['S1_D1 hbo', 'S1_D1 hbr'],
#  '51571c': [],
#  '51571p': [],
#  '50431c': [],
#  '50431p': [],
#  '51631c': [],
#  '51631p': ['S6_D3 hbo', 'S6_D3 hbr'],
#  '50181c': [],
#  '50181p': [],
#  '50631c': [],
#  '50631p': [],
#  '50602c': [],
#  '50602p': [],
#  '51361c': ['S5_D3 hbo', 'S5_D3 hbr'],
#  '51361p': [],
#  '50081c': ['S5_D3 hbo', 'S5_D3 hbr'],
#  '50081p': [],
#  '50191c': [],
#  '50191p': [],
#  '51132c': [],
#  '51132p': [],
#  '50521c': [],
#  '50521p': [],
#  '50941c': [],
#  '50941p': [],
#  '51661c': [],
#  '51661p': [],
#  '50942c': [],
#  '50942p': ['S8_D4 hbo', 'S8_D4 hbr'],
#  '50231c': [],
#  '50231p': ['S7_D3 hbo', 'S7_D3 hbr'],
#  '50171c': [],
#  '50171p': [],
#  '50851c': [],
#  '50851p': [],
#  '50131c': ['S3_D2 hbo',
#   'S3_D2 hbr',
#   'S6_D3 hbo',
#   'S6_D3 hbr',
#   'S7_D4 hbo',
#   'S7_D4 hbr',
#   'S8_D4 hbo',
#   'S8_D4 hbr'],
#  '50131p': [],
#  '50532c': [],
#  '50532p': [],
#  '51831c': [],
#  '51831p': ['S1_D1 hbo', 'S1_D1 hbr', 'S2_D1 hbo', 'S2_D1 hbr'],
#  '51422c': ['S7_D3 hbo', 'S7_D3 hbr', 'S7_D4 hbo', 'S7_D4 hbr'],
#  '51422p': ['S1_D1 hbo',
#   'S1_D1 hbr',
#   'S2_D1 hbo',
#   'S2_D1 hbr',
#   'S2_D2 hbo',
#   'S2_D2 hbr',
#   'S3_D2 hbo',
#   'S3_D2 hbr',
#   'S4_D2 hbo',
#   'S4_D2 hbr',
#   'S6_D3 hbo',
#   'S6_D3 hbr',
#   'S7_D3 hbo',
#   'S7_D3 hbr',
#   'S7_D4 hbo',
#   'S7_D4 hbr',
#   'S8_D4 hbo',
#   'S8_D4 hbr'],
#  '50691c': ['S8_D4 hbo', 'S8_D4 hbr'],
#  '50691p': [],
#  '50502c': [],
#  '50502p': [],
#  '51751c': [],
#  '51751p': [],
#  '50811c': [],
#  '50811p': [],
#  '50251c': [],
#  '50251p': [],
#  '50801c': [],
#  '50801p': ['S1_D1 hbo', 'S1_D1 hbr'],
#  '51851c': ['S8_D4 hbo', 'S8_D4 hbr'],
#  '51851p': ['S7_D3 hbo', 'S7_D3 hbr'],
#  '50871c': [],
#  '50871p': [],
#  '51241c': [],
#  '51241p': [],
#  '51371c': ['S5_D3 hbo', 'S5_D3 hbr'],
#  '51371p': ['S3_D2 hbo', 'S3_D2 hbr'],
#  '50551c': [],
#  '50551p': [],
#  '50921c': [],
#  '50921p': ['S8_D4 hbo', 'S8_D4 hbr'],
#  '51652c': [],
#  '51652p': [],
#  '51501c': [],
#  '51501p': ['S1_D1 hbo', 'S1_D1 hbr']}

# %%
bad_channels_dict['50001c']
# Out:
# []

# %%
pps[7][0].info['subject_info']
# Out:
# {'his_id': '51381c',
#  'first_name': '51381',
#  'sex': 0 (FIFFV_SUBJ_SEX_UNKNOWN),
#  'birthday': (2022, 8, 1)}

# %%
# example plot for 2200 seconds
#can either plot all hbo channels or a single channel for a subject
pps[10][0].copy().pick(['hbo']).plot(duration=2000, scalings=0.001)
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
sampling_rate = pps[0][0].info['sfreq']
print(sampling_rate)
# Out:
# 7.8125

# %%
pps[152][0]
# Out:
# <RawNIRX | 50921_V0_fNIRS, 20 x 14855 (1901.3 s), ~2.3 MB, data loaded>

# %%
event_dict
# Out:
# {'Block 1': 1, 'Block 2': 2, 'Block 3': 3}

# %%
# make a dictionary where all of the epoch'd data will go
epoch_df = {}

# loop over the dyads in the preprocessed list
for dscan in pps:
    
    # February 9th 2023
    # Clayton update to prune subjects who have
    # >= 10 channels dropped from the SCI function during preprocessing
    max_bad = max([len(scan.info['bads']) for scan in dscan])
    # whichever number is higher ^, num. of channels dropped in
    # either parent or child
    
    if max_bad >= 10:
        for scan in dscan:
            sub_num = scan.info['subject_info']['his_id']
            print("Subject {} was dropped from further analysis.".format(sub_num))
        
        continue # skip this dyad
        # if max_bad is greater than or equal to 10
    
    # for each scan in the dyad
    for scan in dscan:
    
        # set their location in the epoch df to a dictionary
        epoch_df[scan.info['subject_info']['his_id']] = {}
    
#        for i, ROI in enumerate(ROIs.keys()):

        # loop over ROIs (channels here)
        for i, ROI in enumerate([ch for ch in scan.info['ch_names'] if "hbo" in ch]):
            
            epoch_df[scan.info['subject_info']['his_id']][ROI] = []
        
            # get their events and set block durations
            events, event_dict = mne.events_from_annotations(dscan[0], verbose=False)
            reject_criteria = dict(hbo=200e-6)
            tmin, puzzletmax, playtmax = -5, 105, 120
            
            # use the mne.Epochs function / object to generate epochs
            preplay_epochs = mne.Epochs(
                scan, # the scan object
                events, # its events
#                 picks=ROIs[ROI],
                picks=[ROI], # the channels
                event_id={list(event_dict.keys())[0]: list(event_dict.values())[0]}, # the first event key
                tmin=tmin, # epoch relative start time
                tmax=playtmax, # epoch relative end time
                baseline= (None, 0), # baseline window to subtract
#                 reject=reject_criteria,
                reject_by_annotation=True,
                detrend=1, # linear detrend
                verbose=False, 
                preload=False, # don't actually load it yet (saves memory)
                event_repeated='merge')
            
            epoch_df[scan.info['subject_info']['his_id']][ROI].append(preplay_epochs)
            
            puzzle_epochs = mne.Epochs(
                scan,
                events,
#                 picks=ROIs[ROI],
                picks=[ROI],
                event_id={list(event_dict.keys())[1]: list(event_dict.values())[1]},
                tmin=tmin,
                tmax=puzzletmax,
                baseline= (None, 0),
#                 reject=reject_criteria,
                reject_by_annotation=True,
                detrend=1,
                verbose=False,
                preload=False,
                event_repeated='merge')
            
            epoch_df[scan.info['subject_info']['his_id']][ROI].append(puzzle_epochs)
            
            postplay_epochs = mne.Epochs(
                scan,
                events,
#                 picks=ROIs[ROI],
                picks=[ROI],
                event_id={list(event_dict.keys())[2]: list(event_dict.values())[2]},
                tmin=tmin,
                tmax=playtmax,
                baseline=(None, 0),
#                 reject=reject_criteria,
                reject_by_annotation=True,
                detrend=1,
                verbose=False,
                preload=False,
                event_repeated='merge')
            
            epoch_df[scan.info['subject_info']['his_id']][ROI].append(postplay_epochs)
# Out:
# Subject 50701c was dropped from further analysis.
# Subject 50701p was dropped from further analysis.
# Subject 50211c was dropped from further analysis.
# Subject 50211p was dropped from further analysis.
# Subject 51431c was dropped from further analysis.
# Subject 51431p was dropped from further analysis.
# Subject 51741c was dropped from further analysis.
# Subject 51741p was dropped from further analysis.
# Subject 51421c was dropped from further analysis.
# Subject 51421p was dropped from further analysis.
# Subject 50091c was dropped from further analysis.
# Subject 50091p was dropped from further analysis.
# Subject 51422c was dropped from further analysis.
# Subject 51422p was dropped from further analysis.

# %%
# here is the way to access information in the epoch dictionary

# %%
#Will tell you how many dyads are retaining for further analyses (not sure if we need this for the current CARE script)
len([sub for sub in epoch_df.keys() if "c" in sub])
# Out:
# 148

# %%
# a single subject 
epoch_df['51331c']
# Out:
# {'S1_D1 hbo': [<Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 1': 4>,
#   <Epochs |  4 events (good & bad), -4.992 - 104.96 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 2': 4>,
#   <Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 3': 4>],
#  'S2_D1 hbo': [<Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 1': 4>,
#   <Epochs |  4 events (good & bad), -4.992 - 104.96 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 2': 4>,
#   <Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 3': 4>],
#  'S2_D2 hbo': [<Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 1': 4>,
#   <Epochs |  4 events (good & bad), -4.992 - 104.96 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 2': 4>,
#   <Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 3': 4>],
#  'S3_D2 hbo': [<Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 1': 4>,
#   <Epochs |  4 events (good & bad), -4.992 - 104.96 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 2': 4>,
#   <Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 3': 4>],
#  'S4_D2 hbo': [<Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 1': 4>,
#   <Epochs |  4 events (good & bad), -4.992 - 104.96 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 2': 4>,
#   <Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 3': 4>],
#  'S5_D3 hbo': [<Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 1': 4>,
#   <Epochs |  4 events (good & bad), -4.992 - 104.96 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 2': 4>,
#   <Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 3': 4>],
#  'S6_D3 hbo': [<Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 1': 4>,
#   <Epochs |  4 events (good & bad), -4.992 - 104.96 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 2': 4>,
#   <Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 3': 4>],
#  'S7_D3 hbo': [<Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 1': 4>,
#   <Epochs |  4 events (good & bad), -4.992 - 104.96 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 2': 4>,
#   <Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 3': 4>],
#  'S7_D4 hbo': [<Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 1': 4>,
#   <Epochs |  4 events (good & bad), -4.992 - 104.96 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 2': 4>,
#   <Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 3': 4>],
#  'S8_D4 hbo': [<Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 1': 4>,
#   <Epochs |  4 events (good & bad), -4.992 - 104.96 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 2': 4>,
#   <Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 3': 4>]}

# %%
# a specific channel from the subject
epoch_df['50531c']['S1_D1 hbo']
# Out:
# [<Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#   'Block 1': 4>,
#  <Epochs |  4 events (good & bad), -4.992 - 104.96 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#   'Block 2': 4>,
#  <Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#   'Block 3': 4>]

# %%
# a specific block at that subject / channel, in this case the first (0) is pre-play, second (1) is puzzle, and second (2) is post-play
#ask Susan about baseline 
epoch_df['50531c']['S1_D1 hbo'][2]
# Out:
# <Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#  'Block 3': 4>

# %%
# a specific iteration (trial) of that block at that subject / channel, in this case the first (0) is pre-play, we look at the 4th (3) iteration of the block
#120 sec duration of individual trial/iteration
epoch_df['50001c']['S1_D1 hbo'][0][3]
# Out:
# <Epochs |  1 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#  'Block 1': 1>

# %%
event_dict
# Out:
# {'Block 1': 1, 'Block 2': 2, 'Block 3': 3}

# %%
# example WCT between a real dyad, puzzle block (1), iteration 0 (0)
WCT, aWCT, coi, freqs, sig95 = mne_wavelet_coherence_transform(
    epoch_df['50531p']['S1_D1 hbo'][1][0].copy(),
    epoch_df['50531c']['S1_D1 hbo'][1][0].copy(),
    plot=True)

# same WCT but a random false dyad
WCT, aWCT, coi, freqs, sig95 = mne_wavelet_coherence_transform(
    epoch_df['50531p']['S1_D1 hbo'][1][0].copy(),
    epoch_df['50251c']['S1_D1 hbo'][1][0].copy(),
    plot=True)

# %%
# list out all the subjects in the epoch df
epoch_df.keys()
# Out:
# dict_keys(['50501c', '50501p', '51781c', '51781p', '51651c', '51651p', '51521c', '51521p', '50962c', '50962p', '51331c', '51331p', '50601c', '50601p', '51381c', '51381p', '51082c', '51082p', '51461c', '51461p', '50831c', '50831p', '50261c', '50261p', '51471c', '51471p', '50371c', '50371p', '51141c', '51141p', '51701c', '51701p', '50001c', '50001p', '50291c', '50291p', '51181c', '51181p', '51801c', '51801p', '50992c', '50992p', '50221c', '50221p', '51041c', '51041p', '50731c', '50731p', '50451c', '50451p', '51011c', '51011p', '51441c', '51441p', '51021c', '51021p', '50961c', '50961p', '51841c', '51841p', '50991c', '50991p', '51263c', '51263p', '50281c', '50281p', '51411c', '51411p', '50503c', '50503p', '50592c', '50592p', '51662c', '51662p', '50841c', '50841p', '51691c', '51691p', '50581c', '50581p', '50422c', '50422p', '50381c', '50381p', '50711c', '50711p', '51211c', '51211p', '50771c', '50771p', '51091c', '51091p', '50031c', '50031p', '51131c', '51131p', '51231c', '51231p', '50331c', '50331p', '51591c', '51591p', '50111c', '50111p', '50071c', '50071p', '51491c', '51491p', '51191c', '51191p', '50591c', '50591p', '51051c', '51051p', '50391c', '50391p', '51281c', '51281p', '51731c', '51731p', '50321c', '50321p', '51262c', '51262p', '51271c', '51271p', '50401c', '50401p', '50552c', '50552p', '51052c', '51052p', '51251c', '51251p', '51081c', '51081p', '50781c', '50781p', '50491c', '50491p', '50421c', '50421p', '50481c', '50481p', '51481c', '51481p', '51212c', '51212p', '51121c', '51121p', '51161c', '51161p', '51201c', '51201p', '51221c', '51221p', '50121c', '50121p', '50752c', '50752p', '51301c', '51301p', '51341c', '51341p', '50361c', '50361p', '50322c', '50322p', '50241c', '50241p', '50721c', '50721p', '51001c', '51001p', '50611c', '50611p', '51261c', '51261p', '50032c', '50032p', '50021c', '50021p', '50761c', '50761p', '50342c', '50342p', '50971c', '50971p', '50351c', '50351p', '50911c', '50911p', '50981c', '50981p', '50891c', '50891p', '51601c', '51601p', '51702c', '51702p', '50802c', '50802p', '50832c', '50832p', '50861c', '50861p', '51391c', '51391p', '50621c', '50621p', '50531c', '50531p', '50092c', '50092p', '51511c', '51511p', '50461c', '50461p', '51791c', '51791p', '50341c', '50341p', '51711c', '51711p', '51382c', '51382p', '51171c', '51171p', '51571c', '51571p', '50431c', '50431p', '51631c', '51631p', '50181c', '50181p', '50631c', '50631p', '50602c', '50602p', '51361c', '51361p', '50081c', '50081p', '50191c', '50191p', '51132c', '51132p', '50521c', '50521p', '50941c', '50941p', '51661c', '51661p', '50942c', '50942p', '50231c', '50231p', '50171c', '50171p', '50851c', '50851p', '50131c', '50131p', '50532c', '50532p', '51831c', '51831p', '50691c', '50691p', '50502c', '50502p', '51751c', '51751p', '50811c', '50811p', '50251c', '50251p', '50801c', '50801p', '51851c', '51851p', '50871c', '50871p', '51241c', '51241p', '51371c', '51371p', '50551c', '50551p', '50921c', '50921p', '51652c', '51652p', '51501c', '51501p'])

# %%
# delete things we don't need anymore to save memory
del scans
del pps

# %%
import random

# %%
# make a new dictionary where the synchrony values will be stored
sync_df = {}
block_types = ['Block 1', 'Block 2', 'Block 3']
block_names = ['Pre-Play', 'Puzzle', 'Post-Puzzle']
trials = ['Trial 1', 'Trial 2', 'Trial 3', 'Trial 4']
perm_df = {}

# THIS TAKES A REALLY LONG TIME TO COMPUTE. AROUND 14 HOURS ON A DECENT NETWORK
# SKIP DOWN TO USE THE SAVED VERSIONS!

#real vs single false dyad test of a myriad of real and fake dyad pairs

# for every parent subject
for parent in tqdm([sub for sub in sorted(epoch_df.keys()) if "p" in sub]):
    sync_df[parent] = {}
    perm_df[parent] = []
    
    # pick two children, one real and one random
    children = []
    
#     children.append(parent.replace("p", "c")) # real child
    
    # random sample of N children
    # could be repeated, could be the real dyad 
    randoms = random.choices(
        [sub for sub in epoch_df.keys() if "c" in sub],
        k=999) # N of random 
    # randoms = list(randoms).insert(0, parent.replace("p", "c"))
    perm_df[parent] = list(randoms)
    
    # only going to do synchrony once per kid
    # we can count # of repeats from perm_df[parent]
    for child in list(set(randoms)):
        children.append(child)
    
    # old version that just does 1 random non-real child per parent
#     children.append(
#         random.choice([sub for sub in epoch_df.keys() if "c" in sub \
#             and parent.replace("p", "") not in sub])) # random pick
    
    # loop over these 2 selected children (1 real, N random)
    for child in children:
        
        # and make them a location in the sync dictionary under this parent
        sync_df[parent][child] = {}
        
        # for every block type (pre-play, puzzle, post-play)
        for block_num, block in enumerate(block_types):
            
            # make this parent/child combo a location for this block type, also a dictionary
            sync_df[parent][child][block] = {}
                
            # for each channel available with this subject (not dropped)
            for ch in epoch_df[parent].keys():

                # our sync value is going to go here
                # sync_df[parent][child][block][ch]
                # i.e. averaging over the 4 block iterations

                # so start keeping track of values to average now
                pc_wcts = []

                # load in their epoched data for this subject / channel / block
                p_epoch = epoch_df[parent][ch][block_num].load_data()
                c_epoch = epoch_df[child][ch][block_num].load_data()

                # for each iteration of this block (max 4)
                for block_it in np.arange(0, np.min([
                    len(p_epoch),
                    len(c_epoch)])):

                    # try to do the WCT with these epochs
                    try:
                        sync_df[parent][child][block][f'Trial {block_it + 1}'] = {}
                        WCT, aWCT, coi, freqs, sig95 = mne_wavelet_coherence_transform(
                            p_epoch[block_it],
                            c_epoch[block_it],
                            plot=True if "S5_D3" in ch else False, # save plots but only for some random channel because otherwise it's an insane amount
                            fig_fname=f"/data/perlman/moochie/analysis/eDOC_NARSAD/sync_figs/{parent}_{child}_{ch.replace(' ', '_')}_{block_num}_{block_it}.png")

                        # make values outside COI = np.nan
                        nanWCT = WCT
                        for t in range(nanWCT.shape[1]):
                            nanWCT[np.where(freqs>coi[t]), t] = np.nan
                        # also set to nan outside frequencies of interest

                        # TASK RELATED FREQUENCIES ARE ARBITRARILY DETERMINED here
                        WCT[(2>(1/freqs))|((1/freqs)>13), :] = np.nan

                        # between periods of 2s and 13s (.08 -.5 Hz; flip for sec) which is based on Reindl et al 2018 paper (in Reindl study a single trial typcially took 5-8 sec)
                        #also in Reindl paper, significant coherence values were identifed above .65 (can be between 0 and 1)


                        # average inside cone of influence
                        # and within values from freq range determined above
                        sync_df[parent][child][block][f'Trial {block_it + 1}'][ch] = np.nanmean(nanWCT)
                    # if anything with the WCT fails, say so
                    except:
                        print(f"Fail @ parent {parent}, child {child}, block {block}, channel {ch}, block it {block_it}")
#                 print(np.average(pc_wcts))
# Out:
#   3%|▉                                   | 4/148 [1:26:12<51:44:43, 1293.63s/it]

# %%
sync_df

# %%
# del sync_df['51391p']

# %%
list(sync_df['50861p']['50861c']['Block 1']['Trial 1'].values())
# Out:
# [0.2575046347183404,
#  0.268589722137367,
#  0.2488316996514053,
#  0.26258190975576384,
#  0.2366100255867215,
#  0.2777836239347354,
#  0.24503653180612284,
#  0.21384750685228418,
#  0.24571166617825915,
#  0.21856564299673278]

# %%
#important to set channels here
channels = epoch_df[parent].keys()

# %%
channels
# Out:
# dict_keys(['S1_D1 hbo', 'S2_D1 hbo', 'S2_D2 hbo', 'S3_D2 hbo', 'S4_D2 hbo', 'S5_D3 hbo', 'S6_D3 hbo', 'S7_D3 hbo', 'S7_D4 hbo', 'S8_D4 hbo'])

# %%
epoch_df['51382p']
# Out:
# {'S1_D1 hbo': [<Epochs |  1 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    '8.0': 1>,
#   <Epochs |  3 events (good & bad), -4.992 - 104.96 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 1': 3>,
#   <Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 2': 4>],
#  'S2_D1 hbo': [<Epochs |  1 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    '8.0': 1>,
#   <Epochs |  3 events (good & bad), -4.992 - 104.96 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 1': 3>,
#   <Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 2': 4>],
#  'S2_D2 hbo': [<Epochs |  1 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    '8.0': 1>,
#   <Epochs |  3 events (good & bad), -4.992 - 104.96 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 1': 3>,
#   <Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 2': 4>],
#  'S3_D2 hbo': [<Epochs |  1 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    '8.0': 1>,
#   <Epochs |  3 events (good & bad), -4.992 - 104.96 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 1': 3>,
#   <Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 2': 4>],
#  'S4_D2 hbo': [<Epochs |  1 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    '8.0': 1>,
#   <Epochs |  3 events (good & bad), -4.992 - 104.96 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 1': 3>,
#   <Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 2': 4>],
#  'S5_D3 hbo': [<Epochs |  1 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    '8.0': 1>,
#   <Epochs |  3 events (good & bad), -4.992 - 104.96 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 1': 3>,
#   <Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 2': 4>],
#  'S6_D3 hbo': [<Epochs |  1 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    '8.0': 1>,
#   <Epochs |  3 events (good & bad), -4.992 - 104.96 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 1': 3>,
#   <Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 2': 4>],
#  'S7_D3 hbo': [<Epochs |  1 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    '8.0': 1>,
#   <Epochs |  3 events (good & bad), -4.992 - 104.96 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 1': 3>,
#   <Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 2': 4>],
#  'S7_D4 hbo': [<Epochs |  1 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    '8.0': 1>,
#   <Epochs |  3 events (good & bad), -4.992 - 104.96 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 1': 3>,
#   <Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 2': 4>],
#  'S8_D4 hbo': [<Epochs |  1 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    '8.0': 1>,
#   <Epochs |  3 events (good & bad), -4.992 - 104.96 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 1': 3>,
#   <Epochs |  4 events (good & bad), -4.992 - 120.064 sec, baseline -4.992 – 0 sec, ~13 kB, data not loaded,
#    'Block 2': 4>]}

# %%
# ATTENTION READ THE FOLLOWING COMMENT CAREFULLY BEFORE PROCEEDING (Stats test are being ran concerning study hypotheses, use a different notebook)

# %%
# skip if you're going to load the already-saved ones. for real. don't overwrite this with an empty data file. 
# SAVE SYNCHRONY VALUES

import json
json_object = json.dumps(sync_df, indent=4)

with open("/data/perlman/moochie/analysis/CARE/Test_Analysis/trail_wct_full_permuted_values.json", 'w') as outfile:
    json.dump(sync_df, outfile)
    
    
# also save as CSV
import pandas as pd

cols = ["Parent", "Child", "Block"]
for ch in channels:
    cols.append(ch)
    
df = pd.DataFrame(columns=cols)    

for parent in sync_df.keys():
    
    for child in sync_df[parent].keys():
        
        for block in sync_df[parent][child].keys():
            
            dic = {
                'Parent': parent,
                'Child': child,
                'Block': block}
            
            for key, val in sync_df[parent][child][block].items():
                dic[key] = val
            
#             print(dic)
            df = df.append(dic, ignore_index=True)
        
print(df)
df.to_csv("/data/perlman/moochie/analysis/CARE/Test_Analysis/trial_wct_full_permuted_values.csv")
# Out:
#        Parent   Child    Block  S1_D1 hbo  S2_D1 hbo  S2_D2 hbo  S3_D2 hbo  \
# 0      50001p  50291c  Block 1   0.251709   0.251525   0.299057   0.261383
# 1      50001p  50291c  Block 2   0.289868   0.268776   0.244401   0.292095
# 2      50001p  50291c  Block 3   0.239715   0.246823   0.288193   0.260592
# 3      50001p  51181c  Block 1   0.300608   0.263878   0.241687   0.234232
# 4      50001p  51181c  Block 2   0.243152   0.234133   0.251255   0.247847
# ...       ...     ...      ...        ...        ...        ...        ...
# 67405  51851p  50771c  Block 2   0.266846   0.225000   0.251856   0.273402
# 67406  51851p  50771c  Block 3   0.242324   0.239497   0.233044   0.252672
# 67407  51851p  51201c  Block 1   0.264559   0.245492   0.242274   0.224489
# 67408  51851p  51201c  Block 2   0.262602   0.246049   0.244352   0.277305
# 67409  51851p  51201c  Block 3   0.240144   0.258437   0.252288   0.222593
#
#        S4_D2 hbo  S5_D3 hbo  S6_D3 hbo  S7_D3 hbo  S7_D4 hbo  S8_D4 hbo
# 0       0.257720   0.240019   0.273819   0.268788   0.244543   0.254145
# 1       0.274524   0.235551   0.278852   0.222829   0.276189   0.253339
# 2       0.261783   0.230246   0.238489   0.215964   0.236177   0.234596
# 3       0.253288   0.226612   0.203053   0.217165   0.213900   0.232667
# 4       0.246520   0.241214   0.225285   0.236793   0.243458   0.246671
# ...          ...        ...        ...        ...        ...        ...
# 67405   0.271182   0.234387   0.253971   0.273050   0.249632   0.204146
# 67406   0.246058   0.244114   0.217807   0.244490   0.258271   0.244700
# 67407   0.260137   0.240121   0.248055   0.230443   0.249002   0.233979
# 67408   0.264265   0.229422   0.223484   0.253699   0.261393   0.251187
# 67409   0.274314   0.224397   0.279774   0.273418   0.264574   0.245104
#
# [67410 rows x 13 columns]

# %%
# Save permuted values

json_object = json.dumps(perm_df, indent=4)
with open("/data/perlman/moochie/analysis/CARE/Test_Analysis/trial_permuted_subjects.json", 'w') as outfile:
    json.dump(perm_df, outfile)

# %%
# LOAD PERMUTED SYNCHRONY VALUES from the saved file, saving time and precious CPU-hours

import json
with open("/data/perlman/moochie/analysis/CARE/Test_Analysis/permuted_subjects_1.json", 'r') as infile:
    perm_df = json.load(infile)

# %%
# LOAD REAL SYNCHRONY VALUES from the saved file, saving time and precious CPU-hours

import json
with open("/data/perlman/moochie/analysis/CARE/Test_Analysis/trial_wct_full_permuted_values_1.json", 'r') as infile:
    sync_df = json.load(infile)

# %%
# how many parents are in there (some may be repeated because they have multiple children in the study)
len(sync_df.keys())
# Out:
# 149

# %%
# how many parents are in there, without repeats
len(set([sub[:-2] for sub in list(sync_df.keys())]))
# Out:
# 123

# %%
#THE BEGINNING OF REAL VS FALSE DYADS STATS

# %%
pruned_sync_df = copy(sync_df)

# %%
#Bad channel pruning
for parent in pruned_sync_df.keys():
    
    for child in pruned_sync_df[parent].keys():
        
        for block in pruned_sync_df[parent][child].keys():
            
            for channel in pruned_sync_df[parent][child][block].keys():
                
                if (channel in bad_channels_dict[parent]) or (channel in bad_channels_dict[child]):
                    pruned_sync_df[parent][child][block][channel] = np.nan

# %%
np.isnan(pruned_sync_df['50231p']['50231c']['Block 1']['S1_D1 hbo'])
# Out:
# False

# %%
#1) AVERAGE ACROSS All ROIs

# %%
#to check whether all real dyads are included in the permuted excel file
for parent in sync_df.keys(): 
    if not (parent.replace("p", "c") in sync_df[parent].keys()):
        print(parent)

# %%
dyad_b1 = [] # make a list for real dyads
nyad_b1 = [] # make a list for not-real dyads

# this is just using Block 1 = Pre-Play

for parent in sync_df.keys():
    
    # REAL DYAD SECTION
    ###################
    real_child = parent.replace("p", "c") # # the real child, AKA true dyad, as a string

    # a loop over all the channels in the dataset
    for ch in list(sync_df[parent][real_child]['Block 1'].keys()):
        
        # new February 9th 2023 to ignore bad channels
        good = True # bool flag for whether this channel will get added
        if ch in bad_channels_dict[parent]:
            good = False
        elif ch in bad_channels_dict[real_child]:
            good = False

        if good: # only if the channel wasn't in parent or child's bad_channels_dict
            dyad_b1.append(
                sync_df[parent][real_child]['Block 1'][ch])
        
    # FALSE DYAD SECTION (NYAD)
    ###########################
    false_children = [child for child in sync_df[parent].keys() if child is not real_child] # a list of the false children

    for false_child in false_children:

        # a loop over all the channels in the dataset
        for ch in list(sync_df[parent][false_child]['Block 1'].keys()):
        
            # new February 9th 2023 to ignore bad channels
            good = True # bool flag for whether this channel will get added
            if ch in bad_channels_dict[parent]:
                good = False
            elif ch in bad_channels_dict[false_child]:
                good = False

            if good: # only if the channel wasn't in parent or child's bad_channels_dict
                nyad_b1.append(
                    sync_df[parent][false_child]['Block 1'][ch])

# %%
dyad_b2 = [] # make a list for real dyads
nyad_b2 = [] # make a list for not-real dyads

# this is just using Block 2 = Puzzle

for parent in sync_df.keys():
    
    # REAL DYAD SECTION
    ###################
    real_child = parent.replace("p", "c") # # the real child, AKA true dyad, as a string

    # a loop over all the channels in the dataset
    for ch in list(sync_df[parent][real_child]['Block 2'].keys()):
        
        # new February 9th 2023 to ignore bad channels
        good = True # bool flag for whether this channel will get added
        if ch in bad_channels_dict[parent]:
            good = False
        elif ch in bad_channels_dict[real_child]:
            good = False

        if good: # only if the channel wasn't in parent or child's bad_channels_dict
            dyad_b2.append(
                sync_df[parent][real_child]['Block 2'][ch])
        
    # FALSE DYAD SECTION (NYAD)
    ###########################
    false_children = [child for child in sync_df[parent].keys() if child is not real_child] # a list of the false children

    for false_child in false_children:

        # a loop over all the channels in the dataset
        for ch in list(sync_df[parent][false_child]['Block 2'].keys()):
        
            # new February 9th 2023 to ignore bad channels
            good = True # bool flag for whether this channel will get added
            if ch in bad_channels_dict[parent]:
                good = False
            elif ch in bad_channels_dict[false_child]:
                good = False

            if good: # only if the channel wasn't in parent or child's bad_channels_dict
                nyad_b2.append(
                    sync_df[parent][false_child]['Block 2'][ch])

# %%
dyad_b3 = [] # make a list for real dyads
nyad_b3 = [] # make a list for not-real dyads

# this is just using Block 3 = Post-Play

for parent in sync_df.keys():
    
    # REAL DYAD SECTION
    ###################
    real_child = parent.replace("p", "c") # # the real child, AKA true dyad, as a string

    # a loop over all the channels in the dataset
    for ch in list(sync_df[parent][real_child]['Block 3'].keys()):
        
        # new February 9th 2023 to ignore bad channels
        good = True # bool flag for whether this channel will get added
        if ch in bad_channels_dict[parent]:
            good = False
        elif ch in bad_channels_dict[real_child]:
            good = False

        if good: # only if the channel wasn't in parent or child's bad_channels_dict
            dyad_b3.append(
                sync_df[parent][real_child]['Block 3'][ch])
        
    # FALSE DYAD SECTION (NYAD)
    ###########################
    false_children = [child for child in sync_df[parent].keys() if child is not real_child] # a list of the false children

    for false_child in false_children:

        # a loop over all the channels in the dataset
        for ch in list(sync_df[parent][false_child]['Block 3'].keys()):
        
            # new February 9th 2023 to ignore bad channels
            good = True # bool flag for whether this channel will get added
            if ch in bad_channels_dict[parent]:
                good = False
            elif ch in bad_channels_dict[false_child]:
                good = False

            if good: # only if the channel wasn't in parent or child's bad_channels_dict
                nyad_b3.append(
                    sync_df[parent][false_child]['Block 3'][ch])

# %%
plt.clf()
plt.violinplot(
    [dyad_b1, nyad_b1],
    showmeans=True,
#     showmedians=True,
)
plt.show()

# %%
#synchrony values of real and non-real dyads plotted
plt.boxplot(
    [dyad_b1, nyad_b1],
    showmeans=True,
#     showmedians=True,
)
plt.show()

# %%
plt.clf()
plt.violinplot(
    [dyad_b2, nyad_b2],
    showmeans=True,
#     showmedians=True,
)
plt.show()

# %%
#synchrony values of real and non-real dyads plotted
plt.boxplot(
    [dyad_b2, nyad_b2],
    showmeans=True,
#     showmedians=True,
)
plt.show()

# %%
plt.clf()
plt.violinplot(
    [dyad_b3, nyad_b3],
    showmeans=True,
#     showmedians=True,
)
plt.show()

# %%
#synchrony values of real and non-real dyads plotted
plt.boxplot(
    [dyad_b3, nyad_b3],
    showmeans=True,
#     showmedians=True,
)
plt.show()

# %%
#T-TESTS ARE RAN HERE

# %%
from scipy.stats import ttest_ind

# %%
#Pre-Play
statistic, pvalue = ttest_ind(
    dyad_b1,
    nyad_b1)

# %%
statistic
# Out:
# 4.664071638054461

# %%
print("P Value for Real vs. False Dyads:", pvalue)
# Out:
# P Value for Real vs. False Dyads: 3.1020638409483385e-06

# %%
#Puzzle
statistic, pvalue = ttest_ind(
    dyad_b2,
    nyad_b2)

# %%
statistic
# Out:
# 5.900251188053853

# %%
print("P Value for Real vs. False Dyads:", pvalue)
# Out:
# P Value for Real vs. False Dyads: 3.6350967172254653e-09

# %%
#Post-Play
statistic, pvalue = ttest_ind(
    dyad_b3,
    nyad_b3)

# %%
statistic
# Out:
# 5.265260793358991

# %%
print("P Value for Real vs. False Dyads:", pvalue)
# Out:
# P Value for Real vs. False Dyads: 1.4012955922515106e-07

# %%
#Real vs Baseline (zeroes)/One-Sample T-Test

# %%
#find length of block variable first for each real or false synchrony scores
len(nyad_b3)
# Out:
# 205879

# %%
#Set a list of zeroes for one-sample t-test comparisons
zyad_z1 = []

for num in range(205879):
    zyad_z1.append(0)

# %%
#switch the dyad to synchrony block of interest
statistic, pvalue = ttest_ind(
    dyad_b2,
    dyad_b3)

# %%
statistic
# Out:
# 12.296888982113185

# %%
print("P Value for Real vs. False Dyads:", pvalue)

# %%
#2) HERE CAN TEST SPECIFIC ROIs (CHANNELS) BETWEEN REAL vs FALSE DYADS

# %%
#Use these cells below to test specific channels

# set which channels you want to include in the avg. by commenting / uncommenting lines here
# tip: use ctrl-forward slash to comment or uncomment a line or group of lines!

channels = [
  'S3_D2 hbo', # left frontal
  'S4_D2 hbo',
#   'S5_D3 hbo', # right frontal
#   'S6_D3 hbo',
#    'S1_D1 hbo', # left temporal
#    'S2_D1 hbo',
#    'S2_D2 hbo',
#    'S7_D3 hbo', #right temporal
#    'S7_D4 hbo',
#    'S8_D4 hbo'
]

dyad_c1 = [] # make a list for real dyads
nyad_c1 = [] # make a list for not-real dyads

# this is just using Block 1 = Pre-Play

for parent in sync_df.keys():
    
    # REAL DYAD SECTION
    ###################
    real_child = parent.replace("p", "c") # # the real child, AKA true dyad, as a string

    # a loop over all the channels in the dataset
    for ch in channels:
        
        # new February 9th 2023 to ignore bad channels
        good = True # bool flag for whether this channel will get added
        if ch in bad_channels_dict[parent]:
            good = False
        elif ch in bad_channels_dict[real_child]:
            good = False

        if good: # only if the channel wasn't in parent or child's bad_channels_dict
            dyad_c1.append(
                sync_df[parent][real_child]['Block 1'][ch])
        
    # FALSE DYAD SECTION (NYAD)
    ###########################
    false_children = [child for child in sync_df[parent].keys() if child is not real_child] # a list of the false children

    for false_child in false_children:

        # a loop over all the channels in the dataset
        for ch in channels:
        
            # new February 9th 2023 to ignore bad channels
            good = True # bool flag for whether this channel will get added
            if ch in bad_channels_dict[parent]:
                good = False
            elif ch in bad_channels_dict[false_child]:
                good = False

            if good: # only if the channel wasn't in parent or child's bad_channels_dict
                nyad_c1.append(
                    sync_df[parent][false_child]['Block 1'][ch])

# %%
#Pre-Play T-test (Real vs False Dyads) - Specific Channels
statistic, pvalue = ttest_ind(
    dyad_c1,
    nyad_c1)

# %%
statistic

# %%
print("P Value for Real vs. False Dyads:", pvalue)

# %%
#Use these cells below to test specific channels

# set which channels you want to include in the avg. by commenting / uncommenting lines here
# tip: use ctrl-forward slash to comment or uncomment a line or group of lines!

channels = [
    'S3_D2 hbo', # left frontal
    'S4_D2 hbo',
#      'S5_D3 hbo', # right frontal
#      'S6_D3 hbo',
     'S1_D1 hbo', # left temporal
     'S2_D1 hbo',
     'S2_D2 hbo',
#      'S7_D3 hbo', #right temporal
#      'S7_D4 hbo',
#      'S8_D4 hbo'
]

dyad_c2 = [] # make a list for real dyads
nyad_c2 = [] # make a list for not-real dyads

# this is just using Block 2 = Puzzle

for parent in sync_df.keys():
    
    # REAL DYAD SECTION
    ###################
    real_child = parent.replace("p", "c") # # the real child, AKA true dyad, as a string

    # a loop over all the channels in the dataset
    for ch in channels:
        
        # new February 9th 2023 to ignore bad channels
        good = True # bool flag for whether this channel will get added
        if ch in bad_channels_dict[parent]:
            good = False
        elif ch in bad_channels_dict[real_child]:
            good = False

        if good: # only if the channel wasn't in parent or child's bad_channels_dict
            dyad_c2.append(
                sync_df[parent][real_child]['Block 2'][ch])
        
    # FALSE DYAD SECTION (NYAD)
    ###########################
    false_children = [child for child in sync_df[parent].keys() if child is not real_child] # a list of the false children

    for false_child in false_children:

        # a loop over all the channels in the dataset
        for ch in channels:
        
            # new February 9th 2023 to ignore bad channels
            good = True # bool flag for whether this channel will get added
            if ch in bad_channels_dict[parent]:
                good = False
            elif ch in bad_channels_dict[false_child]:
                good = False

            if good: # only if the channel wasn't in parent or child's bad_channels_dict
                nyad_c2.append(
                    sync_df[parent][false_child]['Block 2'][ch])

# %%
#Puzzle T-test (Real vs False Dyads) - Specific Channels
statistic, pvalue = ttest_ind(
    dyad_b2,
    nyad_c2)

# %%
statistic

# %%
print("P Value for Real vs. False Dyads:", pvalue)

# %%
#Use these cells below to test specific channels

# set which channels you want to include in the avg. by commenting / uncommenting lines here
# tip: use ctrl-forward slash to comment or uncomment a line or group of lines!

channels = [
      'S3_D2 hbo', # left frontal
      'S4_D2 hbo',
#       'S5_D3 hbo', # right frontal
#       'S6_D3 hbo',
      'S1_D1 hbo', # left temporal
      'S2_D1 hbo',
      'S2_D2 hbo',
#       'S7_D3 hbo', #right temporal
#       'S7_D4 hbo',
#       'S8_D4 hbo'
]

dyad_c3 = [] # make a list for real dyads
nyad_c3 = [] # make a list for not-real dyads

# this is just using Block 3 = Post-Play

for parent in sync_df.keys():
    
    # REAL DYAD SECTION
    ###################
    real_child = parent.replace("p", "c") # # the real child, AKA true dyad, as a string

    # a loop over all the channels in the dataset
    for ch in channels:
        
        # new February 9th 2023 to ignore bad channels
        good = True # bool flag for whether this channel will get added
        if ch in bad_channels_dict[parent]:
            good = False
        elif ch in bad_channels_dict[real_child]:
            good = False

        if good: # only if the channel wasn't in parent or child's bad_channels_dict
            dyad_c3.append(
                sync_df[parent][real_child]['Block 3'][ch])
        
    # FALSE DYAD SECTION (NYAD)
    ###########################
    false_children = [child for child in sync_df[parent].keys() if child is not real_child] # a list of the false children

    for false_child in false_children:

        # a loop over all the channels in the dataset
        for ch in channels:
        
            # new February 9th 2023 to ignore bad channels
            good = True # bool flag for whether this channel will get added
            if ch in bad_channels_dict[parent]:
                good = False
            elif ch in bad_channels_dict[false_child]:
                good = False

            if good: # only if the channel wasn't in parent or child's bad_channels_dict
                nyad_c3.append(
                    sync_df[parent][false_child]['Block 3'][ch])

# %%
#Post-Play T-test (Real vs False Dyads) - Specific Channels
statistic, pvalue = ttest_ind(
    dyad_c3,
    nyad_c3)

# %%
statistic

# %%
print("P Value for Real vs. False Dyads:", pvalue)

# %%
#TESTING BETWEEN BLOCK DIFFERECNES BETWEEN REAL DYADS (AVERAGE ACROSS ALL BLOCKS) THERE SHOULD BE 3 COMBINATIONS TOTAL

# %%
#Use the dyad variables created previously in the Real vs False Dyad analyses to test between Blocks
#T-test (Real vs False Dyads) 
statistic, pvalue = ttest_ind(
    dyad_b1,
    dyad_b3)

# %%
statistic

# %%
print("P Value for Real vs. False Dyads:", pvalue)

# %%
#INCORPORATION of CARE QUESTIONNAIRE SCORES BEGINS HERE

# %%
#The code and CSV for the OLD RDAS files for reference (DON'T RUN THIS SECTION)

# %%
# load CSV from emily Hone groups
# groups = pd.read_csv("/data/perlman/moochie/analysis/CARE/forperlman_rdaslist_20221101.csv")
# groups['subject'] = [id.replace('-', '') for id in groups['record_id']]
# groups.set_index('subject', inplace=True)

# %%
groups

# %%
# load CSV from emily Hone's RDAS scores
# scores = pd.read_csv("/data/perlman/moochie/analysis/CARE/Clayton_Alana/forkhalil_fullscored.csv")
# scores['subject'] = [id.replace('-', '') for id in scores['record_id']]
# scores.set_index('subject', inplace=True)
# scores.drop(columns=['record_id'], inplace=True)
# scores = scores.astype({'famid': 'str'})

# %%
scores

# %%
# see how many rows there are in there
# weird number, huh?
# it's because not everybody has RDAS data :(
# len([id for id in scores.index])
# Out:
# 112

# %%
#START HERE (Incorporates most recent baseline data from Pitt Group)

# %%
blocks = {
    'Block 1': 'Pre-Play',
    'Block 2': 'Puzzle',
    'Block 3': 'Post-Play',
}

COIs = [
    'rdas_consensus',
    'rdas_satisfaction',
    'rdas_cohesion',
    'rdas_total'
#     'total'
]

channels = [
     'S3_D2 hbo', # left frontal
     'S4_D2 hbo',
     'S5_D3 hbo', # right frontal
     'S6_D3 hbo',
     'S1_D1 hbo', # left temporal
     'S2_D1 hbo',
     'S2_D2 hbo',
     'S7_D3 hbo', # right temporal
     'S7_D4 hbo',
     'S8_D4 hbo',
]

# %%
channels
# Out:
# ['S3_D2 hbo',
#  'S4_D2 hbo',
#  'S5_D3 hbo',
#  'S6_D3 hbo',
#  'S1_D1 hbo',
#  'S2_D1 hbo',
#  'S2_D2 hbo',
#  'S7_D3 hbo',
#  'S7_D4 hbo',
#  'S8_D4 hbo']

# %%
COIs
# Out:
# ['rdas_consensus', 'rdas_satisfaction', 'rdas_cohesion', 'rdas_total']

# %%
# load CARE Pitt Group CSV 
scores = pd.read_csv("/data/perlman/moochie/analysis/CARE/Baseline_PSU_csv.csv")
scores['subject'] = [id for id in scores['record_id']]
scores = scores.astype({'subject': 'str'})
scores = scores.mask(scores == ' ')
for COI in COIs:
    scores = scores.astype({COI: 'float'})
scores.set_index('subject', inplace=True)
scores.drop(columns=['record_id'], inplace=True)

# %%
#PRQ = Parent Relationship Questionnaire
scores
# Out:
#          family_id    group  timepoint        date       age sex_at_birth  \
# subject
# 50001         5000  divorce          0  2021-01-11  5.286790         male
# 50021         5002  control          0  2021-03-18  5.130732       female
# 50031         5003  control          0  2021-07-06  4.002738       female
# 50032         5003  control          0  2021-07-29  7.945243         male
# 50071         5007  control          0  2021-03-31  5.032170         male
# ...            ...      ...        ...         ...       ...          ...
# 51801         5180  control          0  2023-03-22  7.134839         male
# 51831         5183  control          0  2023-03-28  6.841889         male
# 51841         5184  control          0  2023-03-28  5.845311       female
# 51851         5185  control          0  2023-03-14  7.397673       female
# 51881         5188  control          0  2023-04-13  7.296372       female
#
#          sex_male         race  race_white               ethnicity  ...  \
# subject                                                             ...
# 50001        True        white        True  Not Hispanic or Latino  ...
# 50021       False        white        True  Not Hispanic or Latino  ...
# 50031       False        white        True  Not Hispanic or Latino  ...
# 50032        True        white        True  Not Hispanic or Latino  ...
# 50071        True  multiracial       False  Not Hispanic or Latino  ...
# ...           ...          ...         ...                     ...  ...
# 51801        True        Asian       False  Not Hispanic or Latino  ...
# 51831        True  multiracial       False  Not Hispanic or Latino  ...
# 51841       False        white        True  Not Hispanic or Latino  ...
# 51851       False        white        True  Not Hispanic or Latino  ...
# 51881       False        white        True      Hispanic or Latino  ...
#
#          rdas_c_11_current  rdas_c_12_current rdas_c_13_current  \
# subject
# 50001                  NaN                NaN               NaN
# 50021                  3.0                4.0               3.0
# 50031                  NaN                NaN               NaN
# 50032                  NaN                NaN               NaN
# 50071                  NaN                NaN               NaN
# ...                    ...                ...               ...
# 51801                  1.0                3.0               0.0
# 51831                  2.0                3.0               3.0
# 51841                  2.0                3.0               2.0
# 51851                  3.0                3.0               3.0
# 51881                  NaN                NaN               NaN
#
#          rdas_c_14_current revised_dyadic_adjustment_scale_rdas_complete  \
# subject
# 50001                  NaN                                           NaN
# 50021                  4.0                                           2.0
# 50031                  NaN                                           NaN
# 50032                  NaN                                           NaN
# 50071                  NaN                                           NaN
# ...                    ...                                           ...
# 51801                  0.0                                           2.0
# 51831                  3.0                                           2.0
# 51841                  3.0                                           2.0
# 51851                  4.0                                           2.0
# 51881                  NaN                                           NaN
#
#          revised_dyadic_adjustment_scale_rdas_divorce_complete rdas_consensus  \
# subject
# 50001                                                  NaN                NaN
# 50021                                                  NaN               27.0
# 50031                                                  NaN                NaN
# 50032                                                  NaN                NaN
# 50071                                                  NaN                NaN
# ...                                                    ...                ...
# 51801                                                  NaN               24.0
# 51831                                                  NaN               24.0
# 51841                                                  NaN               22.0
# 51851                                                  NaN               25.0
# 51881                                                  NaN                NaN
#
#          rdas_satisfaction rdas_cohesion rdas_total
# subject
# 50001                  NaN           NaN        NaN
# 50021                 17.0          13.0       57.0
# 50031                  NaN           NaN        NaN
# 50032                  NaN           NaN        NaN
# 50071                  NaN           NaN        NaN
# ...                    ...           ...        ...
# 51801                 16.0           6.0       46.0
# 51831                 15.0          11.0       50.0
# 51841                 15.0           8.0       45.0
# 51851                 14.0          11.0       50.0
# 51881                  NaN           NaN        NaN
#
# [174 rows x 1119 columns]

# %%
scores.columns
# Out:
# Index(['family_id', 'group', 'timepoint', 'date', 'age', 'sex_at_birth',
#        'sex_male', 'race', 'race_white', 'ethnicity',
#        ...
#        'rdas_c_11_current', 'rdas_c_12_current', 'rdas_c_13_current',
#        'rdas_c_14_current', 'revised_dyadic_adjustment_scale_rdas_complete',
#        'revised_dyadic_adjustment_scale_rdas_divorce_complete',
#        'rdas_consensus', 'rdas_satisfaction', 'rdas_cohesion', 'rdas_total'],
#       dtype='object', length=1119)

# %%
scores.index
# Out:
# Index(['50001', '50021', '50031', '50032', '50071', '50081', '50091', '50092',
#        '50101', '50111',
#        ...
#        '51741', '51751', '51771', '51781', '51791', '51801', '51831', '51841',
#        '51851', '51881'],
#       dtype='object', name='subject', length=174)

# %%
# see how many rows there are in there
len([id for id in scores.index])
# Out:
# 174

# %%
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy.stats.mstats import winsorize

# %%
# this is because, in the sync_df, we need to have a way to differentiate between the parent and child. so subject names are, e.g.
# 1234p or 1234c. Whereas, in your .csv / dataframe for other variables of interest, they are not specific to a parent or child, but a family. 
# so we often combine these values by looping over the parents (top level values in sync_df that end in "p"), and then reference that name,
# with the "p" replaced by "" (nothing) to access the correct value in the dataframe. 

channels = [
     'S3_D2 hbo', # left frontal
     'S4_D2 hbo',
     'S5_D3 hbo', # right frontal
     'S6_D3 hbo',
     'S1_D1 hbo', # left temporal
     'S2_D1 hbo',
     'S2_D2 hbo',
     'S7_D3 hbo', # right temporal
     'S7_D4 hbo',
     'S8_D4 hbo'
]

#Set the Block of Interest here

block_num = 'Block 1'
block_name = 'Pre-Play'

# Set an identifier function for handling family id
# Use the difference in size of the ID's as a guide
sync_sample = list(sync_df.keys())[0]
scores_sample = scores.index[0]
identifier_diff =  len(scores_sample) - len(sync_sample) # Figure out how much smaller the scores sample is
score_identifier = lambda string : string[:identifier_diff]

# Variant 1 (individual block)
# ==================
# for all the parent / child pairs who are listed in the scores .csv / dataframe,
#    and averaging over all the channels that are uncommented above
#    so this will yield a list called "syncs" which is as long as the number of parent / child pairs 
#    that are found in both sync_df and the scores dataframe
#    i.e. 1 averaged WTC value per dyad, specifically derived from whichever block is named in 
#    "block_num" above.

syncs = []
sync_parents = []
for parent in list(sync_df.keys()):
    dyad_syncs = []
    child = parent.replace('p', 'c')
    if score_identifier(parent) in list(scores.index):
        for ch in channels:
            if ch not in bad_channels_dict[parent]:
                if ch not in bad_channels_dict[child]:
                    dyad_syncs.append(sync_df[parent][child][block_num][ch])
    if len(dyad_syncs) > 0:
        syncs.append(np.average(dyad_syncs))
        sync_parents.append(parent)
        
# print(sync_parents)
# Variant 2 (block difference)
# ==================
# this version is doing the same thing, but specifically looking at the _difference_ of the WTC
#    in a dyad between two blocks. In this example, you can see that it is marking the difference
#    between sync of 'Block 2' and 'Block 1'. You are welcome to configure those variables 
#    as you see fit. The shape of the output list, syncs, will be the same as in Variant 1, and you
#    could use it just as well in any subsequent regressions, etc.  


# syncs = []
# sync_parents = []
# for parent in list(sync_df.keys()):
#    dyad_syncs = []
#    child = parent.replace('p', 'c')
#    if parent.replace('p', '') in list(scores.index):
#       for ch in channels:
#          if ch not in bad_channels_dict[parent]:
#             if ch not in bad_channels_dict[child]:
#                dyad_syncs.append(
#                   sync_df[parent][child]['Block 1'][ch] - \
#                   sync_df[parent][child]['Block 3'][ch])
#    if len(dyad_syncs) > 0:
#       syncs.append(np.average(dyad_syncs))
#       sync_parents.append(parent)


# Regression
# ================
# looping over the "columns of interest" which should be defined in a previous cell. as COIs = [ <stuff> ]
#     i.e., the names of any columns in your .csv you want to run regression on
for COI in COIs:

    # get the current variable of interest from the "scores" dataframe
    #    once again, only for subjects who are found in both the sync_df 
    #    and in the scores dataframe / .csv.
    voi = [scores.loc[[sub]][COI][0] for sub in [sub.replace('p', '') for sub in sync_parents]]
    
    # force the values read to be interpreted as float, as opposed to default string
    xnan = np.array(voi, dtype='float')
    ynan = np.array(syncs, dtype='float')

    # IQR correction if desired
#         # get IQR
#         q75, q25 = np.percentile(xnan, [75, 25])
#         intr_qr = q75 - q25
#         qmax = q75 + (1.5 * intr_qr)
#         qmin = q25 - (1.5 * intr_qr)
#         # remove the extra-IQR vals
#         xnan[xnan < qmin] = qmin
#         xnan[xnan > qmax] = qmin

    # remove any values that are NaN (hopefully none?) otherwise there
    #    may be issues in your .csv format 
    x = np.delete(xnan, np.where(np.isnan(xnan)))
    y = np.delete(ynan, np.where(np.isnan(xnan)))

    # Winsorize function (not recommended)
    # winsorize(y, inplace=True, limits=[0.05, 0.05])
    # winsorize(x, inplace=True, limits=[0.05, 0.05])

    # duplicate variables for use in regression (requires reshaping)
    X = x
    Y = y
    x = x.reshape(-1, 1)
    model = LinearRegression().fit(x, y)
    r_sq = model.score(x, y)
    print(f"Coefficient of Determination: {r_sq}")
    print(f"intercept: {model.intercept_}")
    print(f"slope: {model.coef_}")

    # plot data
    plt.clf()
    plt.scatter(
        x,
        y,
        color='black')

    # plot regression line
    plt.plot(
        np.linspace(np.min(x), np.max(x)),
        model.predict(np.linspace(np.min(x), np.max(x)).reshape(-1, 1)),
        color='blue',
        linewidth=1.5)

    plt.xlabel(f" {COI.upper()}")
    plt.ylabel(f"Dyadic Synchrony in {block_name}")
    plt.title(f"{block_name}: {COI}")
    plt.show()
    X2 = sm.add_constant(X)
    est = sm.OLS(Y, X2)
    est2 = est.fit()
    print(est2.summary())
# Out:
# Coefficient of Determination: 0.004544674028192142
# intercept: 0.24216204947384173
# slope: [0.00015168]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.5889
# Date:                Thu, 06 Jul 2023   Prob (F-statistic):              0.444
# Time:                        12:35:57   Log-Likelihood:                 376.00
# No. Observations:                 131   AIC:                            -748.0
# Df Residuals:                     129   BIC:                            -742.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2422      0.005     53.456      0.000       0.233       0.251
# x1             0.0002      0.000      0.767      0.444      -0.000       0.001
# ==============================================================================
# Omnibus:                        1.782   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.410   Jarque-Bera (JB):                1.301
# Skew:                           0.160   Prob(JB):                        0.522
# Kurtosis:                       3.369   Cond. No.                         86.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Coefficient of Determination: 0.0015906535527466792
# intercept: 0.2437621973663866
# slope: [0.00012484]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.006
# Method:                 Least Squares   F-statistic:                    0.2055
# Date:                Thu, 06 Jul 2023   Prob (F-statistic):              0.651
# Time:                        12:35:58   Log-Likelihood:                 375.81
# No. Observations:                 131   AIC:                            -747.6
# Df Residuals:                     129   BIC:                            -741.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2438      0.004     60.241      0.000       0.236       0.252
# x1             0.0001      0.000      0.453      0.651      -0.000       0.001
# ==============================================================================
# Omnibus:                        1.675   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.433   Jarque-Bera (JB):                1.203
# Skew:                           0.146   Prob(JB):                        0.548
# Kurtosis:                       3.368   Cond. No.                         49.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Coefficient of Determination: 0.03671474151432608
# intercept: 0.23882351567683718
# slope: [0.00065591]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.037
# Model:                            OLS   Adj. R-squared:                  0.029
# Method:                 Least Squares   F-statistic:                     4.917
# Date:                Thu, 06 Jul 2023   Prob (F-statistic):             0.0283
# Time:                        12:35:58   Log-Likelihood:                 378.15
# No. Observations:                 131   AIC:                            -752.3
# Df Residuals:                     129   BIC:                            -746.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2388      0.003     73.660      0.000       0.232       0.245
# x1             0.0007      0.000      2.217      0.028    7.07e-05       0.001
# ==============================================================================
# Omnibus:                        4.756   Durbin-Watson:                   1.971
# Prob(Omnibus):                  0.093   Jarque-Bera (JB):                4.573
# Skew:                           0.304   Prob(JB):                        0.102
# Kurtosis:                       3.685   Cond. No.                         30.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Coefficient of Determination: 0.011360168924339775
# intercept: 0.24018119643473892
# slope: [0.00011512]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     1.482
# Date:                Thu, 06 Jul 2023   Prob (F-statistic):              0.226
# Time:                        12:35:58   Log-Likelihood:                 376.45
# No. Observations:                 131   AIC:                            -748.9
# Df Residuals:                     129   BIC:                            -743.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2402      0.005     52.886      0.000       0.231       0.249
# x1             0.0001   9.46e-05      1.217      0.226    -7.2e-05       0.000
# ==============================================================================
# Omnibus:                        2.057   Durbin-Watson:                   1.966
# Prob(Omnibus):                  0.358   Jarque-Bera (JB):                1.556
# Skew:                           0.196   Prob(JB):                        0.459
# Kurtosis:                       3.362   Cond. No.                         181.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
len(set([sub[:-1] for sub in list(sync_df.keys())]))

# %%
#Older code to run group analysis for RDAS data (CAN STOP HERE UNLESS YOU NEED TO RUN GROUPS)

# %%
# Differences in synchrony between the conflict and non-conflict group
group1syncs = [] # get synchrony from all of groups 1 (control)
group2syncs = [] # get synchrony from problem group

# set which channels you want to include in the avg. by commenting / uncommenting lines here
# tip: use ctrl-forward slash to comment or uncomment a line or group of lines!

channels = [
#     'S3_D2 hbo', # left frontal
    'S4_D2 hbo',
    'S5_D3 hbo', # right frontal
#     'S6_D3 hbo',
#     'S1_D1 hbo', # left temporal
#     'S2_D1 hbo',
#     'S2_D2 hbo',
#     'S7_D3 hbo', #right temporal
#     'S7_D4 hbo',
#     'S8_D4 hbo'
]

for sub in sync_df.keys():
    avgsync = np.average([
        sync_df[sub][sub.replace('p', 'c')]['Block 2'][ch] for ch in channels])
    
    if (groups.loc[[sub.replace('p', '')]]['enroll_group'][0] == "Control") and \
        (groups.loc[[sub.replace('p', '')]]['rdas_group'][0] == "Non-Conflict"):
        group1syncs.append(avgsync)
    else:
        group2syncs.append(avgsync)
        
plt.clf()
plt.violinplot(
    [group1syncs, group2syncs],
    showmeans=True)
plt.show()

statistic, pvalue = ttest_ind(
    group1syncs,
    group2syncs)

print("T stat:", statistic, "\n", "P value:", pvalue)

# %%
np.std(group2syncs)

# %%
# enrollment group 2 OR above RDAS critical value == conflict group

# %%
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy.stats.mstats import winsorize

# %%
#configuration section that allows you to change which blocks, RDAS columns, and channels you want to include in subsequent analysis
blocks = {
    'Block 1': 'Pre-Play',
    'Block 2': 'Puzzle',
    'Block 3': 'Post-Play',
}

COIs = [
    'consensus',
    'satisfaction',
    'cohesion',
#     'total'
]

channels = [
#     'S3_D2 hbo', # left frontal
    'S4_D2 hbo',
    'S5_D3 hbo', # right frontal
#     'S6_D3 hbo',
#     'S1_D1 hbo', # left temporal
#     'S2_D1 hbo',
#     'S2_D2 hbo',
#     'S7_D3 hbo', #right temporal
#     'S7_D4 hbo',
#     'S8_D4 hbo'
]
